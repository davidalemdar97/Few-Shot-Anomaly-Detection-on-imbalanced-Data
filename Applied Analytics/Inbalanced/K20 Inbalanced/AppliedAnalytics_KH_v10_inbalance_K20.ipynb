# %% [markdown]
# # Google Drive Connection

# %%
from google.colab import drive
drive.mount('/content/drive')

import sys
import os
sys.path.append('/content/drive/MyDrive/Applied Analytics/Applied-Analytics_Few-Shot-AD/')

from utils import load_local_dataset

#base_path = "/Users/kaihorlacher/Documents/HochschuleAalen/Semester2/03_Machine Learning Research (Data Science)/Applied-Analytics_Few-Shot-AD"
#data_path = base_path + "/data/mechanicalseals"

#base_path_gd = "/content/drive/MyDrive/03 HS Aalen/Applied-Analytics_Few-Shot-AD" # TODO: insert path to your project
#data_path_gd = base_path_gd + "/data/mechanicalseals"

base_path = "/content/drive/MyDrive/Applied Analytics/Applied-Analytics_Few-Shot-AD" # TODO: insert path to your project
data_path = base_path + "/data/mechanicalseals"
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Packages & Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
import random

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers.legacy import Adam, SGD
from keras.preprocessing.image import ImageDataGenerator
from keras.applications import VGG16, ResNet50, InceptionV3, Xception
from keras.applications.vgg16 import preprocess_input
from keras.layers import Flatten, Dense, Dropout, GlobalAveragePooling2D
from keras.callbacks import EarlyStopping
from keras.models import Model, Sequential, clone_model
from keras import backend as K
import datetime


#Pre-processed Images - Input jeweilige Modelle
from tensorflow.keras.applications.vgg16 import preprocess_input as pre_input_vgg16
from tensorflow.keras.applications.resnet50 import preprocess_input as pre_input_resnet50
from tensorflow.keras.applications.inception_v3 import preprocess_input as pre_input_inception_v3
from tensorflow.keras.applications.xception import preprocess_input as pre_input_xception
from sklearn.metrics import balanced_accuracy_score

from sklearn.metrics import make_scorer, f1_score
from sklearn.metrics import roc_auc_score
from tqdm import tqdm
import pandas as pd

from sklearn.metrics import confusion_matrix

import copy
import cv2

from skimage import exposure

# %% [markdown]
# # Data Preprocess & Reproductability

# %%
# Set seed for reproducibility
seed_value = 72
tf.random.set_seed(seed_value)
random.seed(seed_value)
np.random.seed(seed_value)

# %%
#Data splitting
X, y = load_local_dataset(data_path, encoding="integer")
# Out:
# Dataset loaded: 181 images (shape: (224, 224, 3)), belonging to 2 classes.

# %%
# Preprocessing the images with original preprocess of its models

#List with names of the models
list_of_pre_images_models = ["VGG16", "ResNet50", "InceptionV3", "Xception"]

root_x = copy.copy(X)
root_x1 = copy.copy(X)
root_x2 = copy.copy(X)
root_x3 = copy.copy(X)

#Below are the models copied and preprocessed
X_preprocessed_images_vgg16 = copy.copy(X)
X_preprocessed_images_vgg16_rgb = []

for each1 in root_x:
  preprocessed_image1 = pre_input_vgg16(each1)
  X_preprocessed_images_vgg16_rgb.append(preprocessed_image1)

X_preprocessed_images_resnet50_rgb = []


for each2 in root_x1:
  preprocessed_image2 = pre_input_resnet50(each2)
  X_preprocessed_images_resnet50_rgb.append(preprocessed_image2)

X_preprocessed_images_inceptionv3_rgb = []

for each3 in root_x2:
    if each3.shape[2] == 3:
        # Skaling pixel areas from 0 to 255
        each3 = each3 * 255

        # Wende das Preprocessing an
        preprocessed_image_incep_299 = cv2.resize(each3, (299, 299))
        preprocessed_image3 = pre_input_inception_v3(preprocessed_image_incep_299)

        X_preprocessed_images_inceptionv3_rgb.append(preprocessed_image3)
    else:
        print("Error")


X_preprocessed_images_xception_rgb = []
for each4 in root_x3:
    if each4.shape[2] == 3:
        # Skaling pixel areas from 0 to 255
        each4 = each4 * 255

        # Wende das Preprocessing an
        preprocessed_image_xcep_299 = cv2.resize(each4, (299, 299))
        preprocessed_image4 = pre_input_xception(preprocessed_image_xcep_299)

        X_preprocessed_images_xception_rgb.append(preprocessed_image4)
    else:
        print("Error")

# %%
# Checking the images with its preprocess for more understanding (in a 2x2 plot)
fig, axes = plt.subplots(2, 2, figsize=(10, 10))
liste_pic = [X_preprocessed_images_vgg16_rgb[100].astype("uint8"),
             X_preprocessed_images_resnet50_rgb[100].astype("uint8"),
             (X_preprocessed_images_inceptionv3_rgb[100]).astype("uint8"),
             (X_preprocessed_images_xception_rgb[100]).astype("uint8")]

for i, ax in enumerate(axes.flat):
    ax.imshow(liste_pic[i])
    ax.axis('off')

plt.show()

# %%
#Creating splitted lists for X and y for each model because of its different preprocess method
X_undamaged_vgg16 = []
y_undamaged_vgg16 = []
X_damaged_vgg16 = []
y_damaged_vgg16 = []

X_undamaged_resnet50 = []
y_undamaged_resnet50 = []
X_damaged_resnet50 = []
y_damaged_resnet50 = []

X_undamaged_inceptionv3= []
y_undamaged_inceptionv3 = []
X_damaged_inceptionv3 = []
y_damaged_inceptionv3 = []

X_undamaged_xception = []
y_undamaged_xception = []
X_damaged_xception = []
y_damaged_xception = []

#Taking all data of X and y and iterating with for-clause to get the right split of undamaged and damaged
sample_count = 0


for element in X:
  #print(y[sample_count])
  #print(X[sample_count])

  if y[sample_count] == 1:
    X_damaged_vgg16.append(X_preprocessed_images_vgg16_rgb[sample_count])
    y_damaged_vgg16.append(y[sample_count])

    X_damaged_resnet50.append(X_preprocessed_images_resnet50_rgb[sample_count])
    y_damaged_resnet50.append(y[sample_count])

    X_damaged_inceptionv3.append(X_preprocessed_images_inceptionv3_rgb[sample_count])
    y_damaged_inceptionv3.append(y[sample_count])

    X_damaged_xception.append(X_preprocessed_images_xception_rgb[sample_count])
    y_damaged_xception.append(y[sample_count])

  elif y[sample_count] == 0:
    X_undamaged_vgg16.append(X_preprocessed_images_vgg16_rgb[sample_count])
    y_undamaged_vgg16.append(y[sample_count])

    X_undamaged_resnet50.append(X_preprocessed_images_resnet50_rgb[sample_count])
    y_undamaged_resnet50.append(y[sample_count])

    X_undamaged_inceptionv3.append(X_preprocessed_images_inceptionv3_rgb[sample_count])
    y_undamaged_inceptionv3.append(y[sample_count])

    X_undamaged_xception.append(X_preprocessed_images_xception_rgb[sample_count])
    y_undamaged_xception.append(y[sample_count])

  sample_count+=1

print("The amount of undamaged images are: " + str(len(X_undamaged_vgg16)) + " inclusive the same number of labels:  " + str(len(y_undamaged_vgg16)))
print("The amount of damaged images are: " + str(len(X_damaged_vgg16)) + " inclusive the same number of labels: " + str(len(y_damaged_vgg16)))
# Out:
# The amount of undamaged images are: 93 inclusive the same number of labels:  93
# The amount of damaged images are: 88 inclusive the same number of labels: 88

# %% [markdown]
# # Prepare Training/Validation/Test

# %% [markdown]
# # K-Sharings

# %% [markdown]
# Below we are creating the K-Shot datasets for each models separated for my clearness

# %% [markdown]
# **VGG16**

# %%
# -----------  Traindata K15  -------------

normal_data_vgg16_k5 = np.array(X_undamaged_vgg16[:5])
anomaly_data_vgg16_k5 = np.array(X_damaged_vgg16[:10])

train_data_vgg16_k5 = np.concatenate((normal_data_vgg16_k5, anomaly_data_vgg16_k5), axis=0)
train_labels_vgg16_k5 = np.concatenate((np.zeros(len(normal_data_vgg16_k5)), np.ones(len(anomaly_data_vgg16_k5))))

# Validation K5
normal_val_data_vgg16_k5 = np.array(X_undamaged_vgg16[71:73])
anomaly_val_data_vgg16_k5 = np.array(X_damaged_vgg16[44:48])

val_data_vgg16_k5 = np.concatenate((normal_val_data_vgg16_k5, anomaly_val_data_vgg16_k5), axis=0)
val_labels_vgg16_k5 = np.concatenate((np.zeros(len(normal_val_data_vgg16_k5)), np.ones(len(anomaly_val_data_vgg16_k5))))

# Test K5
normal_test_data_vgg16_k5 = np.array(X_undamaged_vgg16[73:93])
anomaly_test_data_vgg16_k5 = np.array(X_damaged_vgg16[48:88])

test_data_vgg16_k5 = np.concatenate((normal_test_data_vgg16_k5, anomaly_test_data_vgg16_k5), axis=0)
test_labels_vgg16_k5 = np.concatenate((np.zeros(len(normal_test_data_vgg16_k5)), np.ones(len(anomaly_test_data_vgg16_k5))))


# -----------  Traindata K10  -------------

normal_data_vgg16_k10 = np.array(X_undamaged_vgg16[:10])
anomaly_data_vgg16_k10 = np.array(X_damaged_vgg16[:20])

train_data_vgg16_k10 = np.concatenate((normal_data_vgg16_k10, anomaly_data_vgg16_k10), axis=0)
train_labels_vgg16_k10 = np.concatenate((np.zeros(len(normal_data_vgg16_k10)), np.ones(len(anomaly_data_vgg16_k10))))

# Validation K10
normal_val_data_vgg16_k10 = np.array(X_undamaged_vgg16[69:73])
anomaly_val_data_vgg16_k10 = np.array(X_damaged_vgg16[40:48])

val_data_vgg16_k10 = np.concatenate((normal_val_data_vgg16_k10, anomaly_val_data_vgg16_k10), axis=0)
val_labels_vgg16_k10 = np.concatenate((np.zeros(len(normal_val_data_vgg16_k10)), np.ones(len(anomaly_val_data_vgg16_k10))))

# Test K10
normal_test_data_vgg16_k10 = np.array(X_undamaged_vgg16[73:93])
anomaly_test_data_vgg16_k10 = np.array(X_damaged_vgg16[48:88])

test_data_vgg16_k10 = np.concatenate((normal_test_data_vgg16_k10, anomaly_test_data_vgg16_k10), axis=0)
test_labels_vgg16_k10 = np.concatenate((np.zeros(len(normal_test_data_vgg16_k10)), np.ones(len(anomaly_test_data_vgg16_k10))))

# -----------  Traindata K20  -------------
normal_data_vgg16_k20 = np.array(X_undamaged_vgg16[:20])
anomaly_data_vgg16_k20 = np.array(X_damaged_vgg16[:40])

train_data_vgg16_k20 = np.concatenate((normal_data_vgg16_k20, anomaly_data_vgg16_k20), axis=0)
train_labels_vgg16_k20 = np.concatenate((np.zeros(len(normal_data_vgg16_k20)), np.ones(len(anomaly_data_vgg16_k20))))

# Validation K20
normal_val_data_vgg16_k20 = np.array(X_undamaged_vgg16[69:73])
anomaly_val_data_vgg16_k20 = np.array(X_damaged_vgg16[40:48])

val_data_vgg16_k20 = np.concatenate((normal_val_data_vgg16_k20, anomaly_val_data_vgg16_k20), axis=0)
val_labels_vgg16_k20 = np.concatenate((np.zeros(len(normal_val_data_vgg16_k20)), np.ones(len(anomaly_val_data_vgg16_k20))))

# Test K20
normal_test_data_vgg16_k20 = np.array(X_undamaged_vgg16[73:93])
anomaly_test_data_vgg16_k20 = np.array(X_damaged_vgg16[48:88])

test_data_vgg16_k20 = np.concatenate((normal_test_data_vgg16_k20, anomaly_test_data_vgg16_k20), axis=0)
test_labels_vgg16_k20 = np.concatenate((np.zeros(len(normal_test_data_vgg16_k20)), np.ones(len(anomaly_test_data_vgg16_k20))))

# %% [markdown]
# **ResNet50**

# %%
# -----------  Traindata K5  -------------

normal_data_resnet50_k5 = np.array(X_undamaged_resnet50[:5])
anomaly_data_resnet50_k5 = np.array(X_damaged_resnet50[:10])

train_data_resnet50_k5 = np.concatenate((normal_data_resnet50_k5, anomaly_data_resnet50_k5), axis=0)
train_labels_resnet50_k5 = np.concatenate((np.zeros(len(normal_data_resnet50_k5)), np.ones(len(anomaly_data_resnet50_k5))))

# Validation K5
normal_val_data_resnet50_k5 = np.array(X_undamaged_resnet50[71:73])
anomaly_val_data_resnet50_k5 = np.array(X_damaged_resnet50[44:48])

val_data_resnet50_k5 = np.concatenate((normal_val_data_resnet50_k5, anomaly_val_data_resnet50_k5), axis=0)
val_labels_resnet50_k5 = np.concatenate((np.zeros(len(normal_val_data_resnet50_k5)), np.ones(len(anomaly_val_data_resnet50_k5))))

# Test K5
normal_test_data_resnet50_k5 = np.array(X_undamaged_resnet50[73:93])
anomaly_test_data_resnet50_k5 = np.array(X_damaged_resnet50[48:88])

test_data_resnet50_k5 = np.concatenate((normal_test_data_resnet50_k5, anomaly_test_data_resnet50_k5), axis=0)
test_labels_resnet50_k5 = np.concatenate((np.zeros(len(normal_test_data_resnet50_k5)), np.ones(len(anomaly_test_data_resnet50_k5))))

# -----------  Traindata K10  -------------

normal_data_resnet50_k10 = np.array(X_undamaged_resnet50[:10])
anomaly_data_resnet50_k10 = np.array(X_damaged_resnet50[:20])

train_data_resnet50_k10 = np.concatenate((normal_data_resnet50_k10, anomaly_data_resnet50_k10), axis=0)
train_labels_resnet50_k10 = np.concatenate((np.zeros(len(normal_data_resnet50_k10)), np.ones(len(anomaly_data_resnet50_k10))))

# Validation K10
normal_val_data_resnet50_k10 = np.array(X_undamaged_resnet50[69:73])
anomaly_val_data_resnet50_k10 = np.array(X_damaged_resnet50[40:48])

val_data_resnet50_k10 = np.concatenate((normal_val_data_resnet50_k10, anomaly_val_data_resnet50_k10), axis=0)
val_labels_resnet50_k10 = np.concatenate((np.zeros(len(normal_val_data_resnet50_k10)), np.ones(len(anomaly_val_data_resnet50_k10))))

# Test K10 20%
normal_test_data_resnet50_k10 = np.array(X_undamaged_resnet50[73:93])
anomaly_test_data_resnet50_k10 = np.array(X_damaged_resnet50[48:88])

test_data_resnet50_k10 = np.concatenate((normal_test_data_resnet50_k10, anomaly_test_data_resnet50_k10), axis=0)
test_labels_resnet50_k10 = np.concatenate((np.zeros(len(normal_test_data_resnet50_k10)), np.ones(len(anomaly_test_data_resnet50_k10))))

# -----------  Traindata K20  -------------

normal_data_resnet50_k20 = np.array(X_undamaged_resnet50[:20])
anomaly_data_resnet50_k20 = np.array(X_damaged_resnet50[:40])

train_data_resnet50_k20 = np.concatenate((normal_data_resnet50_k20, anomaly_data_resnet50_k20), axis=0)
train_labels_resnet50_k20 = np.concatenate((np.zeros(len(normal_data_resnet50_k20)), np.ones(len(anomaly_data_resnet50_k20))))

# Validation K20
normal_val_data_resnet50_k20 = np.array(X_undamaged_resnet50[69:73])
anomaly_val_data_resnet50_k20 = np.array(X_damaged_resnet50[40:48])

val_data_resnet50_k20 = np.concatenate((normal_val_data_resnet50_k20, anomaly_val_data_resnet50_k20), axis=0)
val_labels_resnet50_k20 = np.concatenate((np.zeros(len(normal_val_data_resnet50_k20)), np.ones(len(anomaly_val_data_resnet50_k20))))

# Test K20
normal_test_data_resnet50_k20 = np.array(X_undamaged_resnet50[73:93])
anomaly_test_data_resnet50_k20 = np.array(X_damaged_resnet50[48:88])

test_data_resnet50_k20 = np.concatenate((normal_test_data_resnet50_k20, anomaly_test_data_resnet50_k20), axis=0)
test_labels_resnet50_k20 = np.concatenate((np.zeros(len(normal_test_data_resnet50_k20)), np.ones(len(anomaly_test_data_resnet50_k20))))

# %% [markdown]
# **InceptionV3**

# %%
# -----------  Traindata K5  -------------

normal_data_inceptionv3_k5 = np.array(X_undamaged_inceptionv3[:5])
anomaly_data_inceptionv3_k5 = np.array(X_damaged_inceptionv3[:10])

train_data_inceptionv3_k5 = np.concatenate((normal_data_inceptionv3_k5, anomaly_data_inceptionv3_k5), axis=0)
train_labels_inceptionv3_k5 = np.concatenate((np.zeros(len(normal_data_inceptionv3_k5)), np.ones(len(anomaly_data_inceptionv3_k5))))

# Validation K5
normal_val_data_inceptionv3_k5 = np.array(X_undamaged_inceptionv3[71:73])
anomaly_val_data_inceptionv3_k5 = np.array(X_damaged_inceptionv3[44:48])

val_data_inceptionv3_k5 = np.concatenate((normal_val_data_inceptionv3_k5, anomaly_val_data_inceptionv3_k5), axis=0)
val_labels_inceptionv3_k5 = np.concatenate((np.zeros(len(normal_val_data_inceptionv3_k5)), np.ones(len(anomaly_val_data_inceptionv3_k5))))

# Test K5
normal_test_data_inceptionv3_k5 = np.array(X_undamaged_inceptionv3[73:93])
anomaly_test_data_inceptionv3_k5 = np.array(X_damaged_inceptionv3[48:88])

test_data_inceptionv3_k5 = np.concatenate((normal_test_data_inceptionv3_k5, anomaly_test_data_inceptionv3_k5), axis=0)
test_labels_inceptionv3_k5 = np.concatenate((np.zeros(len(normal_test_data_inceptionv3_k5)), np.ones(len(anomaly_test_data_inceptionv3_k5))))

# -----------  Traindata K10  -------------

normal_data_inceptionv3_k10 = np.array(X_undamaged_inceptionv3[:10])
anomaly_data_inceptionv3_k10 = np.array(X_damaged_inceptionv3[:20])

train_data_inceptionv3_k10 = np.concatenate((normal_data_inceptionv3_k10, anomaly_data_inceptionv3_k10), axis=0)
train_labels_inceptionv3_k10 = np.concatenate((np.zeros(len(normal_data_inceptionv3_k10)), np.ones(len(anomaly_data_inceptionv3_k10))))

# Validation K10
normal_val_data_inceptionv3_k10 = np.array(X_undamaged_inceptionv3[69:73])
anomaly_val_data_inceptionv3_k10 = np.array(X_damaged_inceptionv3[40:48])

val_data_inceptionv3_k10 = np.concatenate((normal_val_data_inceptionv3_k10, anomaly_val_data_inceptionv3_k10), axis=0)
val_labels_inceptionv3_k10 = np.concatenate((np.zeros(len(normal_val_data_inceptionv3_k10)), np.ones(len(anomaly_val_data_inceptionv3_k10))))

# Test K10
normal_test_data_inceptionv3_k10 = np.array(X_undamaged_inceptionv3[73:93])
anomaly_test_data_inceptionv3_k10 = np.array(X_damaged_inceptionv3[48:88])

test_data_inceptionv3_k10 = np.concatenate((normal_test_data_inceptionv3_k10, anomaly_test_data_inceptionv3_k10), axis=0)
test_labels_inceptionv3_k10 = np.concatenate((np.zeros(len(normal_test_data_inceptionv3_k10)), np.ones(len(anomaly_test_data_inceptionv3_k10))))

# -----------  Traindata K20  -------------

normal_data_inceptionv3_k20 = np.array(X_undamaged_inceptionv3[:20])
anomaly_data_inceptionv3_k20 = np.array(X_damaged_inceptionv3[:40])

train_data_inceptionv3_k20 = np.concatenate((normal_data_inceptionv3_k20, anomaly_data_inceptionv3_k20), axis=0)
train_labels_inceptionv3_k20 = np.concatenate((np.zeros(len(normal_data_inceptionv3_k20)), np.ones(len(anomaly_data_inceptionv3_k20))))

# Validation K20
normal_val_data_inceptionv3_k20 = np.array(X_undamaged_inceptionv3[69:73])
anomaly_val_data_inceptionv3_k20 = np.array(X_damaged_inceptionv3[40:48])

val_data_inceptionv3_k20 = np.concatenate((normal_val_data_inceptionv3_k20, anomaly_val_data_inceptionv3_k20), axis=0)
val_labels_inceptionv3_k20 = np.concatenate((np.zeros(len(normal_val_data_inceptionv3_k20)), np.ones(len(anomaly_val_data_inceptionv3_k20))))

# Test K20
normal_test_data_inceptionv3_k20 = np.array(X_undamaged_inceptionv3[73:93])
anomaly_test_data_inceptionv3_k20 = np.array(X_damaged_inceptionv3[48:88])

test_data_inceptionv3_k20 = np.concatenate((normal_test_data_inceptionv3_k20, anomaly_test_data_inceptionv3_k20), axis=0)
test_labels_inceptionv3_k20 = np.concatenate((np.zeros(len(normal_test_data_inceptionv3_k20)), np.ones(len(anomaly_test_data_inceptionv3_k20))))

# %% [markdown]
# **Xception**

# %%
# Traindata K5
normal_data_xception_k5 = np.array(X_undamaged_xception[:5])
anomaly_data_xception_k5 = np.array(X_damaged_xception[:10])

train_data_xception_k5 = np.concatenate((normal_data_xception_k5, anomaly_data_xception_k5), axis=0)
train_labels_xception_k5 = np.concatenate((np.zeros(len(normal_data_xception_k5)), np.ones(len(anomaly_data_xception_k5))))

# Validation K5
normal_val_data_xception_k5 = np.array(X_undamaged_xception[71:73])
anomaly_val_data_xception_k5 = np.array(X_damaged_xception[44:48])

val_data_xception_k5 = np.concatenate((normal_val_data_xception_k5, anomaly_val_data_xception_k5), axis=0)
val_labels_xception_k5 = np.concatenate((np.zeros(len(normal_val_data_xception_k5)), np.ones(len(anomaly_val_data_xception_k5))))

# Test K5
normal_test_data_xception_k5 = np.array(X_undamaged_xception[73:93])
anomaly_test_data_xception_k5 = np.array(X_damaged_xception[48:88])

test_data_xception_k5 = np.concatenate((normal_test_data_xception_k5, anomaly_test_data_xception_k5), axis=0)
test_labels_xception_k5 = np.concatenate((np.zeros(len(normal_test_data_xception_k5)), np.ones(len(anomaly_test_data_xception_k5))))

# Traindata K10
normal_data_xception_k10 = np.array(X_undamaged_xception[:10])
anomaly_data_xception_k10 = np.array(X_damaged_xception[:20])

train_data_xception_k10 = np.concatenate((normal_data_xception_k10, anomaly_data_xception_k10), axis=0)
train_labels_xception_k10 = np.concatenate((np.zeros(len(normal_data_xception_k10)), np.ones(len(anomaly_data_xception_k10))))

# Validation K10
normal_val_data_xception_k10 = np.array(X_undamaged_xception[69:73])
anomaly_val_data_xception_k10 = np.array(X_damaged_xception[40:48])

val_data_xception_k10 = np.concatenate((normal_val_data_xception_k10, anomaly_val_data_xception_k10), axis=0)
val_labels_xception_k10 = np.concatenate((np.zeros(len(normal_val_data_xception_k10)), np.ones(len(anomaly_val_data_xception_k10))))

# Test K10
normal_test_data_xception_k10 = np.array(X_undamaged_xception[73:93])
anomaly_test_data_xception_k10 = np.array(X_damaged_xception[48:88])

test_data_xception_k10 = np.concatenate((normal_test_data_xception_k10, anomaly_test_data_xception_k10), axis=0)
test_labels_xception_k10 = np.concatenate((np.zeros(len(normal_test_data_xception_k10)), np.ones(len(anomaly_test_data_xception_k10))))

# Traindata K20
normal_data_xception_k20 = np.array(X_undamaged_xception[:20])
anomaly_data_xception_k20 = np.array(X_damaged_xception[:40])

train_data_xception_k20 = np.concatenate((normal_data_xception_k20, anomaly_data_xception_k20), axis=0)
train_labels_xception_k20 = np.concatenate((np.zeros(len(normal_data_xception_k20)), np.ones(len(anomaly_data_xception_k20))))

# Validation K20
normal_val_data_xception_k20 = np.array(X_undamaged_xception[69:73])
anomaly_val_data_xception_k20 = np.array(X_damaged_xception[40:48])

val_data_xception_k20 = np.concatenate((normal_val_data_xception_k20, anomaly_val_data_xception_k20), axis=0)
val_labels_xception_k20 = np.concatenate((np.zeros(len(normal_val_data_xception_k20)), np.ones(len(anomaly_val_data_xception_k20))))

# Test K20
normal_test_data_xception_k20 = np.array(X_undamaged_xception[73:93])
anomaly_test_data_xception_k20 = np.array(X_damaged_xception[48:88])

test_data_xception_k20 = np.concatenate((normal_test_data_xception_k20, anomaly_test_data_xception_k20), axis=0)
test_labels_xception_k20 = np.concatenate((np.zeros(len(normal_test_data_xception_k20)), np.ones(len(anomaly_test_data_xception_k20))))

# %% [markdown]
# # Define Metrics

# %%
def balanced_accuracy(y_true, y_pred):
    return balanced_accuracy_score(y_true, y_pred)



def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

from tensorflow.keras.callbacks import Callback

class AUCROCCallback(Callback):
    def __init__(self, validation_data):
        super(AUCROCCallback, self).__init__()
        self.validation_data = validation_data

    def on_epoch_end(self, epoch, logs=None):
        x_val, y_val = self.validation_data
        y_pred = self.model.predict(x_val)
        auc_roc = roc_auc_score(y_val, y_pred)
        logs['val_auc_roc'] = auc_roc

# %% [markdown]
# # Tranfer Learning - Models VGG16, ResNet50, InceptionV3 & Xception

# %%
#Hypperparameter etc.
learning_rate = 0.0001
optimizer = Adam(learning_rate=learning_rate)
opt = SGD(learning_rate=0.0001, momentum=0.9)

num_classes = 1
dropout_rate = 0.1

# %% [markdown]
# **Below we are mporting the weights of imagenet, freezing them and adding a new modified top for case**

# %% [markdown]
# # VGG16

# %%
vgg_base = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3), pooling='max')
vgg_base.trainable = False

# VGG16 -
vgg_model = Sequential([
    vgg_base,
    Flatten(),
    Dense(512, activation='relu'),
    #Dropout(dropout_rate),
    Dense(256, activation='relu'),
    #Dropout(dropout_rate),
    Dense(num_classes, activation='sigmoid')
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %% [markdown]
# # Resnet50

# %%
resnet_base = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3), pooling='max')
resnet_base.trainable = False

# ResNet50
resnet_model = Sequential([
    resnet_base,
    Flatten(),
    Dense(512, activation='relu'),
    #Dropout(dropout_rate),
    Dense(256, activation='relu'),
    #Dropout(dropout_rate),
    Dense(num_classes, activation='sigmoid')
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step

# %% [markdown]
# # InceptionV3

# %%
optimizer_other = Adam(learning_rate=0.0001)
inception_base = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3),  pooling='max')
inception_base.trainable = False

inception_model = Sequential([
    inception_base,
    Flatten(),
    Dense(512, activation='relu'),
    #Dropout(dropout_rate),
    Dense(256, activation='relu'),
    #Dropout(dropout_rate),
    Dense(num_classes, activation='sigmoid')
])



inception_model.compile(loss='binary_crossentropy', optimizer=optimizer_other, metrics=[f1_m, tf.keras.metrics.AUC()])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 1s 0us/step

# %% [markdown]
# # Xception

# %%
optimizer_other = Adam(learning_rate=0.0001)
xception_base = Xception(weights='imagenet', include_top=False, input_shape=(299, 299, 3), pooling='max')
xception_base.trainable = False

xception_model = Sequential([
    xception_base,
    Flatten(),
    Dense(512, activation='relu'),
    #Dropout(dropout_rate),
    Dense(256, activation='relu'),
    #Dropout(dropout_rate),
    Dense(num_classes, activation='sigmoid')
])
xception_model.compile(loss='binary_crossentropy', optimizer=optimizer_other, metrics=[f1_m, tf.keras.metrics.AUC()])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 1s 0us/step

# %% [markdown]
# # Batch, Epochs & Early Stopping

# %%
# Define early stop
patience = 30
early_stopping = EarlyStopping(monitor='val_loss', patience=patience, mode='auto', restore_best_weights=True)


# Params
epochs = 200
batch_size = 16

# %% [markdown]
# # Train/Test Models

# %% [markdown]
# # K5 Train/Test

# %%
models = [vgg_model, resnet_model, inception_model, xception_model]
model_names = ["VGG16", "ResNet50", "InceptionV3", "Xception"]
scoring_models_k5 = []

# Progressbar
progress_bar = tqdm(total=len(models), desc='Models', position=0)
current_datetime = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

for model, model_name in zip(models, model_names):

    if model_name == "VGG16":
      reset_model_vgg16 = clone_model(vgg_model)
      reset_model_vgg16.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=[f1_m, tf.keras.metrics.AUC()])
      ### Training on Data K5
      history_vgg16_k5 = reset_model_vgg16.fit(train_data_vgg16_k5, train_labels_vgg16_k5, validation_data=(val_data_vgg16_k5, val_labels_vgg16_k5),
                          batch_size=batch_size, epochs=epochs, callbacks=[early_stopping, AUCROCCallback(validation_data=(val_data_vgg16_k5, val_labels_vgg16_k5))])


      formating_results_k5 = {}
      formating_results_k5["Model"] = model_name
      formating_results_k5["Loss"] = history_vgg16_k5.history["loss"]
      formating_results_k5["F1-Score"] = history_vgg16_k5.history["f1_m"]
      formating_results_k5["Validation Loss"] = history_vgg16_k5.history["val_loss"]
      formating_results_k5["Validation F1-Score"] = history_vgg16_k5.history["val_f1_m"]
      formating_results_k5["AUC-ROC VAL"] = history_vgg16_k5.history['val_auc_roc']

      loss_evaluation_vgg16, f1_m_evaluation_vgg16, auc_roc_evaluation_vgg16 = reset_model_vgg16.evaluate(test_data_vgg16_k5, test_labels_vgg16_k5, verbose=1)
      formating_results_k5["F1-Score Test"] = f1_m_evaluation_vgg16
      formating_results_k5["Loss Test"] = loss_evaluation_vgg16
      formating_results_k5["AUC-ROC Test"] = auc_roc_evaluation_vgg16

      scoring_models_k5.append(formating_results_k5)

      y_pred = reset_model_vgg16.predict(test_data_vgg16_k5)
      y_pred = np.argmax(y_pred, axis=1)

      cm = confusion_matrix(test_labels_vgg16_k5, y_pred)
      cm_float = cm.astype(float)  # Datentyp auf float ändern

      try:
          cm_filename = "ConfusionMatrix/ConfusionMatrix_k5_" + model_name + "_" + current_datetime + ".csv"
          np.savetxt(cm_filename, cm_float, delimiter=",", fmt='%.4f')  # Datentyp und Format angeben
      except:
          continue

      ### Progressbar updating
      progress_bar.update(1)
      try:
        filename = "Models/Model_k5_" + model_name + "_" + current_datetime + ".h5"
        # Modell speichern
        reset_model_vgg16.save(filename)
      except:
        continue




    if model_name == "ResNet50":
      reset_model_resnet50 = clone_model(resnet_model)
      reset_model_resnet50.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=[f1_m, tf.keras.metrics.AUC()])
      ### Training on K5
      history_resnet50_k5 = reset_model_resnet50.fit(train_data_resnet50_k5, train_labels_resnet50_k5, validation_data=(val_data_resnet50_k5, val_labels_resnet50_k5),
                          batch_size=batch_size, epochs=epochs, callbacks=[early_stopping, AUCROCCallback(validation_data=(val_data_resnet50_k5, val_labels_resnet50_k5))])

      formating_results_k5 = {}
      formating_results_k5["Model"] = model_name
      formating_results_k5["Loss"] = history_resnet50_k5.history["loss"]
      formating_results_k5["F1-Score"] = history_resnet50_k5.history["f1_m"]
      formating_results_k5["Validation Loss"] = history_resnet50_k5.history["val_loss"]
      formating_results_k5["Validation F1-Score"] = history_resnet50_k5.history["val_f1_m"]
      formating_results_k5["AUC-ROC VAL"] = history_resnet50_k5.history['val_auc_roc']

      loss_evaluation_resnet50, f1_m_evaluation_resnet50, auc_roc_evaluation_resnet50 = reset_model_resnet50.evaluate(test_data_resnet50_k5, test_labels_resnet50_k5, verbose=1)
      formating_results_k5["F1-Score Test"] = f1_m_evaluation_resnet50
      formating_results_k5["Loss Test"] = loss_evaluation_resnet50
      formating_results_k5["AUC-ROC Test"] = auc_roc_evaluation_resnet50


      scoring_models_k5.append(formating_results_k5)

      y_pred = reset_model_resnet50.predict(test_data_resnet50_k5)
      y_pred = np.argmax(y_pred, axis=1)

      cm = confusion_matrix(test_labels_resnet50_k5, y_pred)
      cm_float = cm.astype(float)

      try:
          cm_filename = "ConfusionMatrix/ConfusionMatrix_k5_" + model_name + "_" + current_datetime + ".csv"
          np.savetxt(cm_filename, cm_float, delimiter=",", fmt='%.4f')
      except:
          continue

      progress_bar.update(1)

      try:
        filename = "Models/Model_k5_" + model_name + "_" + current_datetime + ".h5"
        # Modell speichern
        reset_model_resnet50.save(filename)
      except:
        continue



    if model_name == "InceptionV3":
      reset_model_inceptionv3 = clone_model(inception_model)
      reset_model_inceptionv3.compile(loss='binary_crossentropy', optimizer=optimizer_other, metrics=[f1_m, tf.keras.metrics.AUC()])
      ###Training on K5
      history_inceptionv3_k5 = reset_model_inceptionv3.fit(train_data_inceptionv3_k5, train_labels_inceptionv3_k5,
                                validation_data=(val_data_inceptionv3_k5, val_labels_inceptionv3_k5),
                          batch_size=batch_size, epochs=epochs, callbacks=[early_stopping, AUCROCCallback(validation_data=(val_data_inceptionv3_k5, val_labels_inceptionv3_k5))])

      formating_results_k5 = {}
      formating_results_k5["Model"] = model_name
      formating_results_k5["Loss"] = history_inceptionv3_k5.history["loss"]
      formating_results_k5["F1-Score"] = history_inceptionv3_k5.history["f1_m"]
      formating_results_k5["Validation Loss"] = history_inceptionv3_k5.history["val_loss"]
      formating_results_k5["Validation F1-Score"] = history_inceptionv3_k5.history["val_f1_m"]
      formating_results_k5["AUC-ROC VAL"] = history_inceptionv3_k5.history['val_auc_roc']

      loss_evaluation_inceptionv3, f1_m_evaluation_inceptionv3, auc_roc_evaluation_inceptionv3 = reset_model_inceptionv3.evaluate(test_data_inceptionv3_k5, test_labels_inceptionv3_k5, verbose=1)
      formating_results_k5["F1-Score Test"] = f1_m_evaluation_inceptionv3
      formating_results_k5["Loss Test"] = loss_evaluation_inceptionv3
      formating_results_k5["AUC-ROC Test"] = auc_roc_evaluation_inceptionv3

      scoring_models_k5.append(formating_results_k5)

      y_pred = reset_model_inceptionv3.predict(test_data_inceptionv3_k5)
      y_pred = np.argmax(y_pred, axis=1)

      cm = confusion_matrix(test_labels_inceptionv3_k5, y_pred)
      cm_float = cm.astype(float)

      try:
          cm_filename = "ConfusionMatrix/ConfusionMatrix_k5_" + model_name + "_" + current_datetime + ".csv"
          np.savetxt(cm_filename, cm_float, delimiter=",", fmt='%.4f')
      except:
          continue

      progress_bar.update(1)

      try:
        filename = "Models/Model_k5_" + model_name + "_" + current_datetime + ".h5"
        # Modell speichern
        reset_model_inceptionv3.save(filename)
      except:
        continue


    if model_name == "Xception":
      reset_model_xception = clone_model(model)
      reset_model_xception.compile(loss='binary_crossentropy', optimizer=optimizer_other, metrics=[f1_m, tf.keras.metrics.AUC()])

      ### Training on K5
      history_xception_k5 = reset_model_xception.fit(train_data_xception_k5, train_labels_xception_k5,
                                validation_data=(val_data_xception_k5, val_labels_xception_k5),
                          batch_size=batch_size, epochs=epochs, callbacks=[early_stopping, AUCROCCallback(validation_data=(val_data_xception_k5, val_labels_xception_k5))])

      formating_results_k5 = {}
      formating_results_k5["Model"] = model_name
      formating_results_k5["Loss"] = history_xception_k5.history["loss"]
      formating_results_k5["F1-Score"] = history_xception_k5.history["f1_m"]
      formating_results_k5["Validation Loss"] = history_xception_k5.history["val_loss"]
      formating_results_k5["Validation F1-Score"] = history_xception_k5.history["val_f1_m"]
      formating_results_k5["AUC-ROC VAL"] = history_xception_k5.history['val_auc_roc']

      loss_evaluation_xception, f1_m_evaluation_xception, auc_roc_evaluation_xception  = reset_model_xception.evaluate(test_data_xception_k5, test_labels_xception_k5, verbose=1)
      formating_results_k5["F1-Score Test"] = f1_m_evaluation_xception
      formating_results_k5["Loss Test"] = loss_evaluation_xception
      formating_results_k5["AUC-ROC Test"] = auc_roc_evaluation_xception

      scoring_models_k5.append(formating_results_k5)


      y_pred = reset_model_xception.predict(test_data_xception_k5)
      y_pred = np.argmax(y_pred, axis=1)

      cm = confusion_matrix(test_labels_xception_k5, y_pred)
      cm_float = cm.astype(float)

      try:
          cm_filename = "ConfusionMatrix/ConfusionMatrix_k5_" + model_name + "_" + current_datetime + ".csv"
          np.savetxt(cm_filename, cm_float, delimiter=",", fmt='%.4f')
      except:
          continue

      progress_bar.update(1)

      try:
        filename = "Models/Model_k5_" + model_name + "_" + current_datetime + ".h5"
        reset_model_xception.save(filename)
      except:
        continue


# Progressbar close
progress_bar.close()

# Dataframe with scorings
df_k5 = pd.DataFrame(scoring_models_k5)
df_k5.to_csv("model_metrics_k5_balanced" + current_datetime, index=False)
# Out:
# Models:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 1/200
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 12s 12s/step - loss: 0.7844 - f1_m: 0.0000e+00 - auc_2: 1.0000 - val_loss: 0.7040 - val_f1_m: 0.0000e+00 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 2/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 254ms/step - loss: 0.7037 - f1_m: 0.0000e+00 - auc_2: 1.0000 - val_loss: 0.6541 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 3/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 241ms/step - loss: 0.6539 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6300 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 4/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 323ms/step - loss: 0.6293 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6229 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 5/200
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 276ms/step - loss: 0.6221 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6257 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 6/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 271ms/step - loss: 0.6247 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6340 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 7/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 197ms/step - loss: 0.6330 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6404 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 8/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 233ms/step - loss: 0.6394 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6425 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 9/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 200ms/step - loss: 0.6415 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6404 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 10/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 197ms/step - loss: 0.6391 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6352 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 11/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 261ms/step - loss: 0.6337 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6286 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 12/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 243ms/step - loss: 0.6271 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6220 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 13/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 237ms/step - loss: 0.6205 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6165 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 14/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 242ms/step - loss: 0.6151 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6130 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 15/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 276ms/step - loss: 0.6117 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6118 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 16/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 222ms/step - loss: 0.6106 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6123 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 17/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 200ms/step - loss: 0.6112 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6135 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 18/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 263ms/step - loss: 0.6125 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6144 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 19/200
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 283ms/step - loss: 0.6132 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6144 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 20/200
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 307ms/step - loss: 0.6133 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6134 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 21/200
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 331ms/step - loss: 0.6121 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6113 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 22/200
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 339ms/step - loss: 0.6099 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6086 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 23/200
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 356ms/step - loss: 0.6072 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6059 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 24/200
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 332ms/step - loss: 0.6045 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6038 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 25/200
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 336ms/step - loss: 0.6022 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6024 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 26/200
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 308ms/step - loss: 0.6007 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6016 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 27/200
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 341ms/step - loss: 0.5999 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6012 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 28/200
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 321ms/step - loss: 0.5993 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6008 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 29/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 291ms/step - loss: 0.5989 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6002 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 30/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 233ms/step - loss: 0.5983 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5993 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 31/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 231ms/step - loss: 0.5973 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5979 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 32/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 308ms/step - loss: 0.5959 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5962 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 33/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 301ms/step - loss: 0.5942 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5945 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 34/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 271ms/step - loss: 0.5924 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5928 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 35/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 239ms/step - loss: 0.5907 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5914 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 36/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 244ms/step - loss: 0.5892 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5902 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 37/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 301ms/step - loss: 0.5880 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5892 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 38/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 261ms/step - loss: 0.5870 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5883 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 266ms/step - loss: 0.5859 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5872 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 40/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 262ms/step - loss: 0.5848 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5859 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 41/200
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 284ms/step - loss: 0.5835 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5845 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 42/200
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 274ms/step - loss: 0.5820 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5830 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 43/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 302ms/step - loss: 0.5804 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5814 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 44/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 296ms/step - loss: 0.5788 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5799 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 45/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 265ms/step - loss: 0.5772 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5785 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 46/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 274ms/step - loss: 0.5757 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5771 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 47/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 261ms/step - loss: 0.5743 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5758 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 48/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 268ms/step - loss: 0.5730 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5745 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 305ms/step - loss: 0.5716 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5730 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 50/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 275ms/step - loss: 0.5700 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5715 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 51/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 235ms/step - loss: 0.5684 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5699 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 52/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 233ms/step - loss: 0.5667 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5682 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 53/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 311ms/step - loss: 0.5650 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5666 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 54/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 235ms/step - loss: 0.5633 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5650 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 55/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 237ms/step - loss: 0.5617 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5635 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 56/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 295ms/step - loss: 0.5600 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5619 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 296ms/step - loss: 0.5584 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5603 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 58/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 284ms/step - loss: 0.5567 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5586 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 59/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 280ms/step - loss: 0.5549 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5568 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 60/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 251ms/step - loss: 0.5531 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5550 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 61/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 233ms/step - loss: 0.5512 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5532 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 62/200
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 241ms/step - loss: 0.5493 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5514 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 236ms/step - loss: 0.5474 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5496 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 64/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 238ms/step - loss: 0.5455 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5477 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 307ms/step - loss: 0.5436 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5459 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 310ms/step - loss: 0.5417 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5439 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 67/200
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 283ms/step - loss: 0.5397 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5420 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 283ms/step - loss: 0.5376 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5400 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 350ms/step - loss: 0.5355 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5380 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 281ms/step - loss: 0.5334 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5359 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 299ms/step - loss: 0.5313 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5339 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 346ms/step - loss: 0.5291 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5318 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 302ms/step - loss: 0.5270 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5297 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 280ms/step - loss: 0.5247 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5275 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 331ms/step - loss: 0.5225 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5253 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 290ms/step - loss: 0.5202 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5230 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 1s 545ms/step - loss: 0.5178 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5207 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 264ms/step - loss: 0.5155 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5184 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 281ms/step - loss: 0.5131 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5161 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 244ms/step - loss: 0.5106 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5137 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 279ms/step - loss: 0.5081 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5113 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 241ms/step - loss: 0.5056 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5088 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 247ms/step - loss: 0.5031 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5063 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 273ms/step - loss: 0.5005 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5038 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 311ms/step - loss: 0.4979 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5013 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 288ms/step - loss: 0.4952 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.4987 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 307ms/step - loss: 0.4925 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.4960 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 235ms/step - loss: 0.4898 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.4933 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 282ms/step - loss: 0.4870 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.4906 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 272ms/step - loss: 0.4842 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.4879 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 240ms/step - loss: 0.4813 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.4851 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 271ms/step - loss: 0.4784 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.4822 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 281ms/step - loss: 0.4755 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.4794 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 246ms/step - loss: 0.4725 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.4765 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 306ms/step - loss: 0.4695 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.4735 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 246ms/step - loss: 0.4664 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.4705 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 265ms/step - loss: 0.4633 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.4675 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 275ms/step - loss: 0.4602 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.4644 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 262ms/step - loss: 0.4570 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.4613 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 275ms/step - loss: 0.4538 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.4582 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 271ms/step - loss: 0.4505 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.4550 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 276ms/step - loss: 0.4472 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.4518 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 301ms/step - loss: 0.4439 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.4485 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 104/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 242ms/step - loss: 0.4405 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.4452 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 271ms/step - loss: 0.4371 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.4418 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 273ms/step - loss: 0.4336 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.4385 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 272ms/step - loss: 0.4302 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.4351 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 231ms/step - loss: 0.4266 - f1_m: 0.8696 - auc_2: 1.0000 - val_loss: 0.4316 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 295ms/step - loss: 0.4231 - f1_m: 0.8696 - auc_2: 1.0000 - val_loss: 0.4281 - val_f1_m: 0.8889 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 247ms/step - loss: 0.4195 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4246 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 263ms/step - loss: 0.4158 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4211 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 349ms/step - loss: 0.4122 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4175 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 113/200
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 348ms/step - loss: 0.4085 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4138 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 356ms/step - loss: 0.4047 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4102 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 275ms/step - loss: 0.4009 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4065 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 276ms/step - loss: 0.3971 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4028 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 339ms/step - loss: 0.3933 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3991 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 352ms/step - loss: 0.3894 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3953 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 288ms/step - loss: 0.3855 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3914 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 353ms/step - loss: 0.3816 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3876 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 303ms/step - loss: 0.3777 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3837 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 261ms/step - loss: 0.3737 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3798 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 271ms/step - loss: 0.3697 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3758 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 243ms/step - loss: 0.3657 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3719 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 271ms/step - loss: 0.3616 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3679 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 259ms/step - loss: 0.3575 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3639 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 301ms/step - loss: 0.3535 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3599 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 318ms/step - loss: 0.3494 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3559 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 248ms/step - loss: 0.3452 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3518 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 246ms/step - loss: 0.3411 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3477 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 274ms/step - loss: 0.3369 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3437 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 233ms/step - loss: 0.3328 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3396 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 269ms/step - loss: 0.3286 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3355 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 271ms/step - loss: 0.3244 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3314 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 234ms/step - loss: 0.3202 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3273 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 235ms/step - loss: 0.3160 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3231 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 302ms/step - loss: 0.3118 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3190 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 262ms/step - loss: 0.3076 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3148 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 241ms/step - loss: 0.3034 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3107 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 234ms/step - loss: 0.2992 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3066 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 271ms/step - loss: 0.2950 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3025 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 239ms/step - loss: 0.2908 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2984 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 263ms/step - loss: 0.2866 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2942 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 301ms/step - loss: 0.2825 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2901 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 273ms/step - loss: 0.2783 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2860 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 272ms/step - loss: 0.2742 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2819 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 246ms/step - loss: 0.2700 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2779 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 240ms/step - loss: 0.2659 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2738 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 273ms/step - loss: 0.2618 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2698 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 259ms/step - loss: 0.2577 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2657 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 264ms/step - loss: 0.2537 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2617 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 305ms/step - loss: 0.2496 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2577 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 295ms/step - loss: 0.2456 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2538 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 245ms/step - loss: 0.2416 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2498 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 294ms/step - loss: 0.2377 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2459 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 233ms/step - loss: 0.2337 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2420 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 241ms/step - loss: 0.2298 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2381 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 299ms/step - loss: 0.2260 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2343 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 268ms/step - loss: 0.2221 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2305 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 315ms/step - loss: 0.2183 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2269 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 325ms/step - loss: 0.2146 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2232 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 327ms/step - loss: 0.2109 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2194 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 331ms/step - loss: 0.2072 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2157 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 292ms/step - loss: 0.2035 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2120 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 345ms/step - loss: 0.1999 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2085 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 336ms/step - loss: 0.1963 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2050 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 336ms/step - loss: 0.1928 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2015 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 310ms/step - loss: 0.1893 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1980 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 274ms/step - loss: 0.1859 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1945 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 270ms/step - loss: 0.1825 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1911 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 265ms/step - loss: 0.1791 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1877 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 247ms/step - loss: 0.1758 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1845 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 302ms/step - loss: 0.1726 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1812 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 304ms/step - loss: 0.1694 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1780 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 310ms/step - loss: 0.1662 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1749 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 274ms/step - loss: 0.1631 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1717 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 266ms/step - loss: 0.1600 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1687 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 304ms/step - loss: 0.1570 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1657 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 272ms/step - loss: 0.1541 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1627 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 235ms/step - loss: 0.1511 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1598 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 271ms/step - loss: 0.1483 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1569 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 279ms/step - loss: 0.1455 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1540 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 236ms/step - loss: 0.1427 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1513 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 237ms/step - loss: 0.1400 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1486 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 237ms/step - loss: 0.1373 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1459 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 306ms/step - loss: 0.1347 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1432 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 298ms/step - loss: 0.1321 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1406 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 271ms/step - loss: 0.1296 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1381 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 242ms/step - loss: 0.1271 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1356 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 244ms/step - loss: 0.1247 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1331 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 252ms/step - loss: 0.1223 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1307 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 241ms/step - loss: 0.1199 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1284 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 283ms/step - loss: 0.1176 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1259 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 293ms/step - loss: 0.1154 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1237 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 275ms/step - loss: 0.1132 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1215 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 241ms/step - loss: 0.1110 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1193 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 197/200
# ...
# Epoch 137/200
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 420ms/step - loss: 0.1178 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.1283 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 411ms/step - loss: 0.1149 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.1254 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 425ms/step - loss: 0.1120 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.1224 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 447ms/step - loss: 0.1093 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.1196 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 395ms/step - loss: 0.1066 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.1169 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 398ms/step - loss: 0.1040 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.1142 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 397ms/step - loss: 0.1015 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.1116 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 377ms/step - loss: 0.0990 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.1091 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 440ms/step - loss: 0.0966 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.1066 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 474ms/step - loss: 0.0943 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.1043 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 462ms/step - loss: 0.0921 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.1020 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 496ms/step - loss: 0.0899 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0997 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 1s 513ms/step - loss: 0.0878 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0975 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 499ms/step - loss: 0.0857 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0954 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 1s 507ms/step - loss: 0.0837 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0933 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 498ms/step - loss: 0.0818 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0912 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 441ms/step - loss: 0.0798 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0892 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 398ms/step - loss: 0.0780 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0873 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 434ms/step - loss: 0.0762 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0854 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 430ms/step - loss: 0.0744 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0835 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 401ms/step - loss: 0.0727 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0817 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 428ms/step - loss: 0.0711 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0800 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 398ms/step - loss: 0.0695 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0784 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 430ms/step - loss: 0.0680 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0768 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 399ms/step - loss: 0.0665 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0753 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 402ms/step - loss: 0.0651 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0738 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 406ms/step - loss: 0.0637 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0723 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 418ms/step - loss: 0.0623 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0708 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 429ms/step - loss: 0.0610 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0694 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 418ms/step - loss: 0.0597 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0680 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 399ms/step - loss: 0.0584 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0667 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 414ms/step - loss: 0.0572 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0654 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 407ms/step - loss: 0.0560 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0642 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 436ms/step - loss: 0.0549 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0630 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 426ms/step - loss: 0.0538 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0618 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 417ms/step - loss: 0.0528 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0607 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 394ms/step - loss: 0.0517 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0596 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 409ms/step - loss: 0.0507 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0585 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 393ms/step - loss: 0.0497 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0574 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 432ms/step - loss: 0.0488 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0564 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 485ms/step - loss: 0.0479 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0554 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 1s 503ms/step - loss: 0.0470 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0545 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 472ms/step - loss: 0.0461 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0535 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 457ms/step - loss: 0.0453 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0526 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 1s 505ms/step - loss: 0.0444 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0517 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 1s 534ms/step - loss: 0.0436 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0508 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 500ms/step - loss: 0.0428 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0500 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 448ms/step - loss: 0.0421 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0492 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 417ms/step - loss: 0.0413 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0483 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 445ms/step - loss: 0.0406 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0475 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 422ms/step - loss: 0.0399 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0468 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 399ms/step - loss: 0.0392 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0460 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 395ms/step - loss: 0.0386 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0453 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 400ms/step - loss: 0.0379 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0446 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 411ms/step - loss: 0.0373 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0439 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 419ms/step - loss: 0.0367 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0432 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 426ms/step - loss: 0.0361 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0426 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 382ms/step - loss: 0.0355 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0419 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 389ms/step - loss: 0.0349 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0413 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 406ms/step - loss: 0.0344 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0407 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 422ms/step - loss: 0.0338 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0401 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 408ms/step - loss: 0.0333 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0395 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 424ms/step - loss: 0.0328 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0389 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 409ms/step - loss: 0.0323 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0383 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# 2/2 [==============================] - 5s 2s/step - loss: 0.1593 - f1_m: 0.9615 - auc_5: 0.9525
# 2/2 [==============================] - 0s 215ms/step
# Models: 100%|██████████| 4/4 [06:36<00:00, 99.17s/it]

# %% [markdown]
# # K10 Train/Test

# %%
# Define early stop
patience = 30
early_stopping = EarlyStopping(monitor='val_loss', patience=patience, mode='auto', restore_best_weights=True)


# Params
epochs = 200
batch_size = 16

# %%
from sklearn.metrics import make_scorer, f1_score
from sklearn.metrics import roc_auc_score
from tqdm import tqdm
import pandas as pd

models = [vgg_model, resnet_model, inception_model, xception_model]
model_names = ["VGG16", "ResNet50", "InceptionV3", "Xception"]
scoring_models_k10 = []
current_datetime = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# Progressbar
progress_bar = tqdm(total=len(models), desc='Models', position=0)


for model, model_name in zip(models, model_names):

    if model_name == "VGG16":
      reset_model_vgg16 = clone_model(vgg_model)
      reset_model_vgg16.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=[f1_m, tf.keras.metrics.AUC()])
      ### Training on Data K10
      history_vgg16_k10 = reset_model_vgg16.fit(train_data_vgg16_k10, train_labels_vgg16_k10, validation_data=(val_data_vgg16_k10, val_labels_vgg16_k10),
                          batch_size=batch_size, epochs=epochs, callbacks=[early_stopping, AUCROCCallback(validation_data=(val_data_vgg16_k10, val_labels_vgg16_k10))])


      formating_results_k10 = {}
      formating_results_k10["Model"] = model_name
      formating_results_k10["Loss"] = history_vgg16_k10.history["loss"]
      formating_results_k10["F1-Score"] = history_vgg16_k10.history["f1_m"]
      formating_results_k10["Validation Loss"] = history_vgg16_k10.history["val_loss"]
      formating_results_k10["Validation F1-Score"] = history_vgg16_k10.history["val_f1_m"]
      formating_results_k10["AUC-ROC VAL"] = history_vgg16_k10.history['val_auc_roc']

      loss_evaluation_vgg16, f1_m_evaluation_vgg16, auc_roc_evaluation_vgg16 = reset_model_vgg16.evaluate(test_data_vgg16_k10, test_labels_vgg16_k10, verbose=1)
      formating_results_k10["F1-Score Test"] = f1_m_evaluation_vgg16
      formating_results_k10["Loss Test"] = loss_evaluation_vgg16
      formating_results_k10["AUC-ROC Test"] = auc_roc_evaluation_vgg16

      scoring_models_k10.append(formating_results_k10)

      y_pred = reset_model_vgg16.predict(test_data_vgg16_k10)
      y_pred = np.argmax(y_pred, axis=1)

      cm = confusion_matrix(test_labels_vgg16_k10, y_pred)
      cm_float = cm.astype(float)

      try:
          cm_filename = "ConfusionMatrix/ConfusionMatrix_k10_" + model_name + "_" + current_datetime + ".csv"
          np.savetxt(cm_filename, cm_float, delimiter=",", fmt='%.4f')
      except:
          continue

      progress_bar.update(1)

      try:
        filename = "Models/Model_k10_" + model_name + "_" + current_datetime + ".h5"
        reset_model_vgg16.save(filename)
      except:
        continue

    if model_name == "ResNet50":
      reset_model_resnet50 = clone_model(resnet_model)
      reset_model_resnet50.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=[f1_m, tf.keras.metrics.AUC()])
      ### Training on K10
      history_resnet50_k10 = reset_model_resnet50.fit(train_data_resnet50_k10, train_labels_resnet50_k10, validation_data=(val_data_resnet50_k10, val_labels_resnet50_k10),
                          batch_size=batch_size, epochs=epochs, callbacks=[early_stopping, AUCROCCallback(validation_data=(val_data_resnet50_k10, val_labels_resnet50_k10))])

      formating_results_k10 = {}
      formating_results_k10["Model"] = model_name
      formating_results_k10["Loss"] = history_resnet50_k10.history["loss"]
      formating_results_k10["F1-Score"] = history_resnet50_k10.history["f1_m"]
      formating_results_k10["Validation Loss"] = history_resnet50_k10.history["val_loss"]
      formating_results_k10["Validation F1-Score"] = history_resnet50_k10.history["val_f1_m"]
      formating_results_k10["AUC-ROC VAL"] = history_resnet50_k10.history['val_auc_roc']

      loss_evaluation_resnet50, f1_m_evaluation_resnet50, auc_roc_evaluation_resnet50 = reset_model_resnet50.evaluate(test_data_resnet50_k10, test_labels_resnet50_k10, verbose=1)
      formating_results_k10["F1-Score Test"] = f1_m_evaluation_resnet50
      formating_results_k10["Loss Test"] = loss_evaluation_resnet50
      formating_results_k10["AUC-ROC Test"] = auc_roc_evaluation_resnet50

      scoring_models_k10.append(formating_results_k10)
      filename = "models/" + model_name + "_" + current_datetime + ".h5"

      y_pred = reset_model_resnet50.predict(test_data_resnet50_k10)
      y_pred = np.argmax(y_pred, axis=1)

      cm = confusion_matrix(test_labels_resnet50_k10, y_pred)
      cm_float = cm.astype(float)

      try:
          cm_filename = "ConfusionMatrix/ConfusionMatrix_k10_" + model_name + "_" + current_datetime + ".csv"
          np.savetxt(cm_filename, cm_float, delimiter=",", fmt='%.4f')
      except:
          continue

      progress_bar.update(1)

      try:
        filename = "Models/Model_k10_" + model_name + "_" + current_datetime + ".h5"
        reset_model_resnet50.save(filename)
      except:
        continue

    if model_name == "InceptionV3":
      reset_model_inceptionv3 = clone_model(inception_model)
      reset_model_inceptionv3.compile(loss='binary_crossentropy', optimizer=optimizer_other, metrics=[f1_m, tf.keras.metrics.AUC()])

      ###Training on K10
      history_inceptionv3_k10 = reset_model_inceptionv3.fit(train_data_inceptionv3_k10, train_labels_inceptionv3_k10,
                                validation_data=(val_data_inceptionv3_k10, val_labels_inceptionv3_k10),
                          batch_size=batch_size, epochs=epochs, callbacks=[early_stopping, AUCROCCallback(validation_data=(val_data_inceptionv3_k10, val_labels_inceptionv3_k10))])

      formating_results_k10 = {}
      formating_results_k10["Model"] = model_name
      formating_results_k10["Loss"] = history_inceptionv3_k10.history["loss"]
      formating_results_k10["F1-Score"] = history_inceptionv3_k10.history["f1_m"]
      formating_results_k10["Validation Loss"] = history_inceptionv3_k10.history["val_loss"]
      formating_results_k10["Validation F1-Score"] = history_inceptionv3_k10.history["val_f1_m"]
      formating_results_k10["AUC-ROC VAL"] = history_inceptionv3_k10.history['val_auc_roc']

      loss_evaluation_inceptionv3, f1_m_evaluation_inceptionv3, auc_roc_evaluation_inceptionv3 = reset_model_inceptionv3.evaluate(test_data_inceptionv3_k10, test_labels_inceptionv3_k10, verbose=1)
      formating_results_k10["F1-Score Test"] = f1_m_evaluation_inceptionv3
      formating_results_k10["Loss Test"] = loss_evaluation_inceptionv3
      formating_results_k10["AUC-ROC Test"] = auc_roc_evaluation_inceptionv3

      scoring_models_k10.append(formating_results_k10)

      y_pred = reset_model_inceptionv3.predict(test_data_inceptionv3_k10)
      y_pred = np.argmax(y_pred, axis=1)

      cm = confusion_matrix(test_labels_inceptionv3_k10, y_pred)
      cm_float = cm.astype(float)

      try:
          cm_filename = "ConfusionMatrix/ConfusionMatrix_k10_" + model_name + "_" + current_datetime + ".csv"
          np.savetxt(cm_filename, cm_float, delimiter=",", fmt='%.4f')
      except:
          continue

      progress_bar.update(1)

      try:
        filename = "Models/Model_k10_" + model_name + "_" + current_datetime + ".h5"
        reset_model_inceptionv3.save(filename)
      except:
        continue



    if model_name == "Xception":
      reset_model_xception = clone_model(xception_model)
      reset_model_xception.compile(loss='binary_crossentropy', optimizer=optimizer_other, metrics=[f1_m, tf.keras.metrics.AUC()])
      ### Training on K10
      history_xception_k10 = reset_model_xception.fit(train_data_xception_k10, train_labels_xception_k10,
                                validation_data=(val_data_xception_k10, val_labels_xception_k10),
                          batch_size=batch_size, epochs=epochs, callbacks=[early_stopping, AUCROCCallback(validation_data=(val_data_xception_k10, val_labels_xception_k10))])

      formating_results_k10 = {}
      formating_results_k10["Model"] = model_name
      formating_results_k10["Loss"] = history_xception_k10.history["loss"]
      formating_results_k10["F1-Score"] = history_xception_k10.history["f1_m"]
      formating_results_k10["Validation Loss"] = history_xception_k10.history["val_loss"]
      formating_results_k10["Validation F1-Score"] = history_xception_k10.history["val_f1_m"]
      formating_results_k10["AUC-ROC VAL"] = history_xception_k10.history['val_auc_roc']

      loss_evaluation_xception, f1_m_evaluation_xception, auc_roc_evaluation_xception  = reset_model_xception.evaluate(test_data_xception_k10, test_labels_xception_k10, verbose=1)
      formating_results_k10["F1-Score Test"] = f1_m_evaluation_xception
      formating_results_k10["Loss Test"] = loss_evaluation_xception
      formating_results_k10["AUC-ROC Test"] = auc_roc_evaluation_xception

      scoring_models_k10.append(formating_results_k10)

      y_pred = reset_model_xception.predict(test_data_xception_k10)
      y_pred = np.argmax(y_pred, axis=1)

      cm = confusion_matrix(test_labels_xception_k10, y_pred)
      cm_float = cm.astype(float)

      try:
          cm_filename = "ConfusionMatrix/ConfusionMatrix_k10_" + model_name + "_" + current_datetime + ".csv"
          np.savetxt(cm_filename, cm_float, delimiter=",", fmt='%.4f')
      except:
          continue

      progress_bar.update(1)

      try:
        filename = "Models/Model_k10_" + model_name + "_" + current_datetime + ".h5"
        reset_model_xception.save(filename)
      except:
        continue
      progress_bar.update(1)

# Progressbar close
progress_bar.close()

# Dataframe
df_k10 = pd.DataFrame(scoring_models_k10)
df_k10.to_csv("model_metrics_k10_balanced" + current_datetime, index=False)
# Out:
# Models:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 1/200
# 1/1 [==============================] - 0s 176ms/step
# 2/2 [==============================] - 17s 6s/step - loss: 0.7603 - f1_m: 0.0000e+00 - auc_2: 0.6400 - val_loss: 0.6571 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 2/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 303ms/step - loss: 0.6345 - f1_m: 0.8000 - auc_2: 0.8650 - val_loss: 0.6217 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 3/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 264ms/step - loss: 0.6122 - f1_m: 0.8000 - auc_2: 0.8650 - val_loss: 0.6239 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 4/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 260ms/step - loss: 0.6415 - f1_m: 0.7816 - auc_2: 0.5450 - val_loss: 0.6387 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 5/200
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 257ms/step - loss: 0.6377 - f1_m: 0.8013 - auc_2: 1.0000 - val_loss: 0.6365 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 6/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 246ms/step - loss: 0.6363 - f1_m: 0.7816 - auc_2: 1.0000 - val_loss: 0.6306 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 7/200
# 1/1 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 311ms/step - loss: 0.6266 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.6193 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 8/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 303ms/step - loss: 0.6187 - f1_m: 0.8013 - auc_2: 0.9500 - val_loss: 0.6120 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 9/200
# 1/1 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 292ms/step - loss: 0.6129 - f1_m: 0.8013 - auc_2: 0.9900 - val_loss: 0.6112 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 10/200
# 1/1 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 271ms/step - loss: 0.6155 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6134 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 11/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 262ms/step - loss: 0.6135 - f1_m: 0.8013 - auc_2: 1.0000 - val_loss: 0.6131 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 12/200
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 309ms/step - loss: 0.6118 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.6096 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 13/200
# 1/1 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 307ms/step - loss: 0.6098 - f1_m: 0.7922 - auc_2: 1.0000 - val_loss: 0.6055 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 14/200
# 1/1 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 333ms/step - loss: 0.6044 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.6030 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 15/200
# 1/1 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 321ms/step - loss: 0.6016 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.6015 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 16/200
# 1/1 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 308ms/step - loss: 0.6007 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.6006 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 17/200
# 1/1 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 350ms/step - loss: 0.5992 - f1_m: 0.8013 - auc_2: 1.0000 - val_loss: 0.5993 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 18/200
# 1/1 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 322ms/step - loss: 0.5994 - f1_m: 0.7922 - auc_2: 1.0000 - val_loss: 0.5981 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 19/200
# 1/1 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 333ms/step - loss: 0.5970 - f1_m: 0.8013 - auc_2: 1.0000 - val_loss: 0.5954 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 20/200
# 1/1 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 363ms/step - loss: 0.5941 - f1_m: 0.7922 - auc_2: 1.0000 - val_loss: 0.5934 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 21/200
# 1/1 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 330ms/step - loss: 0.5916 - f1_m: 0.7922 - auc_2: 1.0000 - val_loss: 0.5913 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 22/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 310ms/step - loss: 0.5895 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.5897 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 23/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 277ms/step - loss: 0.5880 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.5883 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 24/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 305ms/step - loss: 0.5867 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.5866 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 25/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 279ms/step - loss: 0.5858 - f1_m: 0.7922 - auc_2: 1.0000 - val_loss: 0.5842 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 26/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 287ms/step - loss: 0.5835 - f1_m: 0.7922 - auc_2: 1.0000 - val_loss: 0.5818 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 27/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 300ms/step - loss: 0.5801 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.5797 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 28/200
# 1/1 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 289ms/step - loss: 0.5779 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.5776 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 29/200
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 285ms/step - loss: 0.5759 - f1_m: 0.8013 - auc_2: 1.0000 - val_loss: 0.5754 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 30/200
# 1/1 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 277ms/step - loss: 0.5775 - f1_m: 0.7816 - auc_2: 1.0000 - val_loss: 0.5734 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 31/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 299ms/step - loss: 0.5721 - f1_m: 0.7922 - auc_2: 1.0000 - val_loss: 0.5712 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 32/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 278ms/step - loss: 0.5690 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.5689 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 33/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 287ms/step - loss: 0.5666 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.5668 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 34/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 287ms/step - loss: 0.5710 - f1_m: 0.7949 - auc_2: 1.0000 - val_loss: 0.5654 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 35/200
# 1/1 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 297ms/step - loss: 0.5644 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5629 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 36/200
# 1/1 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 273ms/step - loss: 0.5607 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.5598 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 37/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 307ms/step - loss: 0.5578 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5576 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 38/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 305ms/step - loss: 0.5549 - f1_m: 0.8013 - auc_2: 1.0000 - val_loss: 0.5557 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 282ms/step - loss: 0.5538 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.5540 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 40/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 280ms/step - loss: 0.5516 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.5514 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 41/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 296ms/step - loss: 0.5485 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.5481 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 42/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 275ms/step - loss: 0.5450 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.5451 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 43/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 279ms/step - loss: 0.5422 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.5428 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 44/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 300ms/step - loss: 0.5410 - f1_m: 0.8013 - auc_2: 1.0000 - val_loss: 0.5407 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 45/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 275ms/step - loss: 0.5378 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.5375 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 46/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 287ms/step - loss: 0.5362 - f1_m: 0.7922 - auc_2: 1.0000 - val_loss: 0.5341 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 47/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 305ms/step - loss: 0.5313 - f1_m: 0.8013 - auc_2: 1.0000 - val_loss: 0.5312 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 48/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 279ms/step - loss: 0.5282 - f1_m: 0.8013 - auc_2: 1.0000 - val_loss: 0.5282 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 283ms/step - loss: 0.5271 - f1_m: 0.7922 - auc_2: 1.0000 - val_loss: 0.5256 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 50/200
# 1/1 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 329ms/step - loss: 0.5265 - f1_m: 0.7816 - auc_2: 1.0000 - val_loss: 0.5229 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 51/200
# 1/1 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 344ms/step - loss: 0.5205 - f1_m: 0.8013 - auc_2: 1.0000 - val_loss: 0.5191 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 52/200
# 1/1 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 348ms/step - loss: 0.5156 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.5164 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 53/200
# 1/1 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 352ms/step - loss: 0.5128 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.5134 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 54/200
# 1/1 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 340ms/step - loss: 0.5127 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.5106 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 55/200
# 1/1 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 306ms/step - loss: 0.5066 - f1_m: 0.8013 - auc_2: 1.0000 - val_loss: 0.5064 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 56/200
# 1/1 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 348ms/step - loss: 0.5022 - f1_m: 0.8013 - auc_2: 1.0000 - val_loss: 0.5030 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 337ms/step - loss: 0.5000 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.5006 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 58/200
# 1/1 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 317ms/step - loss: 0.4972 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.4972 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 59/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 290ms/step - loss: 0.4930 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.4927 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 60/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 295ms/step - loss: 0.4886 - f1_m: 0.7922 - auc_2: 1.0000 - val_loss: 0.4887 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 61/200
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 280ms/step - loss: 0.4843 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.4858 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 62/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 273ms/step - loss: 0.4831 - f1_m: 0.8013 - auc_2: 1.0000 - val_loss: 0.4833 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 283ms/step - loss: 0.4813 - f1_m: 0.8000 - auc_2: 1.0000 - val_loss: 0.4790 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 64/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 272ms/step - loss: 0.4746 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.4735 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 285ms/step - loss: 0.4701 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.4710 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 307ms/step - loss: 0.4695 - f1_m: 0.7922 - auc_2: 1.0000 - val_loss: 0.4680 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 67/200
# 1/1 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 305ms/step - loss: 0.4628 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.4619 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 283ms/step - loss: 0.4566 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.4578 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 290ms/step - loss: 0.4550 - f1_m: 0.8846 - auc_2: 1.0000 - val_loss: 0.4558 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 292ms/step - loss: 0.4517 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4499 - val_f1_m: 0.8421 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 305ms/step - loss: 0.4468 - f1_m: 0.8252 - auc_2: 1.0000 - val_loss: 0.4448 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 292ms/step - loss: 0.4399 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.4404 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 279ms/step - loss: 0.4358 - f1_m: 0.8013 - auc_2: 1.0000 - val_loss: 0.4359 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 274ms/step - loss: 0.4309 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.4314 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 277ms/step - loss: 0.4262 - f1_m: 0.7987 - auc_2: 1.0000 - val_loss: 0.4268 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 276ms/step - loss: 0.4228 - f1_m: 0.7922 - auc_2: 1.0000 - val_loss: 0.4222 - val_f1_m: 0.8421 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 326ms/step - loss: 0.4179 - f1_m: 0.9545 - auc_2: 1.0000 - val_loss: 0.4180 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 298ms/step - loss: 0.4132 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4135 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 319ms/step - loss: 0.4077 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4080 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 282ms/step - loss: 0.4028 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4035 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 302ms/step - loss: 0.3980 - f1_m: 0.9762 - auc_2: 1.0000 - val_loss: 0.3985 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 292ms/step - loss: 0.3932 - f1_m: 0.9762 - auc_2: 1.0000 - val_loss: 0.3932 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 272ms/step - loss: 0.3889 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3882 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 293ms/step - loss: 0.3828 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3832 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 296ms/step - loss: 0.3831 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3805 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 287ms/step - loss: 0.3757 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3733 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 342ms/step - loss: 0.3695 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3682 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 350ms/step - loss: 0.3626 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3630 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 321ms/step - loss: 0.3584 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3579 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 357ms/step - loss: 0.3514 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3529 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 354ms/step - loss: 0.3472 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3479 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 358ms/step - loss: 0.3449 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3426 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 334ms/step - loss: 0.3359 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3385 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 342ms/step - loss: 0.3354 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3326 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 322ms/step - loss: 0.3258 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3278 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 309ms/step - loss: 0.3210 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3224 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 284ms/step - loss: 0.3159 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3171 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 275ms/step - loss: 0.3154 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3120 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 298ms/step - loss: 0.3093 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3086 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 291ms/step - loss: 0.3042 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3028 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 283ms/step - loss: 0.3015 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2986 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 286ms/step - loss: 0.2920 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2932 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 284ms/step - loss: 0.2866 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2880 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 104/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 274ms/step - loss: 0.2805 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2824 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 310ms/step - loss: 0.2790 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2789 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 296ms/step - loss: 0.2751 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2727 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 281ms/step - loss: 0.2666 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2682 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 305ms/step - loss: 0.2634 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2636 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 288ms/step - loss: 0.2591 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2588 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 298ms/step - loss: 0.2540 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2543 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 302ms/step - loss: 0.2484 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2497 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 306ms/step - loss: 0.2430 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2453 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 113/200
# 1/1 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 286ms/step - loss: 0.2390 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2410 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 278ms/step - loss: 0.2347 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2356 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 292ms/step - loss: 0.2282 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2317 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 299ms/step - loss: 0.2327 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2293 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 277ms/step - loss: 0.2216 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2224 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 291ms/step - loss: 0.2152 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2204 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 287ms/step - loss: 0.2135 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2180 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 297ms/step - loss: 0.2100 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2105 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 279ms/step - loss: 0.2067 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2068 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 272ms/step - loss: 0.2011 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2027 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 337ms/step - loss: 0.1963 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1975 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 329ms/step - loss: 0.1960 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1974 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 322ms/step - loss: 0.1921 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1921 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 327ms/step - loss: 0.1847 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1864 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 327ms/step - loss: 0.1840 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1853 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 344ms/step - loss: 0.1786 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1786 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 330ms/step - loss: 0.1717 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1759 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 303ms/step - loss: 0.1744 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1780 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 345ms/step - loss: 0.1694 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1688 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 1s 583ms/step - loss: 0.1648 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1657 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 298ms/step - loss: 0.1600 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1620 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 295ms/step - loss: 0.1564 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1578 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 301ms/step - loss: 0.1529 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1548 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 280ms/step - loss: 0.1491 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1524 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 293ms/step - loss: 0.1459 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1501 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 304ms/step - loss: 0.1439 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1460 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 304ms/step - loss: 0.1407 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1427 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 300ms/step - loss: 0.1408 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1399 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 292ms/step - loss: 0.1350 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1364 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 278ms/step - loss: 0.1322 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1337 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 252ms/step - loss: 0.1323 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1359 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 322ms/step - loss: 0.1287 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1296 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 297ms/step - loss: 0.1224 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1258 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 297ms/step - loss: 0.1208 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1248 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 311ms/step - loss: 0.1247 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1204 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 291ms/step - loss: 0.1151 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1180 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 304ms/step - loss: 0.1126 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1159 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 295ms/step - loss: 0.1104 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1137 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 307ms/step - loss: 0.1082 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1112 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 290ms/step - loss: 0.1059 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1088 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 269ms/step - loss: 0.1045 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1068 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 277ms/step - loss: 0.1017 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1045 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 307ms/step - loss: 0.1002 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1024 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 271ms/step - loss: 0.0975 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1004 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 300ms/step - loss: 0.0956 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0984 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 280ms/step - loss: 0.0946 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0966 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 291ms/step - loss: 0.0917 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0946 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 332ms/step - loss: 0.0899 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0927 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 333ms/step - loss: 0.0880 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0909 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 332ms/step - loss: 0.0873 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0895 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 323ms/step - loss: 0.0861 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0874 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 327ms/step - loss: 0.0837 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0859 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 345ms/step - loss: 0.0813 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0841 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 349ms/step - loss: 0.0797 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0825 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 352ms/step - loss: 0.0781 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0809 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 300ms/step - loss: 0.0765 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0794 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 295ms/step - loss: 0.0758 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0782 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 295ms/step - loss: 0.0737 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0764 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 291ms/step - loss: 0.0737 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0750 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 274ms/step - loss: 0.0719 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0739 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 297ms/step - loss: 0.0696 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0725 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 279ms/step - loss: 0.0683 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0710 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 296ms/step - loss: 0.0669 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0695 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 278ms/step - loss: 0.0657 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0682 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 282ms/step - loss: 0.0650 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0671 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 301ms/step - loss: 0.0632 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0658 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 301ms/step - loss: 0.0621 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0646 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 306ms/step - loss: 0.0620 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0637 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 289ms/step - loss: 0.0597 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0623 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 282ms/step - loss: 0.0587 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0612 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 316ms/step - loss: 0.0579 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0601 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 298ms/step - loss: 0.0568 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0591 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 307ms/step - loss: 0.0556 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0586 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 297ms/step - loss: 0.0550 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0577 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 295ms/step - loss: 0.0538 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0562 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 297ms/step - loss: 0.0532 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0552 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 289ms/step - loss: 0.0522 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0541 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 274ms/step - loss: 0.0510 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0530 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 295ms/step - loss: 0.0496 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0521 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 304ms/step - loss: 0.0487 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0513 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 285ms/step - loss: 0.0482 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0504 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 280ms/step - loss: 0.0469 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0491 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 304ms/step - loss: 0.0461 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0483 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 330ms/step - loss: 0.0458 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0476 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 197/200
# ...
# Epoch 137/200
# 1/1 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 1s 493ms/step - loss: 0.0440 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0454 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 1s 529ms/step - loss: 0.0431 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0444 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 1s 471ms/step - loss: 0.0422 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0434 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 1s 540ms/step - loss: 0.0415 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0428 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 1s 589ms/step - loss: 0.0406 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0419 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 1s 596ms/step - loss: 0.0398 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0409 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 1s 476ms/step - loss: 0.0396 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0405 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 1s 591ms/step - loss: 0.0384 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0393 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 1s 475ms/step - loss: 0.0370 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0385 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 1s 468ms/step - loss: 0.0363 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0383 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 1s 482ms/step - loss: 0.0366 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0372 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 1s 625ms/step - loss: 0.0350 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0365 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 51ms/step
# 2/2 [==============================] - 1s 556ms/step - loss: 0.0342 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0356 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 1s 556ms/step - loss: 0.0335 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0350 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 1s 583ms/step - loss: 0.0330 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0343 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 1s 598ms/step - loss: 0.0323 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0336 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 1s 530ms/step - loss: 0.0318 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0331 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 1s 484ms/step - loss: 0.0312 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0327 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 1s 524ms/step - loss: 0.0308 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0320 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 1s 544ms/step - loss: 0.0300 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0314 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 1s 536ms/step - loss: 0.0295 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0308 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 1s 487ms/step - loss: 0.0292 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0303 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 1s 483ms/step - loss: 0.0285 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0298 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 1s 464ms/step - loss: 0.0280 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0294 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 1s 550ms/step - loss: 0.0275 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0288 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 1s 536ms/step - loss: 0.0273 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0283 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 1s 477ms/step - loss: 0.0268 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0278 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 1s 526ms/step - loss: 0.0263 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0274 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 1s 477ms/step - loss: 0.0257 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0269 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 1s 532ms/step - loss: 0.0253 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0265 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 1s 470ms/step - loss: 0.0249 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0262 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 1s 539ms/step - loss: 0.0245 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0257 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 1s 539ms/step - loss: 0.0243 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0253 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 1s 521ms/step - loss: 0.0237 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0249 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 1s 641ms/step - loss: 0.0235 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0246 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 1s 594ms/step - loss: 0.0231 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0242 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 1s 582ms/step - loss: 0.0226 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0238 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 1s 531ms/step - loss: 0.0223 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0234 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 1s 538ms/step - loss: 0.0220 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0231 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 1s 479ms/step - loss: 0.0217 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0228 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 1s 534ms/step - loss: 0.0214 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0224 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 1s 530ms/step - loss: 0.0210 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0221 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 1s 476ms/step - loss: 0.0207 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0218 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 1s 546ms/step - loss: 0.0206 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0215 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 1s 539ms/step - loss: 0.0201 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0212 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 1s 530ms/step - loss: 0.0198 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0209 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 1s 546ms/step - loss: 0.0196 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0207 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 1s 540ms/step - loss: 0.0193 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0203 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 1s 549ms/step - loss: 0.0190 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0200 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 1s 530ms/step - loss: 0.0188 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0198 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 1s 530ms/step - loss: 0.0185 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0195 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 1s 595ms/step - loss: 0.0183 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0193 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 1s 647ms/step - loss: 0.0180 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0190 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 1s 564ms/step - loss: 0.0178 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0188 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 1s 590ms/step - loss: 0.0175 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0185 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 1s 534ms/step - loss: 0.0173 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0182 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 1s 606ms/step - loss: 0.0171 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0180 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 1s 548ms/step - loss: 0.0169 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0178 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 1s 546ms/step - loss: 0.0166 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0176 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 1s 536ms/step - loss: 0.0165 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0175 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 1s 482ms/step - loss: 0.0164 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0173 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 1s 491ms/step - loss: 0.0161 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0169 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 1s 557ms/step - loss: 0.0158 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0167 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 1s 484ms/step - loss: 0.0156 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0165 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# 2/2 [==============================] - 5s 3s/step - loss: 0.1664 - f1_m: 0.9615 - auc_5: 0.9419
# 2/2 [==============================] - 0s 220ms/step
# Models: 5it [10:11, 122.21s/it]

# %% [markdown]
# # K20 Train/Test

# %%
# Define early stop
patience = 30
early_stopping = EarlyStopping(monitor='val_loss', patience=patience, mode='auto', restore_best_weights=True)


# Params
epochs = 200
batch_size = 16

# %%
from sklearn.metrics import make_scorer, f1_score
from sklearn.metrics import roc_auc_score
from tqdm import tqdm
import pandas as pd

models = [vgg_model, resnet_model, inception_model, xception_model]
model_names = ["VGG16", "ResNet50", "InceptionV3", "Xception"]
scoring_models_k20 = []
current_datetime = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# Progressbar
progress_bar = tqdm(total=len(models), desc='Models', position=0)


for model, model_name in zip(models, model_names):

    if model_name == "VGG16":
      reset_model_vgg16 = clone_model(vgg_model)
      reset_model_vgg16.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=[f1_m, tf.keras.metrics.AUC()])
      ### Training on Data K20
      history_vgg16_k20 = reset_model_vgg16.fit(train_data_vgg16_k20, train_labels_vgg16_k20, validation_data=(val_data_vgg16_k20, val_labels_vgg16_k20),
                          batch_size=batch_size, epochs=epochs, callbacks=[early_stopping, AUCROCCallback(validation_data=(val_data_vgg16_k20, val_labels_vgg16_k20))])

      formating_results_k20 = {}
      formating_results_k20["Model"] = model_name
      formating_results_k20["Loss"] = history_vgg16_k20.history["loss"]
      formating_results_k20["F1-Score"] = history_vgg16_k20.history["f1_m"]
      formating_results_k20["Validation Loss"] = history_vgg16_k20.history["val_loss"]
      formating_results_k20["Validation F1-Score"] = history_vgg16_k20.history["val_f1_m"]
      formating_results_k20["AUC-ROC VAL"] = history_vgg16_k20.history['val_auc_roc']

      loss_evaluation_vgg16, f1_m_evaluation_vgg16, auc_roc_evaluation_vgg16 = reset_model_vgg16.evaluate(test_data_vgg16_k20, test_labels_vgg16_k20, verbose=1)
      formating_results_k20["F1-Score Test"] = f1_m_evaluation_vgg16
      formating_results_k20["Loss Test"] = loss_evaluation_vgg16
      formating_results_k20["AUC-ROC Test"] = auc_roc_evaluation_vgg16

      scoring_models_k20.append(formating_results_k20)

      y_pred = reset_model_vgg16.predict(test_data_vgg16_k20)
      y_pred = np.argmax(y_pred, axis=1)

      cm = confusion_matrix(test_labels_vgg16_k20, y_pred)
      cm_float = cm.astype(float)

      try:
          cm_filename = "ConfusionMatrix/ConfusionMatrix_k20_" + model_name + "_" + current_datetime + ".csv"
          np.savetxt(cm_filename, cm_float, delimiter=",", fmt='%.4f')
      except:
          continue

      progress_bar.update(1)

      try:
        filename = "Models/Model_k20_" + model_name + "_" + current_datetime + ".h5"
        reset_model_vgg16.save(filename)
      except:
        continue

    if model_name == "ResNet50":
      reset_model_resnet50 = clone_model(resnet_model)
      reset_model_resnet50.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=[f1_m, tf.keras.metrics.AUC()])
      ### Training on K20
      history_resnet50_k20 = reset_model_resnet50.fit(train_data_resnet50_k20, train_labels_resnet50_k20, validation_data=(val_data_resnet50_k20, val_labels_resnet50_k20),
                          batch_size=batch_size, epochs=epochs, callbacks=[early_stopping, AUCROCCallback(validation_data=(val_data_resnet50_k20, val_labels_resnet50_k20))])

      formating_results_k20 = {}
      formating_results_k20["Model"] = model_name
      formating_results_k20["Loss"] = history_resnet50_k20.history["loss"]
      formating_results_k20["F1-Score"] = history_resnet50_k20.history["f1_m"]
      formating_results_k20["Validation Loss"] = history_resnet50_k20.history["val_loss"]
      formating_results_k20["Validation F1-Score"] = history_resnet50_k20.history["val_f1_m"]
      formating_results_k20["AUC-ROC VAL"] = history_resnet50_k20.history['val_auc_roc']

      loss_evaluation_resnet50, f1_m_evaluation_resnet50, auc_roc_evaluation_resnet50 = reset_model_resnet50.evaluate(test_data_resnet50_k20, test_labels_resnet50_k20, verbose=1)
      formating_results_k20["F1-Score Test"] = f1_m_evaluation_resnet50
      formating_results_k20["Loss Test"] = loss_evaluation_resnet50
      formating_results_k20["AUC-ROC Test"] = auc_roc_evaluation_resnet50


      scoring_models_k20.append(formating_results_k20)

      y_pred = reset_model_resnet50.predict(test_data_resnet50_k20)
      y_pred = np.argmax(y_pred, axis=1)

      cm = confusion_matrix(test_labels_resnet50_k20, y_pred)
      cm_float = cm.astype(float)

      try:
          cm_filename = "ConfusionMatrix/ConfusionMatrix_k20_" + model_name + "_" + current_datetime + ".csv"
          np.savetxt(cm_filename, cm_float, delimiter=",", fmt='%.4f')
      except:
          continue

      progress_bar.update(1)

      try:
        filename = "Models/Model_k20_" + model_name + "_" + current_datetime + ".h5"
        reset_model_resnet50.save(filename)
      except:
        continue

    if model_name == "InceptionV3":

      reset_model_inceptionv3 = clone_model(inception_model)
      reset_model_inceptionv3.compile(loss='binary_crossentropy', optimizer=optimizer_other, metrics=[f1_m, tf.keras.metrics.AUC()])
      ###Training on K20
      history_inceptionv3_k20 = reset_model_inceptionv3.fit(train_data_inceptionv3_k20, train_labels_inceptionv3_k20,
                                validation_data=(val_data_inceptionv3_k20, val_labels_inceptionv3_k20),
                          batch_size=batch_size, epochs=epochs, callbacks=[early_stopping, AUCROCCallback(validation_data=(val_data_inceptionv3_k20, val_labels_inceptionv3_k20))])

      formating_results_k20 = {}
      formating_results_k20["Model"] = model_name
      formating_results_k20["Loss"] = history_inceptionv3_k20.history["loss"]
      formating_results_k20["F1-Score"] = history_inceptionv3_k20.history["f1_m"]
      formating_results_k20["Validation Loss"] = history_inceptionv3_k20.history["val_loss"]
      formating_results_k20["Validation F1-Score"] = history_inceptionv3_k20.history["val_f1_m"]
      formating_results_k20["AUC-ROC VAL"] = history_inceptionv3_k20.history['val_auc_roc']

      loss_evaluation_inceptionv3, f1_m_evaluation_inceptionv3, auc_roc_evaluation_inceptionv3 = reset_model_inceptionv3.evaluate(test_data_inceptionv3_k20, test_labels_inceptionv3_k20, verbose=1)
      formating_results_k20["F1-Score Test"] = f1_m_evaluation_inceptionv3
      formating_results_k20["Loss Test"] = loss_evaluation_inceptionv3
      formating_results_k20["AUC-ROC Test"] = auc_roc_evaluation_inceptionv3

      scoring_models_k20.append(formating_results_k20)


      y_pred = reset_model_inceptionv3.predict(test_data_inceptionv3_k20)
      y_pred = np.argmax(y_pred, axis=1)

      cm = confusion_matrix(test_labels_inceptionv3_k20, y_pred)
      cm_float = cm.astype(float)

      try:
          cm_filename = "ConfusionMatrix/ConfusionMatrix_k20_" + model_name + "_" + current_datetime + ".csv"
          np.savetxt(cm_filename, cm_float, delimiter=",", fmt='%.4f')
      except:
          continue


      progress_bar.update(1)

      try:
        filename = "Models/Model_K20_" + model_name + "_" + current_datetime + ".h5"
        reset_model_inceptionv3.save(filename)
      except:
        continue

    if model_name == "Xception":
      reset_model_xception = clone_model(xception_model)
      reset_model_xception.compile(loss='binary_crossentropy', optimizer=optimizer_other, metrics=[f1_m, tf.keras.metrics.AUC()])
      ### Training on K20
      history_xception_k20 = reset_model_xception.fit(train_data_xception_k20, train_labels_xception_k20,
                                validation_data=(val_data_xception_k20, val_labels_xception_k20),
                          batch_size=batch_size, epochs=epochs, callbacks=[early_stopping, AUCROCCallback(validation_data=(val_data_xception_k20, val_labels_xception_k20))])

      formating_results_k20 = {}
      formating_results_k20["Model"] = model_name
      formating_results_k20["Loss"] = history_xception_k20.history["loss"]
      formating_results_k20["F1-Score"] = history_xception_k20.history["f1_m"]
      formating_results_k20["Validation Loss"] = history_xception_k20.history["val_loss"]
      formating_results_k20["Validation F1-Score"] = history_xception_k20.history["val_f1_m"]
      formating_results_k20["AUC-ROC VAL"] = history_xception_k20.history['val_auc_roc']

      loss_evaluation_xception, f1_m_evaluation_xception, auc_roc_evaluation_xception  = reset_model_xception.evaluate(test_data_xception_k20, test_labels_xception_k20, verbose=1)
      formating_results_k20["F1-Score Test"] = f1_m_evaluation_xception
      formating_results_k20["Loss Test"] = loss_evaluation_xception
      formating_results_k20["AUC-ROC Test"] = auc_roc_evaluation_xception

      scoring_models_k20.append(formating_results_k20)

      y_pred = reset_model_xception.predict(test_data_xception_k20)
      y_pred = np.argmax(y_pred, axis=1)

      cm = confusion_matrix(test_labels_xception_k20, y_pred)
      cm_float = cm.astype(float)

      try:
          cm_filename = "ConfusionMatrix/ConfusionMatrix_k20_" + model_name + "_" + current_datetime + ".csv"
          np.savetxt(cm_filename, cm_float, delimiter=",", fmt='%.4f')
      except:
          continue

      progress_bar.update(1)

      try:
        filename = "Models/Model_k20_" + model_name + "_" + current_datetime + ".h5"
        reset_model_xception.save(filename)
      except:
        continue

# Progressbar close
progress_bar.close()

# Scoring Dataframe
df_k20 = pd.DataFrame(scoring_models_k20)
df_k20.to_csv("model_metrics_k20_balanced" + current_datetime, index=False)
# Out:
# Models:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 1/200
# 1/1 [==============================] - 0s 177ms/step
# 4/4 [==============================] - 13s 972ms/step - loss: 0.7080 - f1_m: 0.3879 - auc_2: 0.5512 - val_loss: 0.6218 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 2/200
# 1/1 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 0s 121ms/step - loss: 0.6281 - f1_m: 0.8033 - auc_2: 0.6488 - val_loss: 0.6320 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 3/200
# 1/1 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 0s 127ms/step - loss: 0.6399 - f1_m: 0.7980 - auc_2: 0.8625 - val_loss: 0.6256 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 4/200
# 1/1 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 139ms/step - loss: 0.6295 - f1_m: 0.8033 - auc_2: 0.6406 - val_loss: 0.6116 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 5/200
# 1/1 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 0s 128ms/step - loss: 0.6231 - f1_m: 0.7964 - auc_2: 0.7581 - val_loss: 0.6138 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 6/200
# 1/1 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 138ms/step - loss: 0.6245 - f1_m: 0.7764 - auc_2: 0.7375 - val_loss: 0.6071 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 7/200
# 1/1 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 141ms/step - loss: 0.6125 - f1_m: 0.7997 - auc_2: 0.8438 - val_loss: 0.6050 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 8/200
# 1/1 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 134ms/step - loss: 0.6123 - f1_m: 0.8013 - auc_2: 0.8537 - val_loss: 0.6025 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 9/200
# 1/1 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 145ms/step - loss: 0.6103 - f1_m: 0.7945 - auc_2: 0.8913 - val_loss: 0.6001 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 10/200
# 1/1 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 0s 139ms/step - loss: 0.6080 - f1_m: 0.8042 - auc_2: 0.8375 - val_loss: 0.5967 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 11/200
# 1/1 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 134ms/step - loss: 0.6054 - f1_m: 0.7884 - auc_2: 0.8663 - val_loss: 0.5944 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 12/200
# 1/1 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 131ms/step - loss: 0.6101 - f1_m: 0.7763 - auc_2: 0.8462 - val_loss: 0.5920 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 13/200
# 1/1 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 146ms/step - loss: 0.6035 - f1_m: 0.8033 - auc_2: 0.8813 - val_loss: 0.5914 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 14/200
# 1/1 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 145ms/step - loss: 0.5997 - f1_m: 0.7980 - auc_2: 0.8706 - val_loss: 0.5878 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 15/200
# 1/1 [==============================] - 0s 94ms/step
# 4/4 [==============================] - 1s 212ms/step - loss: 0.5973 - f1_m: 0.7921 - auc_2: 0.8806 - val_loss: 0.5837 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 16/200
# 1/1 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 140ms/step - loss: 0.5952 - f1_m: 0.7943 - auc_2: 0.8906 - val_loss: 0.5805 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 17/200
# 1/1 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 1s 203ms/step - loss: 0.5934 - f1_m: 0.7974 - auc_2: 0.8675 - val_loss: 0.5775 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 18/200
# 1/1 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 145ms/step - loss: 0.5881 - f1_m: 0.7989 - auc_2: 0.8775 - val_loss: 0.5749 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 19/200
# 1/1 [==============================] - 0s 36ms/step
# 4/4 [==============================] - 1s 160ms/step - loss: 0.5925 - f1_m: 0.7979 - auc_2: 0.8744 - val_loss: 0.5716 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 20/200
# 1/1 [==============================] - 0s 37ms/step
# 4/4 [==============================] - 1s 159ms/step - loss: 0.5832 - f1_m: 0.8009 - auc_2: 0.8888 - val_loss: 0.5686 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 21/200
# 1/1 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 1s 157ms/step - loss: 0.5809 - f1_m: 0.7980 - auc_2: 0.9044 - val_loss: 0.5659 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 22/200
# 1/1 [==============================] - 0s 37ms/step
# 4/4 [==============================] - 1s 155ms/step - loss: 0.5807 - f1_m: 0.7989 - auc_2: 0.8550 - val_loss: 0.5623 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 23/200
# 1/1 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 1s 160ms/step - loss: 0.5765 - f1_m: 0.8017 - auc_2: 0.8700 - val_loss: 0.5590 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 24/200
# 1/1 [==============================] - 0s 39ms/step
# 4/4 [==============================] - 1s 156ms/step - loss: 0.5741 - f1_m: 0.8009 - auc_2: 0.9362 - val_loss: 0.5556 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 25/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 139ms/step - loss: 0.5784 - f1_m: 0.7987 - auc_2: 0.8225 - val_loss: 0.5533 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 26/200
# 1/1 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 1s 147ms/step - loss: 0.5669 - f1_m: 0.7921 - auc_2: 0.9394 - val_loss: 0.5495 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 27/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 145ms/step - loss: 0.5723 - f1_m: 0.7952 - auc_2: 0.8519 - val_loss: 0.5481 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 28/200
# 1/1 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 138ms/step - loss: 0.5740 - f1_m: 0.7974 - auc_2: 0.8600 - val_loss: 0.5422 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 29/200
# 1/1 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 135ms/step - loss: 0.5641 - f1_m: 0.7851 - auc_2: 0.8719 - val_loss: 0.5378 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 30/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 135ms/step - loss: 0.5596 - f1_m: 0.8017 - auc_2: 0.8344 - val_loss: 0.5361 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 31/200
# 1/1 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 138ms/step - loss: 0.5542 - f1_m: 0.7980 - auc_2: 0.9275 - val_loss: 0.5303 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 32/200
# 1/1 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 133ms/step - loss: 0.5495 - f1_m: 0.7997 - auc_2: 0.9000 - val_loss: 0.5261 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 33/200
# 1/1 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 135ms/step - loss: 0.5490 - f1_m: 0.7930 - auc_2: 0.8975 - val_loss: 0.5220 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 34/200
# 1/1 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 135ms/step - loss: 0.5509 - f1_m: 0.8033 - auc_2: 0.8600 - val_loss: 0.5213 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 35/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 138ms/step - loss: 0.5440 - f1_m: 0.7851 - auc_2: 0.8662 - val_loss: 0.5140 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 36/200
# 1/1 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 137ms/step - loss: 0.5391 - f1_m: 0.7945 - auc_2: 0.9019 - val_loss: 0.5099 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 37/200
# 1/1 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 0s 138ms/step - loss: 0.5363 - f1_m: 0.7851 - auc_2: 0.8925 - val_loss: 0.5047 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 38/200
# 1/1 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 0s 139ms/step - loss: 0.5292 - f1_m: 0.7997 - auc_2: 0.9275 - val_loss: 0.5045 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 136ms/step - loss: 0.5345 - f1_m: 0.8213 - auc_2: 0.9150 - val_loss: 0.5018 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 40/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 143ms/step - loss: 0.5222 - f1_m: 0.8189 - auc_2: 0.9150 - val_loss: 0.4908 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 41/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 142ms/step - loss: 0.5191 - f1_m: 0.7980 - auc_2: 0.8719 - val_loss: 0.4881 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 42/200
# 1/1 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 0s 143ms/step - loss: 0.5201 - f1_m: 0.7875 - auc_2: 0.9038 - val_loss: 0.4820 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 43/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 138ms/step - loss: 0.5097 - f1_m: 0.7930 - auc_2: 0.9112 - val_loss: 0.4815 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 44/200
# 1/1 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 0s 141ms/step - loss: 0.5137 - f1_m: 0.9503 - auc_2: 0.9000 - val_loss: 0.4806 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 45/200
# 1/1 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 139ms/step - loss: 0.5030 - f1_m: 0.9517 - auc_2: 0.9087 - val_loss: 0.4661 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 46/200
# 1/1 [==============================] - 0s 37ms/step
# 4/4 [==============================] - 1s 155ms/step - loss: 0.4979 - f1_m: 0.8026 - auc_2: 0.9044 - val_loss: 0.4657 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 47/200
# 1/1 [==============================] - 0s 48ms/step
# 4/4 [==============================] - 1s 164ms/step - loss: 0.5008 - f1_m: 0.7928 - auc_2: 0.8888 - val_loss: 0.4567 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 48/200
# 1/1 [==============================] - 0s 35ms/step
# 4/4 [==============================] - 1s 147ms/step - loss: 0.5027 - f1_m: 0.8490 - auc_2: 0.8881 - val_loss: 0.4570 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 0s 36ms/step
# 4/4 [==============================] - 1s 159ms/step - loss: 0.4885 - f1_m: 0.9545 - auc_2: 0.9469 - val_loss: 0.4466 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 50/200
# 1/1 [==============================] - 0s 38ms/step
# 4/4 [==============================] - 1s 155ms/step - loss: 0.4885 - f1_m: 0.8239 - auc_2: 0.8888 - val_loss: 0.4413 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 51/200
# 1/1 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 1s 162ms/step - loss: 0.4822 - f1_m: 0.7851 - auc_2: 0.8950 - val_loss: 0.4346 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 52/200
# 1/1 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 1s 153ms/step - loss: 0.4736 - f1_m: 0.8876 - auc_2: 0.9212 - val_loss: 0.4318 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 53/200
# 1/1 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 0s 134ms/step - loss: 0.4715 - f1_m: 0.9581 - auc_2: 0.8838 - val_loss: 0.4292 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 54/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 139ms/step - loss: 0.4640 - f1_m: 0.9511 - auc_2: 0.9569 - val_loss: 0.4171 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 55/200
# 1/1 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 0s 139ms/step - loss: 0.4594 - f1_m: 0.8612 - auc_2: 0.9456 - val_loss: 0.4129 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 56/200
# 1/1 [==============================] - 0s 34ms/step
# 4/4 [==============================] - 1s 147ms/step - loss: 0.4666 - f1_m: 0.8913 - auc_2: 0.8544 - val_loss: 0.4060 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 140ms/step - loss: 0.4526 - f1_m: 0.9524 - auc_2: 0.8675 - val_loss: 0.4002 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 58/200
# 1/1 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 0s 137ms/step - loss: 0.4513 - f1_m: 0.8909 - auc_2: 0.9444 - val_loss: 0.3941 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 59/200
# 1/1 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 138ms/step - loss: 0.4464 - f1_m: 0.8877 - auc_2: 0.9563 - val_loss: 0.3876 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 60/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 124ms/step - loss: 0.4507 - f1_m: 0.9564 - auc_2: 0.9031 - val_loss: 0.4089 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 61/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 142ms/step - loss: 0.4420 - f1_m: 0.9486 - auc_2: 0.9594 - val_loss: 0.3762 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 62/200
# 1/1 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 123ms/step - loss: 0.4655 - f1_m: 0.8173 - auc_2: 0.8900 - val_loss: 0.3900 - val_f1_m: 0.8000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 139ms/step - loss: 0.4319 - f1_m: 0.8675 - auc_2: 0.9700 - val_loss: 0.3663 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 64/200
# 1/1 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 0s 126ms/step - loss: 0.4309 - f1_m: 0.9564 - auc_2: 0.8950 - val_loss: 0.4020 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 139ms/step - loss: 0.4325 - f1_m: 0.9495 - auc_2: 0.8594 - val_loss: 0.3544 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 0s 141ms/step - loss: 0.4064 - f1_m: 0.9496 - auc_2: 0.9112 - val_loss: 0.3491 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 67/200
# 1/1 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 143ms/step - loss: 0.4168 - f1_m: 0.9514 - auc_2: 0.8962 - val_loss: 0.3434 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 123ms/step - loss: 0.4174 - f1_m: 0.9486 - auc_2: 0.9100 - val_loss: 0.3505 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 144ms/step - loss: 0.4018 - f1_m: 0.9518 - auc_2: 0.9275 - val_loss: 0.3338 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 0s 143ms/step - loss: 0.3975 - f1_m: 0.9615 - auc_2: 0.9619 - val_loss: 0.3259 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 143ms/step - loss: 0.3937 - f1_m: 0.9513 - auc_2: 0.9106 - val_loss: 0.3211 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 142ms/step - loss: 0.3864 - f1_m: 0.9519 - auc_2: 0.9250 - val_loss: 0.3205 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 0s 40ms/step
# 4/4 [==============================] - 1s 150ms/step - loss: 0.3841 - f1_m: 0.9524 - auc_2: 0.9169 - val_loss: 0.3098 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 38ms/step
# 4/4 [==============================] - 1s 148ms/step - loss: 0.3765 - f1_m: 0.9564 - auc_2: 0.9675 - val_loss: 0.3043 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 1s 148ms/step - loss: 0.3750 - f1_m: 0.9435 - auc_2: 0.9088 - val_loss: 0.2980 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 159ms/step
# 4/4 [==============================] - 1s 391ms/step - loss: 0.3667 - f1_m: 0.9506 - auc_2: 0.9581 - val_loss: 0.2985 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 1s 160ms/step - loss: 0.3659 - f1_m: 0.9573 - auc_2: 0.9325 - val_loss: 0.2943 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 47ms/step
# 4/4 [==============================] - 1s 163ms/step - loss: 0.3627 - f1_m: 0.9496 - auc_2: 0.9406 - val_loss: 0.2801 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 124ms/step - loss: 0.3685 - f1_m: 0.9460 - auc_2: 0.8656 - val_loss: 0.2817 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 141ms/step - loss: 0.3543 - f1_m: 0.9495 - auc_2: 0.9469 - val_loss: 0.2702 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 142ms/step - loss: 0.3842 - f1_m: 0.9392 - auc_2: 0.8713 - val_loss: 0.2667 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 123ms/step - loss: 0.3456 - f1_m: 0.9506 - auc_2: 0.9394 - val_loss: 0.2854 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 128ms/step - loss: 0.3582 - f1_m: 0.9541 - auc_2: 0.9369 - val_loss: 0.2751 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 144ms/step - loss: 0.3478 - f1_m: 0.9514 - auc_2: 0.9088 - val_loss: 0.2501 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 139ms/step - loss: 0.3421 - f1_m: 0.9591 - auc_2: 0.9256 - val_loss: 0.2445 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 120ms/step - loss: 0.3465 - f1_m: 0.9497 - auc_2: 0.8875 - val_loss: 0.2593 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 1s 147ms/step - loss: 0.3283 - f1_m: 0.9494 - auc_2: 0.9288 - val_loss: 0.2341 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 1s 146ms/step - loss: 0.3272 - f1_m: 0.9568 - auc_2: 0.9494 - val_loss: 0.2295 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 129ms/step - loss: 0.3223 - f1_m: 0.9460 - auc_2: 0.9650 - val_loss: 0.2305 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 131ms/step - loss: 0.3190 - f1_m: 0.9456 - auc_2: 0.9163 - val_loss: 0.2322 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 136ms/step - loss: 0.3169 - f1_m: 0.9522 - auc_2: 0.9456 - val_loss: 0.2267 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 142ms/step - loss: 0.3118 - f1_m: 0.9533 - auc_2: 0.9056 - val_loss: 0.2142 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 143ms/step - loss: 0.3100 - f1_m: 0.9526 - auc_2: 0.9563 - val_loss: 0.2103 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 128ms/step - loss: 0.3099 - f1_m: 0.9499 - auc_2: 0.9175 - val_loss: 0.2184 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 0s 142ms/step - loss: 0.3022 - f1_m: 0.9545 - auc_2: 0.9450 - val_loss: 0.2011 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 144ms/step - loss: 0.3106 - f1_m: 0.9442 - auc_2: 0.8825 - val_loss: 0.1936 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 135ms/step - loss: 0.2972 - f1_m: 0.9411 - auc_2: 0.9513 - val_loss: 0.2138 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 132ms/step - loss: 0.3027 - f1_m: 0.9487 - auc_2: 0.9475 - val_loss: 0.2059 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 134ms/step - loss: 0.2921 - f1_m: 0.9594 - auc_2: 0.9812 - val_loss: 0.1860 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 1s 154ms/step - loss: 0.3021 - f1_m: 0.9391 - auc_2: 0.8688 - val_loss: 0.1787 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 39ms/step
# 4/4 [==============================] - 0s 141ms/step - loss: 0.3181 - f1_m: 0.9497 - auc_2: 0.8850 - val_loss: 0.2188 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 39ms/step
# 4/4 [==============================] - 1s 196ms/step - loss: 0.2859 - f1_m: 0.9545 - auc_2: 0.9806 - val_loss: 0.1730 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 1s 161ms/step - loss: 0.3012 - f1_m: 0.9529 - auc_2: 0.9081 - val_loss: 0.1696 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 104/200
# 1/1 [==============================] - 0s 39ms/step
# 4/4 [==============================] - 0s 137ms/step - loss: 0.2826 - f1_m: 0.9459 - auc_2: 0.9894 - val_loss: 0.1814 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 37ms/step
# 4/4 [==============================] - 1s 150ms/step - loss: 0.2821 - f1_m: 0.9498 - auc_2: 0.9613 - val_loss: 0.2118 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 39ms/step
# 4/4 [==============================] - 1s 166ms/step - loss: 0.2992 - f1_m: 0.9444 - auc_2: 0.8587 - val_loss: 0.1624 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 136ms/step - loss: 0.2764 - f1_m: 0.9571 - auc_2: 0.9650 - val_loss: 0.1640 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 130ms/step - loss: 0.2755 - f1_m: 0.9555 - auc_2: 0.9281 - val_loss: 0.1670 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 135ms/step - loss: 0.2728 - f1_m: 0.9552 - auc_2: 0.9725 - val_loss: 0.1623 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 104ms/step
# 4/4 [==============================] - 1s 312ms/step - loss: 0.2745 - f1_m: 0.9410 - auc_2: 0.9112 - val_loss: 0.1501 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 129ms/step - loss: 0.2701 - f1_m: 0.9529 - auc_2: 0.9300 - val_loss: 0.1579 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 35ms/step
# 4/4 [==============================] - 1s 220ms/step - loss: 0.2672 - f1_m: 0.9574 - auc_2: 0.9513 - val_loss: 0.1596 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 113/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 1s 148ms/step - loss: 0.2710 - f1_m: 0.9421 - auc_2: 0.8969 - val_loss: 0.1439 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 129ms/step - loss: 0.2663 - f1_m: 0.9499 - auc_2: 0.9231 - val_loss: 0.1517 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 131ms/step - loss: 0.2681 - f1_m: 0.9574 - auc_2: 0.8981 - val_loss: 0.1501 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 138ms/step - loss: 0.2842 - f1_m: 0.9466 - auc_2: 0.8763 - val_loss: 0.1326 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 120ms/step - loss: 0.2815 - f1_m: 0.9542 - auc_2: 0.8750 - val_loss: 0.1747 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 126ms/step - loss: 0.2795 - f1_m: 0.9392 - auc_2: 0.8631 - val_loss: 0.1336 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 125ms/step - loss: 0.2635 - f1_m: 0.9541 - auc_2: 0.8981 - val_loss: 0.1492 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 0s 125ms/step - loss: 0.2565 - f1_m: 0.9564 - auc_2: 0.9769 - val_loss: 0.1348 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 0s 140ms/step - loss: 0.2568 - f1_m: 0.9447 - auc_2: 0.9513 - val_loss: 0.1262 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 127ms/step - loss: 0.2543 - f1_m: 0.9532 - auc_2: 0.9500 - val_loss: 0.1345 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 122ms/step - loss: 0.2543 - f1_m: 0.9514 - auc_2: 0.9619 - val_loss: 0.1407 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 127ms/step - loss: 0.2519 - f1_m: 0.9561 - auc_2: 0.9700 - val_loss: 0.1302 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 139ms/step - loss: 0.2504 - f1_m: 0.9506 - auc_2: 0.9569 - val_loss: 0.1223 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 125ms/step - loss: 0.2517 - f1_m: 0.9564 - auc_2: 0.9262 - val_loss: 0.1322 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 0s 141ms/step - loss: 0.2493 - f1_m: 0.9542 - auc_2: 0.9856 - val_loss: 0.1242 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 36ms/step
# 4/4 [==============================] - 1s 164ms/step - loss: 0.2510 - f1_m: 0.9532 - auc_2: 0.9450 - val_loss: 0.1137 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 145ms/step - loss: 0.2488 - f1_m: 0.9606 - auc_2: 0.9588 - val_loss: 0.1252 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 34ms/step
# 4/4 [==============================] - 1s 148ms/step - loss: 0.2482 - f1_m: 0.9447 - auc_2: 0.9563 - val_loss: 0.1282 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 40ms/step
# 4/4 [==============================] - 1s 153ms/step - loss: 0.2510 - f1_m: 0.9416 - auc_2: 0.9131 - val_loss: 0.1151 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 36ms/step
# 4/4 [==============================] - 1s 146ms/step - loss: 0.2451 - f1_m: 0.9506 - auc_2: 0.9650 - val_loss: 0.1195 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 40ms/step
# 4/4 [==============================] - 0s 140ms/step - loss: 0.2506 - f1_m: 0.9507 - auc_2: 0.9019 - val_loss: 0.1317 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 0s 140ms/step - loss: 0.2513 - f1_m: 0.9463 - auc_2: 0.8938 - val_loss: 0.1048 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 124ms/step - loss: 0.2449 - f1_m: 0.9583 - auc_2: 0.9212 - val_loss: 0.1264 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 127ms/step - loss: 0.2434 - f1_m: 0.9518 - auc_2: 0.9606 - val_loss: 0.1141 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 121ms/step - loss: 0.2396 - f1_m: 0.9522 - auc_2: 0.9875 - val_loss: 0.1114 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 123ms/step - loss: 0.2448 - f1_m: 0.9508 - auc_2: 0.9194 - val_loss: 0.1110 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 130ms/step - loss: 0.2427 - f1_m: 0.9591 - auc_2: 0.9263 - val_loss: 0.1123 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 1s 234ms/step - loss: 0.2493 - f1_m: 0.9506 - auc_2: 0.9069 - val_loss: 0.0960 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 0s 128ms/step - loss: 0.2374 - f1_m: 0.9509 - auc_2: 0.9869 - val_loss: 0.1162 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 134ms/step - loss: 0.2505 - f1_m: 0.9542 - auc_2: 0.9225 - val_loss: 0.1464 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 0s 139ms/step - loss: 0.2678 - f1_m: 0.9381 - auc_2: 0.8575 - val_loss: 0.0892 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 0s 135ms/step - loss: 0.2452 - f1_m: 0.9564 - auc_2: 0.9475 - val_loss: 0.1160 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 0s 140ms/step - loss: 0.2542 - f1_m: 0.9564 - auc_2: 0.8875 - val_loss: 0.1350 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 146ms/step - loss: 0.2644 - f1_m: 0.9405 - auc_2: 0.8612 - val_loss: 0.0864 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 128ms/step - loss: 0.2399 - f1_m: 0.9512 - auc_2: 0.9656 - val_loss: 0.1067 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 137ms/step - loss: 0.2346 - f1_m: 0.9545 - auc_2: 0.9619 - val_loss: 0.1431 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 143ms/step - loss: 0.2410 - f1_m: 0.9500 - auc_2: 0.9563 - val_loss: 0.1015 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 1s 149ms/step - loss: 0.2424 - f1_m: 0.9495 - auc_2: 0.9106 - val_loss: 0.0857 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 35ms/step
# 4/4 [==============================] - 0s 129ms/step - loss: 0.2372 - f1_m: 0.9567 - auc_2: 0.9106 - val_loss: 0.1176 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 0s 132ms/step - loss: 0.2362 - f1_m: 0.9558 - auc_2: 0.9863 - val_loss: 0.1145 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 1s 148ms/step - loss: 0.2355 - f1_m: 0.9580 - auc_2: 0.9344 - val_loss: 0.0838 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 131ms/step - loss: 0.2381 - f1_m: 0.9536 - auc_2: 0.9913 - val_loss: 0.0912 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 36ms/step
# 4/4 [==============================] - 1s 148ms/step - loss: 0.2301 - f1_m: 0.9503 - auc_2: 0.9581 - val_loss: 0.1189 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 36ms/step
# 4/4 [==============================] - 1s 148ms/step - loss: 0.2435 - f1_m: 0.9534 - auc_2: 0.9175 - val_loss: 0.1177 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 39ms/step
# 4/4 [==============================] - 1s 160ms/step - loss: 0.2419 - f1_m: 0.9500 - auc_2: 0.9119 - val_loss: 0.0773 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 35ms/step
# 4/4 [==============================] - 0s 136ms/step - loss: 0.2506 - f1_m: 0.9486 - auc_2: 0.9069 - val_loss: 0.0839 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 54ms/step
# 4/4 [==============================] - 1s 157ms/step - loss: 0.2370 - f1_m: 0.9588 - auc_2: 0.9156 - val_loss: 0.1313 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 39ms/step
# 4/4 [==============================] - 1s 151ms/step - loss: 0.2350 - f1_m: 0.9568 - auc_2: 0.9544 - val_loss: 0.0975 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 1s 148ms/step - loss: 0.2291 - f1_m: 0.9523 - auc_2: 0.9794 - val_loss: 0.0871 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 128ms/step - loss: 0.2312 - f1_m: 0.9427 - auc_2: 0.9694 - val_loss: 0.0805 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 135ms/step - loss: 0.2386 - f1_m: 0.9460 - auc_2: 0.8906 - val_loss: 0.0934 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 124ms/step - loss: 0.2273 - f1_m: 0.9493 - auc_2: 0.9950 - val_loss: 0.0858 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 0s 130ms/step - loss: 0.2280 - f1_m: 0.9555 - auc_2: 0.9844 - val_loss: 0.0918 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 36ms/step
# 4/4 [==============================] - 0s 136ms/step - loss: 0.2276 - f1_m: 0.9522 - auc_2: 0.9625 - val_loss: 0.0945 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 134ms/step - loss: 0.2327 - f1_m: 0.9527 - auc_2: 0.9212 - val_loss: 0.0887 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 132ms/step - loss: 0.2295 - f1_m: 0.9499 - auc_2: 0.9650 - val_loss: 0.0868 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 137ms/step - loss: 0.2234 - f1_m: 0.9532 - auc_2: 0.9800 - val_loss: 0.1091 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 129ms/step - loss: 0.2319 - f1_m: 0.9479 - auc_2: 0.9675 - val_loss: 0.1069 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 1s 147ms/step - loss: 0.2249 - f1_m: 0.9506 - auc_2: 0.9488 - val_loss: 0.0715 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 0s 125ms/step - loss: 0.2336 - f1_m: 0.9416 - auc_2: 0.9244 - val_loss: 0.0806 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 133ms/step - loss: 0.2297 - f1_m: 0.9522 - auc_2: 0.9275 - val_loss: 0.1016 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 0s 130ms/step - loss: 0.2240 - f1_m: 0.9517 - auc_2: 0.9700 - val_loss: 0.0850 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 0s 134ms/step - loss: 0.2267 - f1_m: 0.9495 - auc_2: 0.9756 - val_loss: 0.0825 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 130ms/step - loss: 0.2419 - f1_m: 0.9523 - auc_2: 0.8800 - val_loss: 0.1142 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 144ms/step - loss: 0.2358 - f1_m: 0.9456 - auc_2: 0.9125 - val_loss: 0.0684 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 135ms/step - loss: 0.2297 - f1_m: 0.9564 - auc_2: 0.9488 - val_loss: 0.0903 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 124ms/step - loss: 0.2248 - f1_m: 0.9491 - auc_2: 0.9563 - val_loss: 0.0896 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 131ms/step - loss: 0.2229 - f1_m: 0.9479 - auc_2: 0.9825 - val_loss: 0.0986 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 129ms/step - loss: 0.2254 - f1_m: 0.9574 - auc_2: 0.9725 - val_loss: 0.1023 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 138ms/step - loss: 0.2319 - f1_m: 0.9522 - auc_2: 0.9125 - val_loss: 0.0694 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 34ms/step
# 4/4 [==============================] - 0s 139ms/step - loss: 0.2322 - f1_m: 0.9568 - auc_2: 0.8956 - val_loss: 0.0963 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 34ms/step
# 4/4 [==============================] - 0s 145ms/step - loss: 0.2278 - f1_m: 0.9460 - auc_2: 0.9331 - val_loss: 0.0763 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 39ms/step
# 4/4 [==============================] - 0s 140ms/step - loss: 0.2354 - f1_m: 0.9542 - auc_2: 0.8813 - val_loss: 0.1055 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 35ms/step
# 4/4 [==============================] - 1s 147ms/step - loss: 0.2309 - f1_m: 0.9510 - auc_2: 0.9181 - val_loss: 0.0692 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 47ms/step
# 4/4 [==============================] - 0s 142ms/step - loss: 0.2254 - f1_m: 0.9513 - auc_2: 0.9256 - val_loss: 0.0881 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 37ms/step
# 4/4 [==============================] - 1s 172ms/step - loss: 0.2228 - f1_m: 0.9544 - auc_2: 0.9787 - val_loss: 0.0941 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 40ms/step
# 4/4 [==============================] - 1s 149ms/step - loss: 0.2248 - f1_m: 0.9607 - auc_2: 0.9737 - val_loss: 0.0846 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 144ms/step - loss: 0.2243 - f1_m: 0.9564 - auc_2: 0.9556 - val_loss: 0.0634 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 135ms/step - loss: 0.2418 - f1_m: 0.9450 - auc_2: 0.8650 - val_loss: 0.0895 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 128ms/step - loss: 0.2249 - f1_m: 0.9508 - auc_2: 0.9475 - val_loss: 0.0725 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 126ms/step - loss: 0.2318 - f1_m: 0.9511 - auc_2: 0.8950 - val_loss: 0.0963 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 124ms/step - loss: 0.2191 - f1_m: 0.9545 - auc_2: 0.9863 - val_loss: 0.0792 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 0s 134ms/step - loss: 0.2314 - f1_m: 0.9523 - auc_2: 0.9262 - val_loss: 0.0654 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 131ms/step - loss: 0.2219 - f1_m: 0.9516 - auc_2: 0.9956 - val_loss: 0.0832 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 197/200
# ...
# Epoch 137/200
# 1/1 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 1s 247ms/step - loss: 0.2367 - f1_m: 0.9522 - auc_5: 0.8819 - val_loss: 0.0906 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 48ms/step
# 4/4 [==============================] - 1s 262ms/step - loss: 0.2412 - f1_m: 0.9508 - auc_5: 0.8481 - val_loss: 0.0899 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 1s 217ms/step - loss: 0.2387 - f1_m: 0.9591 - auc_5: 0.8613 - val_loss: 0.0878 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 1s 228ms/step - loss: 0.2440 - f1_m: 0.9506 - auc_5: 0.8575 - val_loss: 0.0734 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 1s 237ms/step - loss: 0.2412 - f1_m: 0.9509 - auc_5: 0.8775 - val_loss: 0.0790 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 1s 195ms/step - loss: 0.2421 - f1_m: 0.9542 - auc_5: 0.8663 - val_loss: 0.1174 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 1s 218ms/step - loss: 0.2509 - f1_m: 0.9381 - auc_5: 0.8400 - val_loss: 0.0846 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 1s 214ms/step - loss: 0.2376 - f1_m: 0.9564 - auc_5: 0.8738 - val_loss: 0.0917 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 1s 217ms/step - loss: 0.2411 - f1_m: 0.9564 - auc_5: 0.8562 - val_loss: 0.0973 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 1s 246ms/step - loss: 0.2502 - f1_m: 0.9405 - auc_5: 0.8400 - val_loss: 0.0711 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 1s 235ms/step - loss: 0.2381 - f1_m: 0.9512 - auc_5: 0.8850 - val_loss: 0.0815 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 35ms/step
# 4/4 [==============================] - 1s 217ms/step - loss: 0.2346 - f1_m: 0.9545 - auc_5: 0.9044 - val_loss: 0.1055 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 1s 193ms/step - loss: 0.2394 - f1_m: 0.9500 - auc_5: 0.8794 - val_loss: 0.1008 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 1s 217ms/step - loss: 0.2402 - f1_m: 0.9495 - auc_5: 0.8619 - val_loss: 0.0801 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 1s 224ms/step - loss: 0.2363 - f1_m: 0.9567 - auc_5: 0.8688 - val_loss: 0.0864 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 55ms/step
# 4/4 [==============================] - 1s 230ms/step - loss: 0.2368 - f1_m: 0.9558 - auc_5: 0.8706 - val_loss: 0.0896 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 48ms/step
# 4/4 [==============================] - 1s 224ms/step - loss: 0.2359 - f1_m: 0.9580 - auc_5: 0.8775 - val_loss: 0.0831 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 49ms/step
# 4/4 [==============================] - 1s 235ms/step - loss: 0.2364 - f1_m: 0.9536 - auc_5: 0.8744 - val_loss: 0.0795 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 40ms/step
# 4/4 [==============================] - 1s 215ms/step - loss: 0.2354 - f1_m: 0.9503 - auc_5: 0.8888 - val_loss: 0.0848 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 1s 196ms/step - loss: 0.2419 - f1_m: 0.9534 - auc_5: 0.8550 - val_loss: 0.1034 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 1s 236ms/step - loss: 0.2384 - f1_m: 0.9500 - auc_5: 0.8575 - val_loss: 0.0818 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 1s 251ms/step - loss: 0.2430 - f1_m: 0.9486 - auc_5: 0.8575 - val_loss: 0.0705 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 1s 197ms/step - loss: 0.2400 - f1_m: 0.9588 - auc_5: 0.8663 - val_loss: 0.0809 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 1s 217ms/step - loss: 0.2366 - f1_m: 0.9568 - auc_5: 0.8700 - val_loss: 0.0893 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 1s 235ms/step - loss: 0.2408 - f1_m: 0.9523 - auc_5: 0.8562 - val_loss: 0.0955 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 34ms/step
# 4/4 [==============================] - 1s 196ms/step - loss: 0.2359 - f1_m: 0.9427 - auc_5: 0.8850 - val_loss: 0.0766 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 1s 191ms/step - loss: 0.2360 - f1_m: 0.9460 - auc_5: 0.8744 - val_loss: 0.0724 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 1s 235ms/step - loss: 0.2368 - f1_m: 0.9493 - auc_5: 0.8838 - val_loss: 0.0706 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 1s 216ms/step - loss: 0.2365 - f1_m: 0.9555 - auc_5: 0.8756 - val_loss: 0.0809 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 1s 196ms/step - loss: 0.2353 - f1_m: 0.9522 - auc_5: 0.8781 - val_loss: 0.0903 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 1s 192ms/step - loss: 0.2371 - f1_m: 0.9527 - auc_5: 0.8506 - val_loss: 0.0839 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 1s 216ms/step - loss: 0.2376 - f1_m: 0.9499 - auc_5: 0.8537 - val_loss: 0.0745 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 48ms/step
# 4/4 [==============================] - 1s 234ms/step - loss: 0.2338 - f1_m: 0.9532 - auc_5: 0.8938 - val_loss: 0.0838 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 38ms/step
# 4/4 [==============================] - 1s 231ms/step - loss: 0.2381 - f1_m: 0.9479 - auc_5: 0.8750 - val_loss: 0.0997 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 40ms/step
# 4/4 [==============================] - 1s 210ms/step - loss: 0.2348 - f1_m: 0.9506 - auc_5: 0.8881 - val_loss: 0.0809 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 1s 250ms/step - loss: 0.2362 - f1_m: 0.9416 - auc_5: 0.8556 - val_loss: 0.0746 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 1s 203ms/step - loss: 0.2347 - f1_m: 0.9522 - auc_5: 0.8719 - val_loss: 0.0770 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 1s 198ms/step - loss: 0.2334 - f1_m: 0.9517 - auc_5: 0.8806 - val_loss: 0.0789 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 1s 217ms/step - loss: 0.2341 - f1_m: 0.9495 - auc_5: 0.8819 - val_loss: 0.0830 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 1s 192ms/step - loss: 0.2434 - f1_m: 0.9523 - auc_5: 0.8437 - val_loss: 0.1027 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 1s 198ms/step - loss: 0.2386 - f1_m: 0.9456 - auc_5: 0.8594 - val_loss: 0.0741 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 1s 213ms/step - loss: 0.2346 - f1_m: 0.9564 - auc_5: 0.8756 - val_loss: 0.0767 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 40ms/step
# 4/4 [==============================] - 1s 215ms/step - loss: 0.2360 - f1_m: 0.9491 - auc_5: 0.8725 - val_loss: 0.0730 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 1s 214ms/step - loss: 0.2325 - f1_m: 0.9479 - auc_5: 0.8956 - val_loss: 0.0875 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 1s 214ms/step - loss: 0.2357 - f1_m: 0.9574 - auc_5: 0.8769 - val_loss: 0.1033 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 36ms/step
# 4/4 [==============================] - 1s 192ms/step - loss: 0.2375 - f1_m: 0.9522 - auc_5: 0.8644 - val_loss: 0.0792 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 1s 235ms/step - loss: 0.2346 - f1_m: 0.9568 - auc_5: 0.8625 - val_loss: 0.0803 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 1s 249ms/step - loss: 0.2374 - f1_m: 0.9460 - auc_5: 0.8663 - val_loss: 0.0682 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 34ms/step
# 4/4 [==============================] - 1s 193ms/step - loss: 0.2426 - f1_m: 0.9542 - auc_5: 0.8606 - val_loss: 0.0904 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 1s 239ms/step - loss: 0.2362 - f1_m: 0.9510 - auc_5: 0.8719 - val_loss: 0.0770 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 77ms/step
# 4/4 [==============================] - 1s 250ms/step - loss: 0.2342 - f1_m: 0.9513 - auc_5: 0.8694 - val_loss: 0.0835 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 47ms/step
# 4/4 [==============================] - 1s 256ms/step - loss: 0.2339 - f1_m: 0.9544 - auc_5: 0.8675 - val_loss: 0.0816 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 47ms/step
# 4/4 [==============================] - 1s 258ms/step - loss: 0.2360 - f1_m: 0.9607 - auc_5: 0.8706 - val_loss: 0.0834 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 1s 211ms/step - loss: 0.2329 - f1_m: 0.9564 - auc_5: 0.8725 - val_loss: 0.0698 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 1s 217ms/step - loss: 0.2397 - f1_m: 0.9450 - auc_5: 0.8375 - val_loss: 0.0777 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 1s 219ms/step - loss: 0.2352 - f1_m: 0.9508 - auc_5: 0.8675 - val_loss: 0.0700 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 1s 197ms/step - loss: 0.2387 - f1_m: 0.9511 - auc_5: 0.8506 - val_loss: 0.0844 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 35ms/step
# 4/4 [==============================] - 1s 196ms/step - loss: 0.2328 - f1_m: 0.9545 - auc_5: 0.8800 - val_loss: 0.0828 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 37ms/step
# 4/4 [==============================] - 1s 199ms/step - loss: 0.2369 - f1_m: 0.9523 - auc_5: 0.8663 - val_loss: 0.0703 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 1s 216ms/step - loss: 0.2353 - f1_m: 0.9516 - auc_5: 0.8756 - val_loss: 0.0700 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 1s 193ms/step - loss: 0.2366 - f1_m: 0.9444 - auc_5: 0.8706 - val_loss: 0.0909 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 1s 240ms/step - loss: 0.2327 - f1_m: 0.9518 - auc_5: 0.8856 - val_loss: 0.0849 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 1s 215ms/step - loss: 0.2318 - f1_m: 0.9513 - auc_5: 0.8800 - val_loss: 0.0737 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 1s 237ms/step - loss: 0.2350 - f1_m: 0.9496 - auc_5: 0.8731 - val_loss: 0.0697 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# 2/2 [==============================] - 5s 2s/step - loss: 0.1467 - f1_m: 0.9615 - auc_5: 0.9600
# 2/2 [==============================] - 0s 215ms/step
# Models: 100%|██████████| 4/4 [10:59<00:00, 164.90s/it]

# %% [markdown]
# # Plot Table

# %%
#df_last_values_k5 = df_k5.copy()
#df_last_values_k10 = df_k10.copy()
df_last_values_k20 = df_k20.copy()

#for column in df_k5.columns[1:-1]:
    #df_last_values_k5[column] = df_k5[column].apply(lambda x: x[-1] if isinstance(x, list) else x)

#for column in df_k10.columns[1:-1]:
    #df_last_values_k10[column] = df_k10[column].apply(lambda x: x[-1] if isinstance(x, list) else x)

for column in df_k20.columns[1:-1]:
    df_last_values_k20[column] = df_k20[column].apply(lambda x: x[-1] if isinstance(x, list) else x)

# Den DataFrame mit den letzten Werten anzeigen
print("--------- K5 -------")
#print(df_last_values_k5)

print("--------- K10 -------")
#print(df_last_values_k10)

print("--------- K20 -------")
print(df_last_values_k20)
# Out:
# --------- K5 -------
# --------- K10 -------
# --------- K20 -------
#          Model      Loss  F1-Score  Validation Loss  Validation F1-Score  \
# 0        VGG16  0.217976  0.949634         0.092719             1.000000
# 1     ResNet50  0.193701  0.949634         0.065620             1.000000
# 2  InceptionV3  0.482107  0.823260         0.400243             0.941176
# 3     Xception  0.235015  0.949634         0.069702             1.000000
#
#    AUC-ROC VAL  F1-Score Test  Loss Test  AUC-ROC Test
# 0          1.0       0.961538   0.157805      0.956250
# 1          1.0       0.961538   0.141605      0.950625
# 2          1.0       0.944444   0.423118      0.978125
# 3          1.0       0.961538   0.146654      0.960000

# %% [markdown]
# # Plot Diagramm

# %%
for index, row in df_k5.iterrows():
    model_name = row['Model']

    # Loss
    plt.figure(figsize=(10, 8))
    plt.plot(row['Loss'], label='Training Loss')
    plt.plot(row['Validation Loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title(f'{model_name} - Loss')
    plt.legend()
    plt.show()

    # F1-Score
    plt.figure(figsize=(10, 5))
    plt.plot(row['F1-Score'], label ='Training F1-Score')
    plt.plot(row['Validation F1-Score'], label='Validation F1-Score')
    plt.xlabel('Epochs')
    plt.ylabel('F1-Score')
    plt.title(f'{model_name} - F1-Score')
    plt.legend()
    plt.show()

    # AUC-ROC
    plt.figure(figsize=(10, 5))
    plt.plot(row['AUC-ROC VAL'], label ='AUC-ROC VAL')
    plt.xlabel('Epochs')
    plt.ylabel('AUC-ROC')
    plt.title(f'{model_name} - AUC-ROC')
    plt.legend()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-d7519d73fb89> in <cell line: 1>()
# ----> 1 for index, row in df_k5.iterrows():
#       2     model_name = row['Model']
#       3
#       4     # Loss
#       5     plt.figure(figsize=(10, 8))
#
# NameError: name 'df_k5' is not defined

# %%
for index, row in df_k10.iterrows():
    model_name = row['Model']

    # Loss
    plt.figure(figsize=(10, 8))
    plt.plot(row['Loss'], label='Training Loss')
    plt.plot(row['Validation Loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title(f'{model_name} - Loss')
    plt.legend()
    plt.show()

    # F1-Score
    plt.figure(figsize=(10, 5))
    plt.plot(row['F1-Score'], label ='Training F1-Score')
    plt.plot(row['Validation F1-Score'], label='Validation F1-Score')
    plt.xlabel('Epochs')
    plt.ylabel('F1-Score')
    plt.title(f'{model_name} - F1-Score')
    plt.legend()
    plt.show()

    # AUC-ROC
    plt.figure(figsize=(10, 5))
    plt.plot(row['AUC-ROC VAL'], label ='AUC-ROC VAL')
    plt.xlabel('Epochs')
    plt.ylabel('AUC-ROC')
    plt.title(f'{model_name} - AUC-ROC')
    plt.legend()
    plt.show()

# %%
for index, row in df_k20.iterrows():
    model_name = row['Model']

    # Loss
    plt.figure(figsize=(10, 8))
    plt.plot(row['Loss'], label='Training Loss')
    plt.plot(row['Validation Loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title(f'{model_name} - Loss')
    plt.legend()
    plt.show()

    # F1-Score
    plt.figure(figsize=(10, 5))
    plt.plot(row['F1-Score'], label ='Training F1-Score')
    plt.plot(row['Validation F1-Score'], label='Validation F1-Score')
    plt.xlabel('Epochs')
    plt.ylabel('F1-Score')
    plt.title(f'{model_name} - F1-Score')
    plt.legend()
    plt.show()

    # AUC-ROC
    plt.figure(figsize=(10, 5))
    plt.plot(row['AUC-ROC VAL'], label ='AUC-ROC VAL')
    plt.xlabel('Epochs')
    plt.ylabel('AUC-ROC')
    plt.title(f'{model_name} - AUC-ROC')
    plt.legend()
    plt.show()

# %%
# Speicherpfad für die Modelle USECASES
model_directory = "UseCases/"

# Aktuelles Datum und Uhrzeit erhalten USECASES
current_datetime = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
