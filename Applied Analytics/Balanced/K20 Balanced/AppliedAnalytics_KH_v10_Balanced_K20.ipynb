# %% [markdown]
# # Google Drive Connection

# %%
from google.colab import drive
drive.mount('/content/drive')

import sys
import os
sys.path.append('/content/drive/MyDrive/Applied Analytics/Applied-Analytics_Few-Shot-AD/')

from utils import load_local_dataset

#base_path = "/Users/kaihorlacher/Documents/HochschuleAalen/Semester2/03_Machine Learning Research (Data Science)/Applied-Analytics_Few-Shot-AD"
#data_path = base_path + "/data/mechanicalseals"

#base_path_gd = "/content/drive/MyDrive/03 HS Aalen/Applied-Analytics_Few-Shot-AD" # TODO: insert path to your project
#data_path_gd = base_path_gd + "/data/mechanicalseals"

base_path = "/content/drive/MyDrive/Applied Analytics/Applied-Analytics_Few-Shot-AD" # TODO: insert path to your project
data_path = base_path + "/data/mechanicalseals"
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Packages & Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
import random

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers.legacy import Adam, SGD
from keras.preprocessing.image import ImageDataGenerator
from keras.applications import VGG16, ResNet50, InceptionV3, Xception
from keras.applications.vgg16 import preprocess_input
from keras.layers import Flatten, Dense, Dropout, GlobalAveragePooling2D
from keras.callbacks import EarlyStopping
from keras.models import Model, Sequential, clone_model
from keras import backend as K
import datetime


#Pre-processed Images - Input jeweilige Modelle
from tensorflow.keras.applications.vgg16 import preprocess_input as pre_input_vgg16
from tensorflow.keras.applications.resnet50 import preprocess_input as pre_input_resnet50
from tensorflow.keras.applications.inception_v3 import preprocess_input as pre_input_inception_v3
from tensorflow.keras.applications.xception import preprocess_input as pre_input_xception
from sklearn.metrics import balanced_accuracy_score

from sklearn.metrics import make_scorer, f1_score
from sklearn.metrics import roc_auc_score
from tqdm import tqdm
import pandas as pd

from sklearn.metrics import confusion_matrix

import copy
import cv2

from skimage import exposure

# %% [markdown]
# # Data Preprocess & Reproductability

# %%
# Set seed for reproducibility
seed_value = 72
tf.random.set_seed(seed_value)
random.seed(seed_value)
np.random.seed(seed_value)

# %%
#Data splitting
X, y = load_local_dataset(data_path, encoding="integer")
# Out:
# Dataset loaded: 181 images (shape: (224, 224, 3)), belonging to 2 classes.

# %%
# Preprocessing the images with original preprocess of its models

#List with names of the models
list_of_pre_images_models = ["VGG16", "ResNet50", "InceptionV3", "Xception"]

root_x = copy.copy(X)
root_x1 = copy.copy(X)
root_x2 = copy.copy(X)
root_x3 = copy.copy(X)

#Below are the models copied and preprocessed
X_preprocessed_images_vgg16 = copy.copy(X)
X_preprocessed_images_vgg16_rgb = []

for each1 in root_x:
  preprocessed_image1 = pre_input_vgg16(each1)
  X_preprocessed_images_vgg16_rgb.append(preprocessed_image1)

X_preprocessed_images_resnet50_rgb = []


for each2 in root_x1:
  preprocessed_image2 = pre_input_resnet50(each2)
  X_preprocessed_images_resnet50_rgb.append(preprocessed_image2)

X_preprocessed_images_inceptionv3_rgb = []

for each3 in root_x2:
    if each3.shape[2] == 3:
        # Skaling pixel areas from 0 to 255
        each3 = each3 * 255

        # Wende das Preprocessing an
        preprocessed_image_incep_299 = cv2.resize(each3, (299, 299))
        preprocessed_image3 = pre_input_inception_v3(preprocessed_image_incep_299)

        X_preprocessed_images_inceptionv3_rgb.append(preprocessed_image3)
    else:
        print("Error")


X_preprocessed_images_xception_rgb = []
for each4 in root_x3:
    if each4.shape[2] == 3:
        # Skaling pixel areas from 0 to 255
        each4 = each4 * 255

        # Wende das Preprocessing an
        preprocessed_image_xcep_299 = cv2.resize(each4, (299, 299))
        preprocessed_image4 = pre_input_xception(preprocessed_image_xcep_299)

        X_preprocessed_images_xception_rgb.append(preprocessed_image4)
    else:
        print("Error")

# %%
# Checking the images with its preprocess for more understanding (in a 2x2 plot)
fig, axes = plt.subplots(2, 2, figsize=(10, 10))
liste_pic = [X_preprocessed_images_vgg16_rgb[100].astype("uint8"),
             X_preprocessed_images_resnet50_rgb[100].astype("uint8"),
             (X_preprocessed_images_inceptionv3_rgb[100]).astype("uint8"),
             (X_preprocessed_images_xception_rgb[100]).astype("uint8")]

for i, ax in enumerate(axes.flat):
    ax.imshow(liste_pic[i])
    ax.axis('off')

plt.show()

# %%
#Creating splitted lists for X and y for each model because of its different preprocess method
X_undamaged_vgg16 = []
y_undamaged_vgg16 = []
X_damaged_vgg16 = []
y_damaged_vgg16 = []

X_undamaged_resnet50 = []
y_undamaged_resnet50 = []
X_damaged_resnet50 = []
y_damaged_resnet50 = []

X_undamaged_inceptionv3= []
y_undamaged_inceptionv3 = []
X_damaged_inceptionv3 = []
y_damaged_inceptionv3 = []

X_undamaged_xception = []
y_undamaged_xception = []
X_damaged_xception = []
y_damaged_xception = []

#Taking all data of X and y and iterating with for-clause to get the right split of undamaged and damaged
sample_count = 0


for element in X:
  #print(y[sample_count])
  #print(X[sample_count])

  if y[sample_count] == 1:
    X_damaged_vgg16.append(X_preprocessed_images_vgg16_rgb[sample_count])
    y_damaged_vgg16.append(y[sample_count])

    X_damaged_resnet50.append(X_preprocessed_images_resnet50_rgb[sample_count])
    y_damaged_resnet50.append(y[sample_count])

    X_damaged_inceptionv3.append(X_preprocessed_images_inceptionv3_rgb[sample_count])
    y_damaged_inceptionv3.append(y[sample_count])

    X_damaged_xception.append(X_preprocessed_images_xception_rgb[sample_count])
    y_damaged_xception.append(y[sample_count])

  elif y[sample_count] == 0:
    X_undamaged_vgg16.append(X_preprocessed_images_vgg16_rgb[sample_count])
    y_undamaged_vgg16.append(y[sample_count])

    X_undamaged_resnet50.append(X_preprocessed_images_resnet50_rgb[sample_count])
    y_undamaged_resnet50.append(y[sample_count])

    X_undamaged_inceptionv3.append(X_preprocessed_images_inceptionv3_rgb[sample_count])
    y_undamaged_inceptionv3.append(y[sample_count])

    X_undamaged_xception.append(X_preprocessed_images_xception_rgb[sample_count])
    y_undamaged_xception.append(y[sample_count])

  sample_count+=1

print("The amount of undamaged images are: " + str(len(X_undamaged_vgg16)) + " inclusive the same number of labels:  " + str(len(y_undamaged_vgg16)))
print("The amount of damaged images are: " + str(len(X_damaged_vgg16)) + " inclusive the same number of labels: " + str(len(y_damaged_vgg16)))
# Out:
# The amount of undamaged images are: 93 inclusive the same number of labels:  93
# The amount of damaged images are: 88 inclusive the same number of labels: 88

# %% [markdown]
# # Prepare Training/Validation/Test

# %% [markdown]
# # K-Sharings

# %% [markdown]
# Below we are creating the K-Shot datasets for each models separated for my clearness

# %% [markdown]
# **VGG16**

# %%
# -----------  Traindata K5  -------------

normal_data_vgg16_k5 = np.array(X_undamaged_vgg16[:5])
anomaly_data_vgg16_k5 = np.array(X_damaged_vgg16[:5])

train_data_vgg16_k5 = np.concatenate((normal_data_vgg16_k5, anomaly_data_vgg16_k5), axis=0)
train_labels_vgg16_k5 = np.concatenate((np.zeros(len(normal_data_vgg16_k5)), np.ones(len(anomaly_data_vgg16_k5))))

# Validation K5
normal_val_data_vgg16_k5 = np.array(X_undamaged_vgg16[61:63])
anomaly_val_data_vgg16_k5 = np.array(X_damaged_vgg16[56:58])

val_data_vgg16_k5 = np.concatenate((normal_val_data_vgg16_k5, anomaly_val_data_vgg16_k5), axis=0)
val_labels_vgg16_k5 = np.concatenate((np.zeros(len(normal_val_data_vgg16_k5)), np.ones(len(anomaly_val_data_vgg16_k5))))

# Test K5
normal_test_data_vgg16_k5 = np.array(X_undamaged_vgg16[63:93])
anomaly_test_data_vgg16_k5 = np.array(X_damaged_vgg16[58:88])

test_data_vgg16_k5 = np.concatenate((normal_test_data_vgg16_k5, anomaly_test_data_vgg16_k5), axis=0)
test_labels_vgg16_k5 = np.concatenate((np.zeros(len(normal_test_data_vgg16_k5)), np.ones(len(anomaly_test_data_vgg16_k5))))


# -----------  Traindata K10  -------------

normal_data_vgg16_k10 = np.array(X_undamaged_vgg16[:10])
anomaly_data_vgg16_k10 = np.array(X_damaged_vgg16[:10])

train_data_vgg16_k10 = np.concatenate((normal_data_vgg16_k10, anomaly_data_vgg16_k10), axis=0)
train_labels_vgg16_k10 = np.concatenate((np.zeros(len(normal_data_vgg16_k10)), np.ones(len(anomaly_data_vgg16_k10))))

# Validation K10
normal_val_data_vgg16_k10 = np.array(X_undamaged_vgg16[59:63])
anomaly_val_data_vgg16_k10 = np.array(X_damaged_vgg16[54:58])

val_data_vgg16_k10 = np.concatenate((normal_val_data_vgg16_k10, anomaly_val_data_vgg16_k10), axis=0)
val_labels_vgg16_k10 = np.concatenate((np.zeros(len(normal_val_data_vgg16_k10)), np.ones(len(anomaly_val_data_vgg16_k10))))

# Test K10
normal_test_data_vgg16_k10 = np.array(X_undamaged_vgg16[63:93])
anomaly_test_data_vgg16_k10 = np.array(X_damaged_vgg16[58:88])

test_data_vgg16_k10 = np.concatenate((normal_test_data_vgg16_k10, anomaly_test_data_vgg16_k10), axis=0)
test_labels_vgg16_k10 = np.concatenate((np.zeros(len(normal_test_data_vgg16_k10)), np.ones(len(anomaly_test_data_vgg16_k10))))

# -----------  Traindata K20  -------------
normal_data_vgg16_k20 = np.array(X_undamaged_vgg16[:20])
anomaly_data_vgg16_k20 = np.array(X_damaged_vgg16[:20])

train_data_vgg16_k20 = np.concatenate((normal_data_vgg16_k20, anomaly_data_vgg16_k20), axis=0)
train_labels_vgg16_k20 = np.concatenate((np.zeros(len(normal_data_vgg16_k20)), np.ones(len(anomaly_data_vgg16_k20))))

# Validation K20
normal_val_data_vgg16_k20 = np.array(X_undamaged_vgg16[55:63])
anomaly_val_data_vgg16_k20 = np.array(X_damaged_vgg16[50:58])

val_data_vgg16_k20 = np.concatenate((normal_val_data_vgg16_k20, anomaly_val_data_vgg16_k20), axis=0)
val_labels_vgg16_k20 = np.concatenate((np.zeros(len(normal_val_data_vgg16_k20)), np.ones(len(anomaly_val_data_vgg16_k20))))

# Test K20
normal_test_data_vgg16_k20 = np.array(X_undamaged_vgg16[63:93])
anomaly_test_data_vgg16_k20 = np.array(X_damaged_vgg16[58:88])

test_data_vgg16_k20 = np.concatenate((normal_test_data_vgg16_k20, anomaly_test_data_vgg16_k20), axis=0)
test_labels_vgg16_k20 = np.concatenate((np.zeros(len(normal_test_data_vgg16_k20)), np.ones(len(anomaly_test_data_vgg16_k20))))

# %% [markdown]
# **ResNet50**

# %%
# -----------  Traindata K5  -------------

normal_data_resnet50_k5 = np.array(X_undamaged_resnet50[:5])
anomaly_data_resnet50_k5 = np.array(X_damaged_resnet50[:5])

train_data_resnet50_k5 = np.concatenate((normal_data_resnet50_k5, anomaly_data_resnet50_k5), axis=0)
train_labels_resnet50_k5 = np.concatenate((np.zeros(len(normal_data_resnet50_k5)), np.ones(len(anomaly_data_resnet50_k5))))

# Validation K5
normal_val_data_resnet50_k5 = np.array(X_undamaged_resnet50[61:63])
anomaly_val_data_resnet50_k5 = np.array(X_damaged_resnet50[56:58])

val_data_resnet50_k5 = np.concatenate((normal_val_data_resnet50_k5, anomaly_val_data_resnet50_k5), axis=0)
val_labels_resnet50_k5 = np.concatenate((np.zeros(len(normal_val_data_resnet50_k5)), np.ones(len(anomaly_val_data_resnet50_k5))))

# Test K5
normal_test_data_resnet50_k5 = np.array(X_undamaged_resnet50[63:93])
anomaly_test_data_resnet50_k5 = np.array(X_damaged_resnet50[58:88])

test_data_resnet50_k5 = np.concatenate((normal_test_data_resnet50_k5, anomaly_test_data_resnet50_k5), axis=0)
test_labels_resnet50_k5 = np.concatenate((np.zeros(len(normal_test_data_resnet50_k5)), np.ones(len(anomaly_test_data_resnet50_k5))))

# -----------  Traindata K10  -------------

normal_data_resnet50_k10 = np.array(X_undamaged_resnet50[:10])
anomaly_data_resnet50_k10 = np.array(X_damaged_resnet50[:10])

train_data_resnet50_k10 = np.concatenate((normal_data_resnet50_k10, anomaly_data_resnet50_k10), axis=0)
train_labels_resnet50_k10 = np.concatenate((np.zeros(len(normal_data_resnet50_k10)), np.ones(len(anomaly_data_resnet50_k10))))

# Validation K10
normal_val_data_resnet50_k10 = np.array(X_undamaged_resnet50[59:63])
anomaly_val_data_resnet50_k10 = np.array(X_damaged_resnet50[54:58])

val_data_resnet50_k10 = np.concatenate((normal_val_data_resnet50_k10, anomaly_val_data_resnet50_k10), axis=0)
val_labels_resnet50_k10 = np.concatenate((np.zeros(len(normal_val_data_resnet50_k10)), np.ones(len(anomaly_val_data_resnet50_k10))))

# Test K10 20%
normal_test_data_resnet50_k10 = np.array(X_undamaged_resnet50[63:93])
anomaly_test_data_resnet50_k10 = np.array(X_damaged_resnet50[58:88])

test_data_resnet50_k10 = np.concatenate((normal_test_data_resnet50_k10, anomaly_test_data_resnet50_k10), axis=0)
test_labels_resnet50_k10 = np.concatenate((np.zeros(len(normal_test_data_resnet50_k10)), np.ones(len(anomaly_test_data_resnet50_k10))))

# -----------  Traindata K20  -------------

normal_data_resnet50_k20 = np.array(X_undamaged_resnet50[:20])
anomaly_data_resnet50_k20 = np.array(X_damaged_resnet50[:20])

train_data_resnet50_k20 = np.concatenate((normal_data_resnet50_k20, anomaly_data_resnet50_k20), axis=0)
train_labels_resnet50_k20 = np.concatenate((np.zeros(len(normal_data_resnet50_k20)), np.ones(len(anomaly_data_resnet50_k20))))

# Validation K20
normal_val_data_resnet50_k20 = np.array(X_undamaged_resnet50[55:63])
anomaly_val_data_resnet50_k20 = np.array(X_damaged_resnet50[50:58])

val_data_resnet50_k20 = np.concatenate((normal_val_data_resnet50_k20, anomaly_val_data_resnet50_k20), axis=0)
val_labels_resnet50_k20 = np.concatenate((np.zeros(len(normal_val_data_resnet50_k20)), np.ones(len(anomaly_val_data_resnet50_k20))))

# Test K20
normal_test_data_resnet50_k20 = np.array(X_undamaged_resnet50[63:93])
anomaly_test_data_resnet50_k20 = np.array(X_damaged_resnet50[58:88])

test_data_resnet50_k20 = np.concatenate((normal_test_data_resnet50_k20, anomaly_test_data_resnet50_k20), axis=0)
test_labels_resnet50_k20 = np.concatenate((np.zeros(len(normal_test_data_resnet50_k20)), np.ones(len(anomaly_test_data_resnet50_k20))))

# %% [markdown]
# **InceptionV3**

# %%
# -----------  Traindata K5  -------------

normal_data_inceptionv3_k5 = np.array(X_undamaged_inceptionv3[:5])
anomaly_data_inceptionv3_k5 = np.array(X_damaged_inceptionv3[:5])

train_data_inceptionv3_k5 = np.concatenate((normal_data_inceptionv3_k5, anomaly_data_inceptionv3_k5), axis=0)
train_labels_inceptionv3_k5 = np.concatenate((np.zeros(len(normal_data_inceptionv3_k5)), np.ones(len(anomaly_data_inceptionv3_k5))))

# Validation K5
normal_val_data_inceptionv3_k5 = np.array(X_undamaged_inceptionv3[61:63])
anomaly_val_data_inceptionv3_k5 = np.array(X_damaged_inceptionv3[56:58])

val_data_inceptionv3_k5 = np.concatenate((normal_val_data_inceptionv3_k5, anomaly_val_data_inceptionv3_k5), axis=0)
val_labels_inceptionv3_k5 = np.concatenate((np.zeros(len(normal_val_data_inceptionv3_k5)), np.ones(len(anomaly_val_data_inceptionv3_k5))))

# Test K5
normal_test_data_inceptionv3_k5 = np.array(X_undamaged_inceptionv3[63:93])
anomaly_test_data_inceptionv3_k5 = np.array(X_damaged_inceptionv3[58:88])

test_data_inceptionv3_k5 = np.concatenate((normal_test_data_inceptionv3_k5, anomaly_test_data_inceptionv3_k5), axis=0)
test_labels_inceptionv3_k5 = np.concatenate((np.zeros(len(normal_test_data_inceptionv3_k5)), np.ones(len(anomaly_test_data_inceptionv3_k5))))

# -----------  Traindata K10  -------------

normal_data_inceptionv3_k10 = np.array(X_undamaged_inceptionv3[:10])
anomaly_data_inceptionv3_k10 = np.array(X_damaged_inceptionv3[:10])

train_data_inceptionv3_k10 = np.concatenate((normal_data_inceptionv3_k10, anomaly_data_inceptionv3_k10), axis=0)
train_labels_inceptionv3_k10 = np.concatenate((np.zeros(len(normal_data_inceptionv3_k10)), np.ones(len(anomaly_data_inceptionv3_k10))))

# Validation K10
normal_val_data_inceptionv3_k10 = np.array(X_undamaged_inceptionv3[59:63])
anomaly_val_data_inceptionv3_k10 = np.array(X_damaged_inceptionv3[54:58])

val_data_inceptionv3_k10 = np.concatenate((normal_val_data_inceptionv3_k10, anomaly_val_data_inceptionv3_k10), axis=0)
val_labels_inceptionv3_k10 = np.concatenate((np.zeros(len(normal_val_data_inceptionv3_k10)), np.ones(len(anomaly_val_data_inceptionv3_k10))))

# Test K10
normal_test_data_inceptionv3_k10 = np.array(X_undamaged_inceptionv3[63:93])
anomaly_test_data_inceptionv3_k10 = np.array(X_damaged_inceptionv3[58:88])

test_data_inceptionv3_k10 = np.concatenate((normal_test_data_inceptionv3_k10, anomaly_test_data_inceptionv3_k10), axis=0)
test_labels_inceptionv3_k10 = np.concatenate((np.zeros(len(normal_test_data_inceptionv3_k10)), np.ones(len(anomaly_test_data_inceptionv3_k10))))

# -----------  Traindata K20  -------------

normal_data_inceptionv3_k20 = np.array(X_undamaged_inceptionv3[:20])
anomaly_data_inceptionv3_k20 = np.array(X_damaged_inceptionv3[:20])

train_data_inceptionv3_k20 = np.concatenate((normal_data_inceptionv3_k20, anomaly_data_inceptionv3_k20), axis=0)
train_labels_inceptionv3_k20 = np.concatenate((np.zeros(len(normal_data_inceptionv3_k20)), np.ones(len(anomaly_data_inceptionv3_k20))))

# Validation K20
normal_val_data_inceptionv3_k20 = np.array(X_undamaged_inceptionv3[55:63])
anomaly_val_data_inceptionv3_k20 = np.array(X_damaged_inceptionv3[50:58])

val_data_inceptionv3_k20 = np.concatenate((normal_val_data_inceptionv3_k20, anomaly_val_data_inceptionv3_k20), axis=0)
val_labels_inceptionv3_k20 = np.concatenate((np.zeros(len(normal_val_data_inceptionv3_k20)), np.ones(len(anomaly_val_data_inceptionv3_k20))))

# Test K20
normal_test_data_inceptionv3_k20 = np.array(X_undamaged_inceptionv3[63:93])
anomaly_test_data_inceptionv3_k20 = np.array(X_damaged_inceptionv3[58:88])

test_data_inceptionv3_k20 = np.concatenate((normal_test_data_inceptionv3_k20, anomaly_test_data_inceptionv3_k20), axis=0)
test_labels_inceptionv3_k20 = np.concatenate((np.zeros(len(normal_test_data_inceptionv3_k20)), np.ones(len(anomaly_test_data_inceptionv3_k20))))

# %% [markdown]
# **Xception**

# %%
# Traindata K5
normal_data_xception_k5 = np.array(X_undamaged_xception[:5])
anomaly_data_xception_k5 = np.array(X_damaged_xception[:5])

train_data_xception_k5 = np.concatenate((normal_data_xception_k5, anomaly_data_xception_k5), axis=0)
train_labels_xception_k5 = np.concatenate((np.zeros(len(normal_data_xception_k5)), np.ones(len(anomaly_data_xception_k5))))

# Validation K5
normal_val_data_xception_k5 = np.array(X_undamaged_xception[61:63])
anomaly_val_data_xception_k5 = np.array(X_damaged_xception[56:58])

val_data_xception_k5 = np.concatenate((normal_val_data_xception_k5, anomaly_val_data_xception_k5), axis=0)
val_labels_xception_k5 = np.concatenate((np.zeros(len(normal_val_data_xception_k5)), np.ones(len(anomaly_val_data_xception_k5))))

# Test K5
normal_test_data_xception_k5 = np.array(X_undamaged_xception[63:93])
anomaly_test_data_xception_k5 = np.array(X_damaged_xception[58:88])

test_data_xception_k5 = np.concatenate((normal_test_data_xception_k5, anomaly_test_data_xception_k5), axis=0)
test_labels_xception_k5 = np.concatenate((np.zeros(len(normal_test_data_xception_k5)), np.ones(len(anomaly_test_data_xception_k5))))

# Traindata K10
normal_data_xception_k10 = np.array(X_undamaged_xception[:10])
anomaly_data_xception_k10 = np.array(X_damaged_xception[:10])

train_data_xception_k10 = np.concatenate((normal_data_xception_k10, anomaly_data_xception_k10), axis=0)
train_labels_xception_k10 = np.concatenate((np.zeros(len(normal_data_xception_k10)), np.ones(len(anomaly_data_xception_k10))))

# Validation K10
normal_val_data_xception_k10 = np.array(X_undamaged_xception[59:63])
anomaly_val_data_xception_k10 = np.array(X_damaged_xception[54:58])

val_data_xception_k10 = np.concatenate((normal_val_data_xception_k10, anomaly_val_data_xception_k10), axis=0)
val_labels_xception_k10 = np.concatenate((np.zeros(len(normal_val_data_xception_k10)), np.ones(len(anomaly_val_data_xception_k10))))

# Test K10
normal_test_data_xception_k10 = np.array(X_undamaged_xception[63:93])
anomaly_test_data_xception_k10 = np.array(X_damaged_xception[58:88])

test_data_xception_k10 = np.concatenate((normal_test_data_xception_k10, anomaly_test_data_xception_k10), axis=0)
test_labels_xception_k10 = np.concatenate((np.zeros(len(normal_test_data_xception_k10)), np.ones(len(anomaly_test_data_xception_k10))))

# Traindata K20
normal_data_xception_k20 = np.array(X_undamaged_xception[:20])
anomaly_data_xception_k20 = np.array(X_damaged_xception[:20])

train_data_xception_k20 = np.concatenate((normal_data_xception_k20, anomaly_data_xception_k20), axis=0)
train_labels_xception_k20 = np.concatenate((np.zeros(len(normal_data_xception_k20)), np.ones(len(anomaly_data_xception_k20))))

# Validation K20
normal_val_data_xception_k20 = np.array(X_undamaged_xception[55:63])
anomaly_val_data_xception_k20 = np.array(X_damaged_xception[50:58])

val_data_xception_k20 = np.concatenate((normal_val_data_xception_k20, anomaly_val_data_xception_k20), axis=0)
val_labels_xception_k20 = np.concatenate((np.zeros(len(normal_val_data_xception_k20)), np.ones(len(anomaly_val_data_xception_k20))))

# Test K20
normal_test_data_xception_k20 = np.array(X_undamaged_xception[63:93])
anomaly_test_data_xception_k20 = np.array(X_damaged_xception[58:88])

test_data_xception_k20 = np.concatenate((normal_test_data_xception_k20, anomaly_test_data_xception_k20), axis=0)
test_labels_xception_k20 = np.concatenate((np.zeros(len(normal_test_data_xception_k20)), np.ones(len(anomaly_test_data_xception_k20))))

# %% [markdown]
# # Define Metrics

# %%
def balanced_accuracy(y_true, y_pred):
    return balanced_accuracy_score(y_true, y_pred)



def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

from tensorflow.keras.callbacks import Callback

class AUCROCCallback(Callback):
    def __init__(self, validation_data):
        super(AUCROCCallback, self).__init__()
        self.validation_data = validation_data

    def on_epoch_end(self, epoch, logs=None):
        x_val, y_val = self.validation_data
        y_pred = self.model.predict(x_val)
        auc_roc = roc_auc_score(y_val, y_pred)
        logs['val_auc_roc'] = auc_roc

# %% [markdown]
# # Tranfer Learning - Models VGG16, ResNet50, InceptionV3 & Xception

# %%
#Hypperparameter etc.
learning_rate = 0.0001
optimizer = Adam(learning_rate=learning_rate)
opt = SGD(learning_rate=0.0001, momentum=0.9)

num_classes = 1
dropout_rate = 0.1

# %% [markdown]
# **Below we are mporting the weights of imagenet, freezing them and adding a new modified top for case**

# %% [markdown]
# # VGG16

# %%
vgg_base = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3), pooling='max')
vgg_base.trainable = False

# VGG16 -
vgg_model = Sequential([
    vgg_base,
    Flatten(),
    Dense(512, activation='relu'),
    #Dropout(dropout_rate),
    Dense(256, activation='relu'),
    #Dropout(dropout_rate),
    Dense(num_classes, activation='sigmoid')
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %% [markdown]
# # Resnet50

# %%
resnet_base = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3), pooling='max')
resnet_base.trainable = False

# ResNet50
resnet_model = Sequential([
    resnet_base,
    Flatten(),
    Dense(512, activation='relu'),
    #Dropout(dropout_rate),
    Dense(256, activation='relu'),
    #Dropout(dropout_rate),
    Dense(num_classes, activation='sigmoid')
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step

# %% [markdown]
# # InceptionV3

# %%
optimizer_other = Adam(learning_rate=0.0001)
inception_base = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3),  pooling='max')
inception_base.trainable = False

inception_model = Sequential([
    inception_base,
    Flatten(),
    Dense(512, activation='relu'),
    #Dropout(dropout_rate),
    Dense(256, activation='relu'),
    #Dropout(dropout_rate),
    Dense(num_classes, activation='sigmoid')
])



inception_model.compile(loss='binary_crossentropy', optimizer=optimizer_other, metrics=[f1_m, tf.keras.metrics.AUC()])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 1s 0us/step

# %% [markdown]
# # Xception

# %%
optimizer_other = Adam(learning_rate=0.0001)
xception_base = Xception(weights='imagenet', include_top=False, input_shape=(299, 299, 3), pooling='max')
xception_base.trainable = False

xception_model = Sequential([
    xception_base,
    Flatten(),
    Dense(512, activation='relu'),
    #Dropout(dropout_rate),
    Dense(256, activation='relu'),
    #Dropout(dropout_rate),
    Dense(num_classes, activation='sigmoid')
])
xception_model.compile(loss='binary_crossentropy', optimizer=optimizer_other, metrics=[f1_m, tf.keras.metrics.AUC()])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 0s 0us/step

# %% [markdown]
# # Batch, Epochs & Early Stopping

# %%
# Define early stop
patience = 30
early_stopping = EarlyStopping(monitor='val_loss', patience=patience, mode='auto', restore_best_weights=True)


# Params
epochs = 200
batch_size = 16

# %% [markdown]
# # Train/Test Models

# %% [markdown]
# # K5 Train/Test

# %%
models = [vgg_model, resnet_model, inception_model, xception_model]
model_names = ["VGG16", "ResNet50", "InceptionV3", "Xception"]
scoring_models_k5 = []

# Progressbar
progress_bar = tqdm(total=len(models), desc='Models', position=0)
current_datetime = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

for model, model_name in zip(models, model_names):

    if model_name == "VGG16":
      reset_model_vgg16 = clone_model(vgg_model)
      reset_model_vgg16.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=[f1_m, tf.keras.metrics.AUC()])
      ### Training on Data K5
      history_vgg16_k5 = reset_model_vgg16.fit(train_data_vgg16_k5, train_labels_vgg16_k5, validation_data=(val_data_vgg16_k5, val_labels_vgg16_k5),
                          batch_size=batch_size, epochs=epochs, callbacks=[early_stopping, AUCROCCallback(validation_data=(val_data_vgg16_k5, val_labels_vgg16_k5))])


      formating_results_k5 = {}
      formating_results_k5["Model"] = model_name
      formating_results_k5["Loss"] = history_vgg16_k5.history["loss"]
      formating_results_k5["F1-Score"] = history_vgg16_k5.history["f1_m"]
      formating_results_k5["Validation Loss"] = history_vgg16_k5.history["val_loss"]
      formating_results_k5["Validation F1-Score"] = history_vgg16_k5.history["val_f1_m"]
      formating_results_k5["AUC-ROC VAL"] = history_vgg16_k5.history['val_auc_roc']

      loss_evaluation_vgg16, f1_m_evaluation_vgg16, auc_roc_evaluation_vgg16 = reset_model_vgg16.evaluate(test_data_vgg16_k5, test_labels_vgg16_k5, verbose=1)
      formating_results_k5["F1-Score Test"] = f1_m_evaluation_vgg16
      formating_results_k5["Loss Test"] = loss_evaluation_vgg16
      formating_results_k5["AUC-ROC Test"] = auc_roc_evaluation_vgg16

      scoring_models_k5.append(formating_results_k5)

      y_pred = reset_model_vgg16.predict(test_data_vgg16_k5)
      y_pred = np.argmax(y_pred, axis=1)

      cm = confusion_matrix(test_labels_vgg16_k5, y_pred)
      cm_float = cm.astype(float)  # Datentyp auf float ändern

      try:
          cm_filename = "ConfusionMatrix/ConfusionMatrix_k5_" + model_name + "_" + current_datetime + ".csv"
          np.savetxt(cm_filename, cm_float, delimiter=",", fmt='%.4f')  # Datentyp und Format angeben
      except:
          continue

      ### Progressbar updating
      progress_bar.update(1)
      try:
        filename = "Models/Model_k5_" + model_name + "_" + current_datetime + ".h5"
        # Modell speichern
        reset_model_vgg16.save(filename)
      except:
        continue




    if model_name == "ResNet50":
      reset_model_resnet50 = clone_model(resnet_model)
      reset_model_resnet50.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=[f1_m, tf.keras.metrics.AUC()])
      ### Training on K5
      history_resnet50_k5 = reset_model_resnet50.fit(train_data_resnet50_k5, train_labels_resnet50_k5, validation_data=(val_data_resnet50_k5, val_labels_resnet50_k5),
                          batch_size=batch_size, epochs=epochs, callbacks=[early_stopping, AUCROCCallback(validation_data=(val_data_resnet50_k5, val_labels_resnet50_k5))])

      formating_results_k5 = {}
      formating_results_k5["Model"] = model_name
      formating_results_k5["Loss"] = history_resnet50_k5.history["loss"]
      formating_results_k5["F1-Score"] = history_resnet50_k5.history["f1_m"]
      formating_results_k5["Validation Loss"] = history_resnet50_k5.history["val_loss"]
      formating_results_k5["Validation F1-Score"] = history_resnet50_k5.history["val_f1_m"]
      formating_results_k5["AUC-ROC VAL"] = history_resnet50_k5.history['val_auc_roc']

      loss_evaluation_resnet50, f1_m_evaluation_resnet50, auc_roc_evaluation_resnet50 = reset_model_resnet50.evaluate(test_data_resnet50_k5, test_labels_resnet50_k5, verbose=1)
      formating_results_k5["F1-Score Test"] = f1_m_evaluation_resnet50
      formating_results_k5["Loss Test"] = loss_evaluation_resnet50
      formating_results_k5["AUC-ROC Test"] = auc_roc_evaluation_resnet50


      scoring_models_k5.append(formating_results_k5)

      y_pred = reset_model_resnet50.predict(test_data_resnet50_k5)
      y_pred = np.argmax(y_pred, axis=1)

      cm = confusion_matrix(test_labels_resnet50_k5, y_pred)
      cm_float = cm.astype(float)

      try:
          cm_filename = "ConfusionMatrix/ConfusionMatrix_k5_" + model_name + "_" + current_datetime + ".csv"
          np.savetxt(cm_filename, cm_float, delimiter=",", fmt='%.4f')
      except:
          continue

      progress_bar.update(1)

      try:
        filename = "Models/Model_k5_" + model_name + "_" + current_datetime + ".h5"
        # Modell speichern
        reset_model_resnet50.save(filename)
      except:
        continue



    if model_name == "InceptionV3":
      reset_model_inceptionv3 = clone_model(inception_model)
      reset_model_inceptionv3.compile(loss='binary_crossentropy', optimizer=optimizer_other, metrics=[f1_m, tf.keras.metrics.AUC()])
      ###Training on K5
      history_inceptionv3_k5 = reset_model_inceptionv3.fit(train_data_inceptionv3_k5, train_labels_inceptionv3_k5,
                                validation_data=(val_data_inceptionv3_k5, val_labels_inceptionv3_k5),
                          batch_size=batch_size, epochs=epochs, callbacks=[early_stopping, AUCROCCallback(validation_data=(val_data_inceptionv3_k5, val_labels_inceptionv3_k5))])

      formating_results_k5 = {}
      formating_results_k5["Model"] = model_name
      formating_results_k5["Loss"] = history_inceptionv3_k5.history["loss"]
      formating_results_k5["F1-Score"] = history_inceptionv3_k5.history["f1_m"]
      formating_results_k5["Validation Loss"] = history_inceptionv3_k5.history["val_loss"]
      formating_results_k5["Validation F1-Score"] = history_inceptionv3_k5.history["val_f1_m"]
      formating_results_k5["AUC-ROC VAL"] = history_inceptionv3_k5.history['val_auc_roc']

      loss_evaluation_inceptionv3, f1_m_evaluation_inceptionv3, auc_roc_evaluation_inceptionv3 = reset_model_inceptionv3.evaluate(test_data_inceptionv3_k5, test_labels_inceptionv3_k5, verbose=1)
      formating_results_k5["F1-Score Test"] = f1_m_evaluation_inceptionv3
      formating_results_k5["Loss Test"] = loss_evaluation_inceptionv3
      formating_results_k5["AUC-ROC Test"] = auc_roc_evaluation_inceptionv3

      scoring_models_k5.append(formating_results_k5)

      y_pred = reset_model_inceptionv3.predict(test_data_inceptionv3_k5)
      y_pred = np.argmax(y_pred, axis=1)

      cm = confusion_matrix(test_labels_inceptionv3_k5, y_pred)
      cm_float = cm.astype(float)

      try:
          cm_filename = "ConfusionMatrix/ConfusionMatrix_k5_" + model_name + "_" + current_datetime + ".csv"
          np.savetxt(cm_filename, cm_float, delimiter=",", fmt='%.4f')
      except:
          continue

      progress_bar.update(1)

      try:
        filename = "Models/Model_k5_" + model_name + "_" + current_datetime + ".h5"
        # Modell speichern
        reset_model_inceptionv3.save(filename)
      except:
        continue


    if model_name == "Xception":
      reset_model_xception = clone_model(model)
      reset_model_xception.compile(loss='binary_crossentropy', optimizer=optimizer_other, metrics=[f1_m, tf.keras.metrics.AUC()])

      ### Training on K5
      history_xception_k5 = reset_model_xception.fit(train_data_xception_k5, train_labels_xception_k5,
                                validation_data=(val_data_xception_k5, val_labels_xception_k5),
                          batch_size=batch_size, epochs=epochs, callbacks=[early_stopping, AUCROCCallback(validation_data=(val_data_xception_k5, val_labels_xception_k5))])

      formating_results_k5 = {}
      formating_results_k5["Model"] = model_name
      formating_results_k5["Loss"] = history_xception_k5.history["loss"]
      formating_results_k5["F1-Score"] = history_xception_k5.history["f1_m"]
      formating_results_k5["Validation Loss"] = history_xception_k5.history["val_loss"]
      formating_results_k5["Validation F1-Score"] = history_xception_k5.history["val_f1_m"]
      formating_results_k5["AUC-ROC VAL"] = history_xception_k5.history['val_auc_roc']

      loss_evaluation_xception, f1_m_evaluation_xception, auc_roc_evaluation_xception  = reset_model_xception.evaluate(test_data_xception_k5, test_labels_xception_k5, verbose=1)
      formating_results_k5["F1-Score Test"] = f1_m_evaluation_xception
      formating_results_k5["Loss Test"] = loss_evaluation_xception
      formating_results_k5["AUC-ROC Test"] = auc_roc_evaluation_xception

      scoring_models_k5.append(formating_results_k5)


      y_pred = reset_model_xception.predict(test_data_xception_k5)
      y_pred = np.argmax(y_pred, axis=1)

      cm = confusion_matrix(test_labels_xception_k5, y_pred)
      cm_float = cm.astype(float)

      try:
          cm_filename = "ConfusionMatrix/ConfusionMatrix_k5_" + model_name + "_" + current_datetime + ".csv"
          np.savetxt(cm_filename, cm_float, delimiter=",", fmt='%.4f')
      except:
          continue

      progress_bar.update(1)

      try:
        filename = "Models/Model_k5_" + model_name + "_" + current_datetime + ".h5"
        reset_model_xception.save(filename)
      except:
        continue


# Progressbar close
progress_bar.close()

# Dataframe with scorings
df_k5 = pd.DataFrame(scoring_models_k5)
df_k5.to_csv("model_metrics_k5_balanced" + current_datetime, index=False)
# Out:
# Models:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 1/200
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 16s 16s/step - loss: 0.7081 - f1_m: 0.0000e+00 - auc_2: 1.0000 - val_loss: 0.6829 - val_f1_m: 0.0000e+00 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 2/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 216ms/step - loss: 0.6817 - f1_m: 0.0000e+00 - auc_2: 1.0000 - val_loss: 0.6816 - val_f1_m: 0.6667 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 3/200
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 243ms/step - loss: 0.6794 - f1_m: 0.6667 - auc_2: 1.0000 - val_loss: 0.6853 - val_f1_m: 0.6667 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 4/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 214ms/step - loss: 0.6830 - f1_m: 0.6667 - auc_2: 1.0000 - val_loss: 0.6836 - val_f1_m: 0.6667 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 5/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 213ms/step - loss: 0.6814 - f1_m: 0.6667 - auc_2: 1.0000 - val_loss: 0.6776 - val_f1_m: 0.6667 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 6/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 212ms/step - loss: 0.6756 - f1_m: 0.6667 - auc_2: 1.0000 - val_loss: 0.6718 - val_f1_m: 0.6667 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 7/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 205ms/step - loss: 0.6698 - f1_m: 0.6667 - auc_2: 1.0000 - val_loss: 0.6689 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 8/200
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 251ms/step - loss: 0.6670 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.6682 - val_f1_m: 0.0000e+00 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 9/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 208ms/step - loss: 0.6663 - f1_m: 0.0000e+00 - auc_2: 1.0000 - val_loss: 0.6680 - val_f1_m: 0.0000e+00 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 10/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 217ms/step - loss: 0.6660 - f1_m: 0.0000e+00 - auc_2: 1.0000 - val_loss: 0.6667 - val_f1_m: 0.0000e+00 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 11/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 248ms/step - loss: 0.6648 - f1_m: 0.0000e+00 - auc_2: 1.0000 - val_loss: 0.6642 - val_f1_m: 0.0000e+00 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 12/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 212ms/step - loss: 0.6622 - f1_m: 0.0000e+00 - auc_2: 1.0000 - val_loss: 0.6611 - val_f1_m: 0.0000e+00 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 13/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 251ms/step - loss: 0.6589 - f1_m: 0.0000e+00 - auc_2: 1.0000 - val_loss: 0.6584 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 14/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 246ms/step - loss: 0.6560 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.6566 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 15/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 255ms/step - loss: 0.6539 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.6554 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 16/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 209ms/step - loss: 0.6525 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.6540 - val_f1_m: 0.6667 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 17/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 211ms/step - loss: 0.6510 - f1_m: 0.6667 - auc_2: 1.0000 - val_loss: 0.6518 - val_f1_m: 0.6667 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 18/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 254ms/step - loss: 0.6488 - f1_m: 0.6667 - auc_2: 1.0000 - val_loss: 0.6492 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 19/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 212ms/step - loss: 0.6462 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.6465 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 20/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 224ms/step - loss: 0.6434 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.6439 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 21/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 247ms/step - loss: 0.6407 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.6415 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 22/200
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 256ms/step - loss: 0.6383 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.6393 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 23/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 258ms/step - loss: 0.6362 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.6369 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 24/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 258ms/step - loss: 0.6338 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.6345 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 25/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 211ms/step - loss: 0.6312 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.6318 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 26/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 247ms/step - loss: 0.6283 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.6292 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 27/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 254ms/step - loss: 0.6256 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.6268 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 28/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 213ms/step - loss: 0.6230 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.6246 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 29/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 256ms/step - loss: 0.6206 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.6222 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 30/200
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 315ms/step - loss: 0.6181 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.6196 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 31/200
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 259ms/step - loss: 0.6153 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.6167 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 32/200
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 361ms/step - loss: 0.6124 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.6138 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 33/200
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 306ms/step - loss: 0.6094 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.6111 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 34/200
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 313ms/step - loss: 0.6066 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.6084 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 35/200
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 291ms/step - loss: 0.6038 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.6057 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 36/200
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 284ms/step - loss: 0.6009 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.6027 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 37/200
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 279ms/step - loss: 0.5978 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.5997 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 38/200
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 306ms/step - loss: 0.5946 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.5967 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 338ms/step - loss: 0.5914 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.5935 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 40/200
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 311ms/step - loss: 0.5881 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.5899 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 41/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 223ms/step - loss: 0.5845 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.5865 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 42/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 224ms/step - loss: 0.5810 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.5825 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 43/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 218ms/step - loss: 0.5771 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.5790 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 44/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 254ms/step - loss: 0.5735 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.5756 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 45/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 248ms/step - loss: 0.5700 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.5722 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 46/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 251ms/step - loss: 0.5665 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.5688 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 47/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 215ms/step - loss: 0.5629 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.5653 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 48/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 212ms/step - loss: 0.5592 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.5617 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 246ms/step - loss: 0.5554 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.5580 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 50/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 260ms/step - loss: 0.5516 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.5544 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 51/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 254ms/step - loss: 0.5477 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.5506 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 52/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 212ms/step - loss: 0.5438 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.5468 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 53/200
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 222ms/step - loss: 0.5398 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.5428 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 54/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 247ms/step - loss: 0.5357 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.5388 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 55/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 216ms/step - loss: 0.5315 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.5347 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 56/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 249ms/step - loss: 0.5273 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.5306 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 212ms/step - loss: 0.5230 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.5264 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 58/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 265ms/step - loss: 0.5187 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.5222 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 59/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 1s 507ms/step - loss: 0.5142 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.5179 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 60/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 295ms/step - loss: 0.5097 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.5137 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 61/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 222ms/step - loss: 0.5052 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.5092 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 62/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 222ms/step - loss: 0.5006 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.5047 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 257ms/step - loss: 0.4959 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.5002 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 64/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 249ms/step - loss: 0.4912 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4956 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 218ms/step - loss: 0.4864 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4908 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 259ms/step - loss: 0.4816 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4861 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 67/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 258ms/step - loss: 0.4767 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4813 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 222ms/step - loss: 0.4717 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4765 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 254ms/step - loss: 0.4667 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4716 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 253ms/step - loss: 0.4616 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4666 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 220ms/step - loss: 0.4564 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4615 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 217ms/step - loss: 0.4512 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4564 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 212ms/step - loss: 0.4460 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4513 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 283ms/step - loss: 0.4407 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4461 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 263ms/step - loss: 0.4353 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4409 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 221ms/step - loss: 0.4299 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4356 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 214ms/step - loss: 0.4245 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4303 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 215ms/step - loss: 0.4190 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4249 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 220ms/step - loss: 0.4134 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4194 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 263ms/step - loss: 0.4078 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4140 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 331ms/step - loss: 0.4022 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4085 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 344ms/step - loss: 0.3966 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.4030 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 299ms/step - loss: 0.3909 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3974 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 329ms/step - loss: 0.3852 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3918 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 272ms/step - loss: 0.3795 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3862 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 336ms/step - loss: 0.3737 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3805 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 328ms/step - loss: 0.3679 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3749 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 296ms/step - loss: 0.3621 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3692 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 331ms/step - loss: 0.3563 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3636 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 299ms/step - loss: 0.3505 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3579 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 224ms/step - loss: 0.3447 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3522 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 224ms/step - loss: 0.3389 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3464 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 255ms/step - loss: 0.3331 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3407 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 220ms/step - loss: 0.3273 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3351 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 223ms/step - loss: 0.3215 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3294 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 284ms/step - loss: 0.3157 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3237 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 217ms/step - loss: 0.3100 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3179 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 251ms/step - loss: 0.3042 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3123 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 223ms/step - loss: 0.2985 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3067 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 213ms/step - loss: 0.2928 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.3011 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 256ms/step - loss: 0.2872 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2955 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 289ms/step - loss: 0.2816 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2899 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 261ms/step - loss: 0.2760 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2844 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 104/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 219ms/step - loss: 0.2705 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2790 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 250ms/step - loss: 0.2650 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2736 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 266ms/step - loss: 0.2595 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2682 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 224ms/step - loss: 0.2541 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2628 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 219ms/step - loss: 0.2488 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2575 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 215ms/step - loss: 0.2435 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2523 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 294ms/step - loss: 0.2382 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2471 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 216ms/step - loss: 0.2330 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2420 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 216ms/step - loss: 0.2279 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2370 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 113/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 248ms/step - loss: 0.2228 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2319 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 218ms/step - loss: 0.2179 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2270 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 252ms/step - loss: 0.2130 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2222 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 211ms/step - loss: 0.2082 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2174 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 227ms/step - loss: 0.2035 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2127 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 222ms/step - loss: 0.1988 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2081 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 264ms/step - loss: 0.1943 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.2035 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 219ms/step - loss: 0.1898 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1990 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 267ms/step - loss: 0.1853 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1946 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 259ms/step - loss: 0.1810 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1903 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 214ms/step - loss: 0.1767 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1860 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 288ms/step - loss: 0.1726 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1818 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 265ms/step - loss: 0.1685 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1778 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 210ms/step - loss: 0.1645 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1737 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 290ms/step - loss: 0.1605 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1698 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 288ms/step - loss: 0.1567 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1660 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 296ms/step - loss: 0.1529 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1622 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 257ms/step - loss: 0.1492 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1585 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 290ms/step - loss: 0.1457 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1549 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 300ms/step - loss: 0.1421 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1513 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 299ms/step - loss: 0.1387 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1479 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 293ms/step - loss: 0.1354 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1445 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 261ms/step - loss: 0.1321 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1413 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 340ms/step - loss: 0.1289 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1380 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 333ms/step - loss: 0.1258 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1349 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 307ms/step - loss: 0.1228 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1318 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 291ms/step - loss: 0.1198 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1288 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 320ms/step - loss: 0.1169 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1259 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 325ms/step - loss: 0.1141 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1230 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 288ms/step - loss: 0.1114 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1203 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 252ms/step - loss: 0.1088 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1176 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 256ms/step - loss: 0.1062 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1150 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 234ms/step - loss: 0.1037 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1123 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 260ms/step - loss: 0.1012 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1098 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 253ms/step - loss: 0.0988 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1074 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 287ms/step - loss: 0.0965 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1051 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 295ms/step - loss: 0.0943 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1027 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 260ms/step - loss: 0.0921 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.1004 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 214ms/step - loss: 0.0899 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0983 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 257ms/step - loss: 0.0878 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0962 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 267ms/step - loss: 0.0858 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0940 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 267ms/step - loss: 0.0839 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0920 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 227ms/step - loss: 0.0820 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0901 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 250ms/step - loss: 0.0801 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0882 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 288ms/step - loss: 0.0783 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0863 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 220ms/step - loss: 0.0766 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0845 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 221ms/step - loss: 0.0749 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0827 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 256ms/step - loss: 0.0732 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0810 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 216ms/step - loss: 0.0716 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0793 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 260ms/step - loss: 0.0701 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0777 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 215ms/step - loss: 0.0685 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0762 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 257ms/step - loss: 0.0671 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0746 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 259ms/step - loss: 0.0656 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0731 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 289ms/step - loss: 0.0642 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0716 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 255ms/step - loss: 0.0629 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0702 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 214ms/step - loss: 0.0616 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0688 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 213ms/step - loss: 0.0603 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0675 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 288ms/step - loss: 0.0590 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0662 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 253ms/step - loss: 0.0578 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0649 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 214ms/step - loss: 0.0567 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0636 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 288ms/step - loss: 0.0555 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0624 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 283ms/step - loss: 0.0544 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0613 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 252ms/step - loss: 0.0533 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0601 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0523 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0590 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 252ms/step - loss: 0.0512 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0579 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 253ms/step - loss: 0.0503 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0569 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 255ms/step - loss: 0.0493 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0558 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 297ms/step - loss: 0.0483 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0548 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 306ms/step - loss: 0.0474 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0539 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 277ms/step - loss: 0.0465 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0529 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 262ms/step - loss: 0.0457 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0520 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 266ms/step - loss: 0.0448 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0511 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 299ms/step - loss: 0.0440 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0501 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 328ms/step - loss: 0.0432 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0493 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 317ms/step - loss: 0.0424 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0484 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 345ms/step - loss: 0.0416 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0476 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 360ms/step - loss: 0.0408 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0468 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 307ms/step - loss: 0.0401 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0460 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 300ms/step - loss: 0.0393 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0452 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 235ms/step - loss: 0.0386 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0444 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 228ms/step - loss: 0.0379 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0437 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 286ms/step - loss: 0.0373 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0430 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 296ms/step - loss: 0.0367 - f1_m: 1.0000 - auc_2: 1.0000 - val_loss: 0.0423 - val_f1_m: 1.0000 - val_auc_2: 1.0000 - val_auc_roc: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 20ms/step
# ...
# Epoch 137/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 361ms/step - loss: 0.0225 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0218 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 355ms/step - loss: 0.0220 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0214 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 372ms/step - loss: 0.0217 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0210 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 362ms/step - loss: 0.0213 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0206 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 351ms/step - loss: 0.0209 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0203 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 378ms/step - loss: 0.0205 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0199 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 361ms/step - loss: 0.0202 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0196 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 334ms/step - loss: 0.0198 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0193 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 364ms/step - loss: 0.0195 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0189 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 349ms/step - loss: 0.0192 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0186 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 364ms/step - loss: 0.0189 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0183 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 333ms/step - loss: 0.0186 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0180 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 324ms/step - loss: 0.0183 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0177 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 336ms/step - loss: 0.0180 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0175 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 353ms/step - loss: 0.0177 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0172 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 403ms/step - loss: 0.0174 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0169 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 469ms/step - loss: 0.0172 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0167 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 451ms/step - loss: 0.0169 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0164 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 465ms/step - loss: 0.0166 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0162 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 386ms/step - loss: 0.0164 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0159 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 440ms/step - loss: 0.0162 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0157 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 408ms/step - loss: 0.0159 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0155 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 419ms/step - loss: 0.0157 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0153 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 424ms/step - loss: 0.0155 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0150 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 396ms/step - loss: 0.0152 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0148 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 350ms/step - loss: 0.0150 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0146 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 408ms/step - loss: 0.0148 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0144 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 367ms/step - loss: 0.0146 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0142 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 366ms/step - loss: 0.0144 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0140 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 355ms/step - loss: 0.0142 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0138 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 358ms/step - loss: 0.0140 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0137 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 336ms/step - loss: 0.0138 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0135 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 363ms/step - loss: 0.0137 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0133 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 391ms/step - loss: 0.0135 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0131 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 324ms/step - loss: 0.0133 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0130 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 320ms/step - loss: 0.0131 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0128 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 385ms/step - loss: 0.0130 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0126 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 365ms/step - loss: 0.0128 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0125 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 364ms/step - loss: 0.0126 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0123 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 349ms/step - loss: 0.0125 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0122 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 350ms/step - loss: 0.0123 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0120 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 364ms/step - loss: 0.0122 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0119 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 348ms/step - loss: 0.0120 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0117 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 364ms/step - loss: 0.0119 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0116 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 342ms/step - loss: 0.0117 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0114 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 361ms/step - loss: 0.0116 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0113 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 339ms/step - loss: 0.0115 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0112 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 367ms/step - loss: 0.0113 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0111 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 374ms/step - loss: 0.0112 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0109 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 350ms/step - loss: 0.0111 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0108 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 415ms/step - loss: 0.0109 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0107 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 422ms/step - loss: 0.0108 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0106 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 443ms/step - loss: 0.0107 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0104 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 417ms/step - loss: 0.0106 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0103 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 425ms/step - loss: 0.0105 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0102 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 470ms/step - loss: 0.0103 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0101 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 415ms/step - loss: 0.0102 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0100 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 472ms/step - loss: 0.0101 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0099 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 423ms/step - loss: 0.0100 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0098 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 398ms/step - loss: 0.0099 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0097 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 341ms/step - loss: 0.0098 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0096 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 398ms/step - loss: 0.0097 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0095 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 365ms/step - loss: 0.0096 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0094 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 377ms/step - loss: 0.0095 - f1_m: 1.0000 - auc_5: 1.0000 - val_loss: 0.0093 - val_f1_m: 1.0000 - val_auc_5: 1.0000 - val_auc_roc: 1.0000
# 2/2 [==============================] - 5s 3s/step - loss: 0.1672 - f1_m: 0.8333 - auc_5: 0.9589
# 2/2 [==============================] - 0s 255ms/step
# Models: 100%|██████████| 4/4 [07:19<00:00, 109.94s/it]

# %% [markdown]
# # K10 Train/Test

# %%
# Define early stop
patience = 30
early_stopping = EarlyStopping(monitor='val_loss', patience=patience, mode='auto', restore_best_weights=True)


# Params
epochs = 200
batch_size = 16

# %%
from sklearn.metrics import make_scorer, f1_score
from sklearn.metrics import roc_auc_score
from tqdm import tqdm
import pandas as pd

models = [vgg_model, resnet_model, inception_model, xception_model]
model_names = ["VGG16", "ResNet50", "InceptionV3", "Xception"]
scoring_models_k10 = []
current_datetime = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# Progressbar
progress_bar = tqdm(total=len(models), desc='Models', position=0)


for model, model_name in zip(models, model_names):

    if model_name == "VGG16":
      reset_model_vgg16 = clone_model(vgg_model)
      reset_model_vgg16.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=[f1_m, tf.keras.metrics.AUC()])
      ### Training on Data K10
      history_vgg16_k10 = reset_model_vgg16.fit(train_data_vgg16_k10, train_labels_vgg16_k10, validation_data=(val_data_vgg16_k10, val_labels_vgg16_k10),
                          batch_size=batch_size, epochs=epochs, callbacks=[early_stopping, AUCROCCallback(validation_data=(val_data_vgg16_k10, val_labels_vgg16_k10))])


      formating_results_k10 = {}
      formating_results_k10["Model"] = model_name
      formating_results_k10["Loss"] = history_vgg16_k10.history["loss"]
      formating_results_k10["F1-Score"] = history_vgg16_k10.history["f1_m"]
      formating_results_k10["Validation Loss"] = history_vgg16_k10.history["val_loss"]
      formating_results_k10["Validation F1-Score"] = history_vgg16_k10.history["val_f1_m"]
      formating_results_k10["AUC-ROC VAL"] = history_vgg16_k10.history['val_auc_roc']

      loss_evaluation_vgg16, f1_m_evaluation_vgg16, auc_roc_evaluation_vgg16 = reset_model_vgg16.evaluate(test_data_vgg16_k10, test_labels_vgg16_k10, verbose=1)
      formating_results_k10["F1-Score Test"] = f1_m_evaluation_vgg16
      formating_results_k10["Loss Test"] = loss_evaluation_vgg16
      formating_results_k10["AUC-ROC Test"] = auc_roc_evaluation_vgg16

      scoring_models_k10.append(formating_results_k10)

      y_pred = reset_model_vgg16.predict(test_data_vgg16_k10)
      y_pred = np.argmax(y_pred, axis=1)

      cm = confusion_matrix(test_labels_vgg16_k10, y_pred)
      cm_float = cm.astype(float)

      try:
          cm_filename = "ConfusionMatrix/ConfusionMatrix_k10_" + model_name + "_" + current_datetime + ".csv"
          np.savetxt(cm_filename, cm_float, delimiter=",", fmt='%.4f')
      except:
          continue

      progress_bar.update(1)

      try:
        filename = "Models/Model_k10_" + model_name + "_" + current_datetime + ".h5"
        reset_model_vgg16.save(filename)
      except:
        continue

    if model_name == "ResNet50":
      reset_model_resnet50 = clone_model(resnet_model)
      reset_model_resnet50.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=[f1_m, tf.keras.metrics.AUC()])
      ### Training on K10
      history_resnet50_k10 = reset_model_resnet50.fit(train_data_resnet50_k10, train_labels_resnet50_k10, validation_data=(val_data_resnet50_k10, val_labels_resnet50_k10),
                          batch_size=batch_size, epochs=epochs, callbacks=[early_stopping, AUCROCCallback(validation_data=(val_data_resnet50_k10, val_labels_resnet50_k10))])

      formating_results_k10 = {}
      formating_results_k10["Model"] = model_name
      formating_results_k10["Loss"] = history_resnet50_k10.history["loss"]
      formating_results_k10["F1-Score"] = history_resnet50_k10.history["f1_m"]
      formating_results_k10["Validation Loss"] = history_resnet50_k10.history["val_loss"]
      formating_results_k10["Validation F1-Score"] = history_resnet50_k10.history["val_f1_m"]
      formating_results_k10["AUC-ROC VAL"] = history_resnet50_k10.history['val_auc_roc']

      loss_evaluation_resnet50, f1_m_evaluation_resnet50, auc_roc_evaluation_resnet50 = reset_model_resnet50.evaluate(test_data_resnet50_k10, test_labels_resnet50_k10, verbose=1)
      formating_results_k10["F1-Score Test"] = f1_m_evaluation_resnet50
      formating_results_k10["Loss Test"] = loss_evaluation_resnet50
      formating_results_k10["AUC-ROC Test"] = auc_roc_evaluation_resnet50

      scoring_models_k10.append(formating_results_k10)
      filename = "models/" + model_name + "_" + current_datetime + ".h5"

      y_pred = reset_model_resnet50.predict(test_data_resnet50_k10)
      y_pred = np.argmax(y_pred, axis=1)

      cm = confusion_matrix(test_labels_resnet50_k10, y_pred)
      cm_float = cm.astype(float)

      try:
          cm_filename = "ConfusionMatrix/ConfusionMatrix_k10_" + model_name + "_" + current_datetime + ".csv"
          np.savetxt(cm_filename, cm_float, delimiter=",", fmt='%.4f')
      except:
          continue

      progress_bar.update(1)

      try:
        filename = "Models/Model_k10_" + model_name + "_" + current_datetime + ".h5"
        reset_model_resnet50.save(filename)
      except:
        continue

    if model_name == "InceptionV3":
      reset_model_inceptionv3 = clone_model(inception_model)
      reset_model_inceptionv3.compile(loss='binary_crossentropy', optimizer=optimizer_other, metrics=[f1_m, tf.keras.metrics.AUC()])

      ###Training on K10
      history_inceptionv3_k10 = reset_model_inceptionv3.fit(train_data_inceptionv3_k10, train_labels_inceptionv3_k10,
                                validation_data=(val_data_inceptionv3_k10, val_labels_inceptionv3_k10),
                          batch_size=batch_size, epochs=epochs, callbacks=[early_stopping, AUCROCCallback(validation_data=(val_data_inceptionv3_k10, val_labels_inceptionv3_k10))])

      formating_results_k10 = {}
      formating_results_k10["Model"] = model_name
      formating_results_k10["Loss"] = history_inceptionv3_k10.history["loss"]
      formating_results_k10["F1-Score"] = history_inceptionv3_k10.history["f1_m"]
      formating_results_k10["Validation Loss"] = history_inceptionv3_k10.history["val_loss"]
      formating_results_k10["Validation F1-Score"] = history_inceptionv3_k10.history["val_f1_m"]
      formating_results_k10["AUC-ROC VAL"] = history_inceptionv3_k10.history['val_auc_roc']

      loss_evaluation_inceptionv3, f1_m_evaluation_inceptionv3, auc_roc_evaluation_inceptionv3 = reset_model_inceptionv3.evaluate(test_data_inceptionv3_k10, test_labels_inceptionv3_k10, verbose=1)
      formating_results_k10["F1-Score Test"] = f1_m_evaluation_inceptionv3
      formating_results_k10["Loss Test"] = loss_evaluation_inceptionv3
      formating_results_k10["AUC-ROC Test"] = auc_roc_evaluation_inceptionv3

      scoring_models_k10.append(formating_results_k10)

      y_pred = reset_model_inceptionv3.predict(test_data_inceptionv3_k10)
      y_pred = np.argmax(y_pred, axis=1)

      cm = confusion_matrix(test_labels_inceptionv3_k10, y_pred)
      cm_float = cm.astype(float)

      try:
          cm_filename = "ConfusionMatrix/ConfusionMatrix_k10_" + model_name + "_" + current_datetime + ".csv"
          np.savetxt(cm_filename, cm_float, delimiter=",", fmt='%.4f')
      except:
          continue

      progress_bar.update(1)

      try:
        filename = "Models/Model_k10_" + model_name + "_" + current_datetime + ".h5"
        reset_model_inceptionv3.save(filename)
      except:
        continue



    if model_name == "Xception":
      reset_model_xception = clone_model(xception_model)
      reset_model_xception.compile(loss='binary_crossentropy', optimizer=optimizer_other, metrics=[f1_m, tf.keras.metrics.AUC()])
      ### Training on K10
      history_xception_k10 = reset_model_xception.fit(train_data_xception_k10, train_labels_xception_k10,
                                validation_data=(val_data_xception_k10, val_labels_xception_k10),
                          batch_size=batch_size, epochs=epochs, callbacks=[early_stopping, AUCROCCallback(validation_data=(val_data_xception_k10, val_labels_xception_k10))])

      formating_results_k10 = {}
      formating_results_k10["Model"] = model_name
      formating_results_k10["Loss"] = history_xception_k10.history["loss"]
      formating_results_k10["F1-Score"] = history_xception_k10.history["f1_m"]
      formating_results_k10["Validation Loss"] = history_xception_k10.history["val_loss"]
      formating_results_k10["Validation F1-Score"] = history_xception_k10.history["val_f1_m"]
      formating_results_k10["AUC-ROC VAL"] = history_xception_k10.history['val_auc_roc']

      loss_evaluation_xception, f1_m_evaluation_xception, auc_roc_evaluation_xception  = reset_model_xception.evaluate(test_data_xception_k10, test_labels_xception_k10, verbose=1)
      formating_results_k10["F1-Score Test"] = f1_m_evaluation_xception
      formating_results_k10["Loss Test"] = loss_evaluation_xception
      formating_results_k10["AUC-ROC Test"] = auc_roc_evaluation_xception

      scoring_models_k10.append(formating_results_k10)

      y_pred = reset_model_xception.predict(test_data_xception_k10)
      y_pred = np.argmax(y_pred, axis=1)

      cm = confusion_matrix(test_labels_xception_k10, y_pred)
      cm_float = cm.astype(float)

      try:
          cm_filename = "ConfusionMatrix/ConfusionMatrix_k10_" + model_name + "_" + current_datetime + ".csv"
          np.savetxt(cm_filename, cm_float, delimiter=",", fmt='%.4f')
      except:
          continue

      progress_bar.update(1)

      try:
        filename = "Models/Model_k10_" + model_name + "_" + current_datetime + ".h5"
        reset_model_xception.save(filename)
      except:
        continue
      progress_bar.update(1)

# Progressbar close
progress_bar.close()

# Dataframe
df_k10 = pd.DataFrame(scoring_models_k10)
df_k10.to_csv("model_metrics_k10_balanced" + current_datetime, index=False)
# Out:
# Models:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 1/200
# 1/1 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 6s 2s/step - loss: 0.7014 - f1_m: 0.3333 - auc_6: 0.1800 - val_loss: 0.6895 - val_f1_m: 0.0000e+00 - val_auc_6: 0.8750 - val_auc_roc: 1.0000
# Epoch 2/200
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 186ms/step - loss: 0.6975 - f1_m: 0.2000 - auc_6: 0.6800 - val_loss: 0.6920 - val_f1_m: 0.0000e+00 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 3/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 188ms/step - loss: 0.6942 - f1_m: 0.0000e+00 - auc_6: 0.8400 - val_loss: 0.7103 - val_f1_m: 0.0000e+00 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 4/200
# 1/1 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 285ms/step - loss: 0.7043 - f1_m: 0.0000e+00 - auc_6: 0.8400 - val_loss: 0.6731 - val_f1_m: 0.0000e+00 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 5/200
# 1/1 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 243ms/step - loss: 0.6707 - f1_m: 0.3333 - auc_6: 0.8400 - val_loss: 0.6772 - val_f1_m: 0.6667 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 6/200
# 1/1 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 316ms/step - loss: 0.6754 - f1_m: 0.6667 - auc_6: 1.0000 - val_loss: 0.6664 - val_f1_m: 0.6667 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 7/200
# 1/1 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 322ms/step - loss: 0.6621 - f1_m: 0.6667 - auc_6: 0.9200 - val_loss: 0.6498 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 8/200
# 1/1 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 274ms/step - loss: 0.6591 - f1_m: 0.5000 - auc_6: 0.7300 - val_loss: 0.6444 - val_f1_m: 0.0000e+00 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 9/200
# 1/1 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 330ms/step - loss: 0.6410 - f1_m: 0.5000 - auc_6: 1.0000 - val_loss: 0.6397 - val_f1_m: 0.6667 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 10/200
# 1/1 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 307ms/step - loss: 0.6374 - f1_m: 0.6667 - auc_6: 1.0000 - val_loss: 0.6377 - val_f1_m: 0.6667 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 11/200
# 1/1 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 269ms/step - loss: 0.6336 - f1_m: 0.6667 - auc_6: 1.0000 - val_loss: 0.6221 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 12/200
# 1/1 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 303ms/step - loss: 0.6153 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.6217 - val_f1_m: 0.0000e+00 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 13/200
# 1/1 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 235ms/step - loss: 0.6215 - f1_m: 0.0000e+00 - auc_6: 1.0000 - val_loss: 0.6383 - val_f1_m: 0.0000e+00 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 14/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 262ms/step - loss: 0.6337 - f1_m: 0.0000e+00 - auc_6: 1.0000 - val_loss: 0.6038 - val_f1_m: 0.6667 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 15/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 221ms/step - loss: 0.5874 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.6208 - val_f1_m: 0.6667 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 16/200
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 217ms/step - loss: 0.6137 - f1_m: 0.7329 - auc_6: 1.0000 - val_loss: 0.6880 - val_f1_m: 0.6667 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 17/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 214ms/step - loss: 0.6847 - f1_m: 0.6667 - auc_6: 1.0000 - val_loss: 0.6560 - val_f1_m: 0.6667 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 18/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 283ms/step - loss: 0.6561 - f1_m: 0.7329 - auc_6: 1.0000 - val_loss: 0.5861 - val_f1_m: 0.6667 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 19/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 231ms/step - loss: 0.5799 - f1_m: 0.8333 - auc_6: 1.0000 - val_loss: 0.5735 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 20/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 183ms/step - loss: 0.5814 - f1_m: 0.5000 - auc_6: 1.0000 - val_loss: 0.5782 - val_f1_m: 0.0000e+00 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 21/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 224ms/step - loss: 0.5707 - f1_m: 0.5000 - auc_6: 1.0000 - val_loss: 0.5589 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 22/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 249ms/step - loss: 0.5808 - f1_m: 0.5000 - auc_6: 1.0000 - val_loss: 0.5580 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 23/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 244ms/step - loss: 0.5530 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.5480 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 24/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 246ms/step - loss: 0.5437 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.5446 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 25/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 252ms/step - loss: 0.5404 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.5407 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 26/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 272ms/step - loss: 0.5379 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.5352 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 27/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 258ms/step - loss: 0.5336 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.5268 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 28/200
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 254ms/step - loss: 0.5215 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.5198 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 29/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 242ms/step - loss: 0.5209 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.5159 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 30/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 234ms/step - loss: 0.5085 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.5063 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 31/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 216ms/step - loss: 0.5023 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.5139 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 32/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 188ms/step - loss: 0.5084 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.5173 - val_f1_m: 0.6667 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 33/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 263ms/step - loss: 0.5141 - f1_m: 0.5000 - auc_6: 1.0000 - val_loss: 0.4977 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 34/200
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 241ms/step - loss: 0.4904 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.4822 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 35/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 189ms/step - loss: 0.4783 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.4928 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 36/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 231ms/step - loss: 0.4872 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.4924 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 37/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 190ms/step - loss: 0.4874 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.4826 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 38/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 246ms/step - loss: 0.4756 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.4625 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 230ms/step - loss: 0.4553 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.4482 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 40/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 195ms/step - loss: 0.4431 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.4495 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 41/200
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 186ms/step - loss: 0.4438 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.4486 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 42/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 248ms/step - loss: 0.4429 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.4383 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 43/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 225ms/step - loss: 0.4310 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.4207 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 44/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 278ms/step - loss: 0.4207 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.4146 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 45/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 249ms/step - loss: 0.4085 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.4066 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 46/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 219ms/step - loss: 0.4011 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.4078 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 47/200
# 1/1 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 240ms/step - loss: 0.4017 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.3995 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 48/200
# 1/1 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 286ms/step - loss: 0.3963 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.3871 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 287ms/step - loss: 0.3814 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.3779 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 50/200
# 1/1 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 230ms/step - loss: 0.3719 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.3785 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 51/200
# 1/1 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 264ms/step - loss: 0.3752 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.3674 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 52/200
# 1/1 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 279ms/step - loss: 0.3556 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.3633 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 53/200
# 1/1 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 251ms/step - loss: 0.3682 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.3724 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 54/200
# 1/1 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 311ms/step - loss: 0.3683 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.3483 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 55/200
# 1/1 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 260ms/step - loss: 0.3410 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.3367 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 56/200
# 1/1 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 295ms/step - loss: 0.3346 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.3313 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 279ms/step - loss: 0.3235 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.3246 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 58/200
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 192ms/step - loss: 0.3190 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.3281 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 59/200
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 225ms/step - loss: 0.3220 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.3224 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 60/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 259ms/step - loss: 0.3168 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.3134 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 61/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 255ms/step - loss: 0.3080 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.3037 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 62/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 262ms/step - loss: 0.2967 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.2931 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 269ms/step - loss: 0.2859 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.2855 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 64/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 210ms/step - loss: 0.2778 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.2863 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 228ms/step - loss: 0.2803 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.2840 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 276ms/step - loss: 0.2788 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.2703 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 67/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 255ms/step - loss: 0.2629 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.2609 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 257ms/step - loss: 0.2529 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.2584 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 194ms/step - loss: 0.2505 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.2676 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 258ms/step - loss: 0.2615 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.2580 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 267ms/step - loss: 0.2466 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.2382 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 222ms/step - loss: 0.2412 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.2496 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 226ms/step - loss: 0.2415 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.2319 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 250ms/step - loss: 0.2241 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.2233 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 275ms/step - loss: 0.2213 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.2216 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 242ms/step - loss: 0.2132 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.2122 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 214ms/step - loss: 0.2066 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.2199 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 233ms/step - loss: 0.2146 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.2074 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 259ms/step - loss: 0.1995 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.2003 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 239ms/step - loss: 0.1992 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.2010 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 275ms/step - loss: 0.1938 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1883 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 256ms/step - loss: 0.1823 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1877 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 226ms/step - loss: 0.1816 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1845 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 227ms/step - loss: 0.1770 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1752 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 190ms/step - loss: 0.1669 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1834 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 184ms/step - loss: 0.1772 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1921 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 275ms/step - loss: 0.1851 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1681 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 196ms/step - loss: 0.1568 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1714 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 201ms/step - loss: 0.1801 - f1_m: 0.5000 - auc_6: 1.0000 - val_loss: 0.1793 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 256ms/step - loss: 0.1693 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1524 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 241ms/step - loss: 0.1412 - f1_m: 0.5000 - auc_6: 1.0000 - val_loss: 0.1732 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 247ms/step - loss: 0.1713 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1908 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 268ms/step - loss: 0.1797 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1479 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 254ms/step - loss: 0.1413 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1534 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 263ms/step - loss: 0.1543 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1661 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 262ms/step - loss: 0.1567 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1371 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 328ms/step - loss: 0.1346 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1335 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 259ms/step - loss: 0.1289 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1350 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 317ms/step - loss: 0.1293 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1264 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 309ms/step - loss: 0.1209 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1252 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 199ms/step - loss: 0.1221 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1258 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 221ms/step - loss: 0.1209 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1188 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 257ms/step - loss: 0.1134 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1149 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 104/200
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 254ms/step - loss: 0.1109 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1126 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 249ms/step - loss: 0.1075 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1103 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 247ms/step - loss: 0.1048 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1115 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 258ms/step - loss: 0.1078 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1098 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 275ms/step - loss: 0.1040 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1035 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 194ms/step - loss: 0.0971 - f1_m: 0.5000 - auc_6: 1.0000 - val_loss: 0.1058 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 218ms/step - loss: 0.1008 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1162 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 189ms/step - loss: 0.1123 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1063 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 262ms/step - loss: 0.1000 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0950 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 113/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 238ms/step - loss: 0.0935 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.1004 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 193ms/step - loss: 0.0954 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0983 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 267ms/step - loss: 0.0935 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0927 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 264ms/step - loss: 0.0885 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0883 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 233ms/step - loss: 0.0835 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0858 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 222ms/step - loss: 0.0808 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0870 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 214ms/step - loss: 0.0828 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0899 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 233ms/step - loss: 0.0858 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0860 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 232ms/step - loss: 0.0813 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0794 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 271ms/step - loss: 0.0753 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0792 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 215ms/step - loss: 0.0753 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0800 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 236ms/step - loss: 0.0758 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0771 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 239ms/step - loss: 0.0726 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0738 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 226ms/step - loss: 0.0697 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0719 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 225ms/step - loss: 0.0688 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0709 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 252ms/step - loss: 0.0671 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0692 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 245ms/step - loss: 0.0654 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0680 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 243ms/step - loss: 0.0644 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0680 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 212ms/step - loss: 0.0643 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0694 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 259ms/step - loss: 0.0652 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0660 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 282ms/step - loss: 0.0614 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0631 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 277ms/step - loss: 0.0582 - f1_m: 0.5000 - auc_6: 1.0000 - val_loss: 0.0667 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 270ms/step - loss: 0.0643 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0718 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 229ms/step - loss: 0.0678 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0640 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 288ms/step - loss: 0.0590 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0588 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 248ms/step - loss: 0.0559 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0642 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 247ms/step - loss: 0.0613 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0629 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 280ms/step - loss: 0.0583 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0560 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 323ms/step - loss: 0.0536 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0558 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 313ms/step - loss: 0.0528 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0558 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 324ms/step - loss: 0.0525 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0537 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 246ms/step - loss: 0.0501 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0521 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 234ms/step - loss: 0.0498 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0525 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 253ms/step - loss: 0.0491 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0514 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 259ms/step - loss: 0.0483 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0499 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 253ms/step - loss: 0.0467 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0488 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 226ms/step - loss: 0.0454 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0485 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 242ms/step - loss: 0.0454 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0496 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 193ms/step - loss: 0.0466 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0499 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 230ms/step - loss: 0.0469 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0472 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 252ms/step - loss: 0.0441 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0451 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 217ms/step - loss: 0.0418 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0466 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 223ms/step - loss: 0.0437 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0479 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 260ms/step - loss: 0.0444 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0443 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 242ms/step - loss: 0.0399 - f1_m: 0.5000 - auc_6: 1.0000 - val_loss: 0.0429 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 190ms/step - loss: 0.0399 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0486 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 230ms/step - loss: 0.0464 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0501 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 214ms/step - loss: 0.0468 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0432 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 274ms/step - loss: 0.0401 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0400 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 237ms/step - loss: 0.0375 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0421 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 194ms/step - loss: 0.0397 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0421 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 255ms/step - loss: 0.0391 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0390 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 281ms/step - loss: 0.0356 - f1_m: 0.5000 - auc_6: 1.0000 - val_loss: 0.0377 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 189ms/step - loss: 0.0349 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0400 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 217ms/step - loss: 0.0384 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0409 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 236ms/step - loss: 0.0381 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0373 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 255ms/step - loss: 0.0347 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0356 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 209ms/step - loss: 0.0337 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0361 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 215ms/step - loss: 0.0335 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0357 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 235ms/step - loss: 0.0334 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0350 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 255ms/step - loss: 0.0324 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0344 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 236ms/step - loss: 0.0322 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0338 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 259ms/step - loss: 0.0313 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0334 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 243ms/step - loss: 0.0310 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0327 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 324ms/step - loss: 0.0303 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0320 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 300ms/step - loss: 0.0297 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0316 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 257ms/step - loss: 0.0292 - f1_m: 0.5000 - auc_6: 1.0000 - val_loss: 0.0317 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 238ms/step - loss: 0.0294 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0326 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 262ms/step - loss: 0.0307 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0321 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 308ms/step - loss: 0.0296 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0301 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 310ms/step - loss: 0.0284 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0299 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 255ms/step - loss: 0.0277 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0302 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 301ms/step - loss: 0.0279 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0297 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 323ms/step - loss: 0.0274 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0288 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 287ms/step - loss: 0.0263 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0282 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 224ms/step - loss: 0.0266 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0285 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 264ms/step - loss: 0.0265 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0279 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 271ms/step - loss: 0.0256 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0271 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 228ms/step - loss: 0.0249 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0277 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 220ms/step - loss: 0.0255 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0288 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 192ms/step - loss: 0.0265 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0283 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 261ms/step - loss: 0.0260 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0267 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 291ms/step - loss: 0.0248 - f1_m: 1.0000 - auc_6: 1.0000 - val_loss: 0.0257 - val_f1_m: 1.0000 - val_auc_6: 1.0000 - val_auc_roc: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 24ms/step
# ...
# Epoch 137/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 362ms/step - loss: 0.0560 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0483 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 365ms/step - loss: 0.0512 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0457 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 226ms/step - loss: 0.0495 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0472 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 225ms/step - loss: 0.0505 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0472 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 342ms/step - loss: 0.0504 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0450 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 354ms/step - loss: 0.0480 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0427 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 342ms/step - loss: 0.0456 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0418 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 368ms/step - loss: 0.0453 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0417 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 1s 389ms/step - loss: 0.0448 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0410 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 363ms/step - loss: 0.0441 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0402 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 353ms/step - loss: 0.0431 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0390 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 1s 408ms/step - loss: 0.0422 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0383 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 1s 499ms/step - loss: 0.0412 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0377 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 52ms/step
# 2/2 [==============================] - 1s 429ms/step - loss: 0.0406 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0369 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 1s 441ms/step - loss: 0.0396 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0364 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 1s 410ms/step - loss: 0.0397 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0363 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 1s 429ms/step - loss: 0.0392 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0355 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 367ms/step - loss: 0.0381 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0345 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 348ms/step - loss: 0.0371 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0344 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 250ms/step - loss: 0.0376 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0345 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 1s 448ms/step - loss: 0.0374 - f1_m: 0.5000 - auc_9: 1.0000 - val_loss: 0.0332 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 372ms/step - loss: 0.0358 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0326 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 248ms/step - loss: 0.0355 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0332 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 240ms/step - loss: 0.0361 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0330 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 353ms/step - loss: 0.0359 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0318 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 1s 382ms/step - loss: 0.0346 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0306 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 345ms/step - loss: 0.0334 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0300 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 371ms/step - loss: 0.0326 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0297 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 345ms/step - loss: 0.0327 - f1_m: 0.5000 - auc_9: 1.0000 - val_loss: 0.0293 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 366ms/step - loss: 0.0319 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0287 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 359ms/step - loss: 0.0315 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0284 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 355ms/step - loss: 0.0310 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0280 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 353ms/step - loss: 0.0305 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0275 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 352ms/step - loss: 0.0302 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0271 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 357ms/step - loss: 0.0297 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0267 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 372ms/step - loss: 0.0294 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0264 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 364ms/step - loss: 0.0291 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0264 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 364ms/step - loss: 0.0289 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0262 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 1s 487ms/step - loss: 0.0287 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0261 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 1s 429ms/step - loss: 0.0286 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0256 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 1s 416ms/step - loss: 0.0281 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0250 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 1s 400ms/step - loss: 0.0274 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0244 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 1s 411ms/step - loss: 0.0265 - f1_m: 0.5000 - auc_9: 1.0000 - val_loss: 0.0243 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 276ms/step - loss: 0.0265 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0249 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 376ms/step - loss: 0.0277 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0250 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 370ms/step - loss: 0.0275 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0238 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 373ms/step - loss: 0.0264 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0229 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 367ms/step - loss: 0.0251 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0227 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 240ms/step - loss: 0.0249 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0229 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 257ms/step - loss: 0.0254 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0229 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 360ms/step - loss: 0.0251 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0221 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 374ms/step - loss: 0.0244 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0215 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 358ms/step - loss: 0.0238 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0213 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 361ms/step - loss: 0.0236 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0210 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 359ms/step - loss: 0.0231 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0207 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 368ms/step - loss: 0.0228 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0206 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 236ms/step - loss: 0.0227 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0208 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 241ms/step - loss: 0.0230 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0208 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 370ms/step - loss: 0.0231 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0206 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 358ms/step - loss: 0.0227 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0201 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 1s 380ms/step - loss: 0.0222 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0194 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 365ms/step - loss: 0.0214 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0191 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 380ms/step - loss: 0.0211 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0191 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 346ms/step - loss: 0.0213 - f1_m: 1.0000 - auc_9: 1.0000 - val_loss: 0.0189 - val_f1_m: 1.0000 - val_auc_9: 1.0000 - val_auc_roc: 1.0000
# 2/2 [==============================] - 0s 210ms/step - loss: 0.1466 - f1_m: 0.8333 - auc_9: 0.9522
# 2/2 [==============================] - 0s 230ms/step
# Models: 100%|██████████| 4/4 [05:48<00:00, 87.24s/it]

# %% [markdown]
# # K20 Train/Test

# %%
# Define early stop
patience = 30
early_stopping = EarlyStopping(monitor='val_loss', patience=patience, mode='auto', restore_best_weights=True)


# Params
epochs = 200
batch_size = 16

# %%
from sklearn.metrics import make_scorer, f1_score
from sklearn.metrics import roc_auc_score
from tqdm import tqdm
import pandas as pd

models = [vgg_model, resnet_model, inception_model, xception_model]
model_names = ["VGG16", "ResNet50", "InceptionV3", "Xception"]
scoring_models_k20 = []
current_datetime = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# Progressbar
progress_bar = tqdm(total=len(models), desc='Models', position=0)


for model, model_name in zip(models, model_names):

    if model_name == "VGG16":
      reset_model_vgg16 = clone_model(vgg_model)
      reset_model_vgg16.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=[f1_m, tf.keras.metrics.AUC()])
      ### Training on Data K20
      history_vgg16_k20 = reset_model_vgg16.fit(train_data_vgg16_k20, train_labels_vgg16_k20, validation_data=(val_data_vgg16_k20, val_labels_vgg16_k20),
                          batch_size=batch_size, epochs=epochs, callbacks=[early_stopping, AUCROCCallback(validation_data=(val_data_vgg16_k20, val_labels_vgg16_k20))])

      formating_results_k20 = {}
      formating_results_k20["Model"] = model_name
      formating_results_k20["Loss"] = history_vgg16_k20.history["loss"]
      formating_results_k20["F1-Score"] = history_vgg16_k20.history["f1_m"]
      formating_results_k20["Validation Loss"] = history_vgg16_k20.history["val_loss"]
      formating_results_k20["Validation F1-Score"] = history_vgg16_k20.history["val_f1_m"]
      formating_results_k20["AUC-ROC VAL"] = history_vgg16_k20.history['val_auc_roc']

      loss_evaluation_vgg16, f1_m_evaluation_vgg16, auc_roc_evaluation_vgg16 = reset_model_vgg16.evaluate(test_data_vgg16_k20, test_labels_vgg16_k20, verbose=1)
      formating_results_k20["F1-Score Test"] = f1_m_evaluation_vgg16
      formating_results_k20["Loss Test"] = loss_evaluation_vgg16
      formating_results_k20["AUC-ROC Test"] = auc_roc_evaluation_vgg16

      scoring_models_k20.append(formating_results_k20)

      y_pred = reset_model_vgg16.predict(test_data_vgg16_k20)
      y_pred = np.argmax(y_pred, axis=1)

      cm = confusion_matrix(test_labels_vgg16_k20, y_pred)
      cm_float = cm.astype(float)

      try:
          cm_filename = "ConfusionMatrix/ConfusionMatrix_k20_" + model_name + "_" + current_datetime + ".csv"
          np.savetxt(cm_filename, cm_float, delimiter=",", fmt='%.4f')
      except:
          continue

      progress_bar.update(1)

      try:
        filename = "Models/Model_k20_" + model_name + "_" + current_datetime + ".h5"
        reset_model_vgg16.save(filename)
      except:
        continue

    if model_name == "ResNet50":
      reset_model_resnet50 = clone_model(resnet_model)
      reset_model_resnet50.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=[f1_m, tf.keras.metrics.AUC()])
      ### Training on K20
      history_resnet50_k20 = reset_model_resnet50.fit(train_data_resnet50_k20, train_labels_resnet50_k20, validation_data=(val_data_resnet50_k20, val_labels_resnet50_k20),
                          batch_size=batch_size, epochs=epochs, callbacks=[early_stopping, AUCROCCallback(validation_data=(val_data_resnet50_k20, val_labels_resnet50_k20))])

      formating_results_k20 = {}
      formating_results_k20["Model"] = model_name
      formating_results_k20["Loss"] = history_resnet50_k20.history["loss"]
      formating_results_k20["F1-Score"] = history_resnet50_k20.history["f1_m"]
      formating_results_k20["Validation Loss"] = history_resnet50_k20.history["val_loss"]
      formating_results_k20["Validation F1-Score"] = history_resnet50_k20.history["val_f1_m"]
      formating_results_k20["AUC-ROC VAL"] = history_resnet50_k20.history['val_auc_roc']

      loss_evaluation_resnet50, f1_m_evaluation_resnet50, auc_roc_evaluation_resnet50 = reset_model_resnet50.evaluate(test_data_resnet50_k20, test_labels_resnet50_k20, verbose=1)
      formating_results_k20["F1-Score Test"] = f1_m_evaluation_resnet50
      formating_results_k20["Loss Test"] = loss_evaluation_resnet50
      formating_results_k20["AUC-ROC Test"] = auc_roc_evaluation_resnet50


      scoring_models_k20.append(formating_results_k20)

      y_pred = reset_model_resnet50.predict(test_data_resnet50_k20)
      y_pred = np.argmax(y_pred, axis=1)

      cm = confusion_matrix(test_labels_resnet50_k20, y_pred)
      cm_float = cm.astype(float)

      try:
          cm_filename = "ConfusionMatrix/ConfusionMatrix_k20_" + model_name + "_" + current_datetime + ".csv"
          np.savetxt(cm_filename, cm_float, delimiter=",", fmt='%.4f')
      except:
          continue

      progress_bar.update(1)

      try:
        filename = "Models/Model_k20_" + model_name + "_" + current_datetime + ".h5"
        reset_model_resnet50.save(filename)
      except:
        continue

    if model_name == "InceptionV3":

      reset_model_inceptionv3 = clone_model(inception_model)
      reset_model_inceptionv3.compile(loss='binary_crossentropy', optimizer=optimizer_other, metrics=[f1_m, tf.keras.metrics.AUC()])
      ###Training on K20
      history_inceptionv3_k20 = reset_model_inceptionv3.fit(train_data_inceptionv3_k20, train_labels_inceptionv3_k20,
                                validation_data=(val_data_inceptionv3_k20, val_labels_inceptionv3_k20),
                          batch_size=batch_size, epochs=epochs, callbacks=[early_stopping, AUCROCCallback(validation_data=(val_data_inceptionv3_k20, val_labels_inceptionv3_k20))])

      formating_results_k20 = {}
      formating_results_k20["Model"] = model_name
      formating_results_k20["Loss"] = history_inceptionv3_k20.history["loss"]
      formating_results_k20["F1-Score"] = history_inceptionv3_k20.history["f1_m"]
      formating_results_k20["Validation Loss"] = history_inceptionv3_k20.history["val_loss"]
      formating_results_k20["Validation F1-Score"] = history_inceptionv3_k20.history["val_f1_m"]
      formating_results_k20["AUC-ROC VAL"] = history_inceptionv3_k20.history['val_auc_roc']

      loss_evaluation_inceptionv3, f1_m_evaluation_inceptionv3, auc_roc_evaluation_inceptionv3 = reset_model_inceptionv3.evaluate(test_data_inceptionv3_k20, test_labels_inceptionv3_k20, verbose=1)
      formating_results_k20["F1-Score Test"] = f1_m_evaluation_inceptionv3
      formating_results_k20["Loss Test"] = loss_evaluation_inceptionv3
      formating_results_k20["AUC-ROC Test"] = auc_roc_evaluation_inceptionv3

      scoring_models_k20.append(formating_results_k20)


      y_pred = reset_model_inceptionv3.predict(test_data_inceptionv3_k20)
      y_pred = np.argmax(y_pred, axis=1)

      cm = confusion_matrix(test_labels_inceptionv3_k20, y_pred)
      cm_float = cm.astype(float)

      try:
          cm_filename = "ConfusionMatrix/ConfusionMatrix_k20_" + model_name + "_" + current_datetime + ".csv"
          np.savetxt(cm_filename, cm_float, delimiter=",", fmt='%.4f')
      except:
          continue


      progress_bar.update(1)

      try:
        filename = "Models/Model_K20_" + model_name + "_" + current_datetime + ".h5"
        reset_model_inceptionv3.save(filename)
      except:
        continue

    if model_name == "Xception":
      reset_model_xception = clone_model(xception_model)
      reset_model_xception.compile(loss='binary_crossentropy', optimizer=optimizer_other, metrics=[f1_m, tf.keras.metrics.AUC()])
      ### Training on K20
      history_xception_k20 = reset_model_xception.fit(train_data_xception_k20, train_labels_xception_k20,
                                validation_data=(val_data_xception_k20, val_labels_xception_k20),
                          batch_size=batch_size, epochs=epochs, callbacks=[early_stopping, AUCROCCallback(validation_data=(val_data_xception_k20, val_labels_xception_k20))])

      formating_results_k20 = {}
      formating_results_k20["Model"] = model_name
      formating_results_k20["Loss"] = history_xception_k20.history["loss"]
      formating_results_k20["F1-Score"] = history_xception_k20.history["f1_m"]
      formating_results_k20["Validation Loss"] = history_xception_k20.history["val_loss"]
      formating_results_k20["Validation F1-Score"] = history_xception_k20.history["val_f1_m"]
      formating_results_k20["AUC-ROC VAL"] = history_xception_k20.history['val_auc_roc']

      loss_evaluation_xception, f1_m_evaluation_xception, auc_roc_evaluation_xception  = reset_model_xception.evaluate(test_data_xception_k20, test_labels_xception_k20, verbose=1)
      formating_results_k20["F1-Score Test"] = f1_m_evaluation_xception
      formating_results_k20["Loss Test"] = loss_evaluation_xception
      formating_results_k20["AUC-ROC Test"] = auc_roc_evaluation_xception

      scoring_models_k20.append(formating_results_k20)

      y_pred = reset_model_xception.predict(test_data_xception_k20)
      y_pred = np.argmax(y_pred, axis=1)

      cm = confusion_matrix(test_labels_xception_k20, y_pred)
      cm_float = cm.astype(float)

      try:
          cm_filename = "ConfusionMatrix/ConfusionMatrix_k20_" + model_name + "_" + current_datetime + ".csv"
          np.savetxt(cm_filename, cm_float, delimiter=",", fmt='%.4f')
      except:
          continue

      progress_bar.update(1)

      try:
        filename = "Models/Model_k20_" + model_name + "_" + current_datetime + ".h5"
        reset_model_xception.save(filename)
      except:
        continue

# Progressbar close
progress_bar.close()

# Scoring Dataframe
df_k20 = pd.DataFrame(scoring_models_k20)
df_k20.to_csv("model_metrics_k20_balanced" + current_datetime, index=False)

# %%
df_k20.to_csv("model_metrics_k20_balanced" + current_datetime, index=False)

# %% [markdown]
# # Plot Table

# %%
#df_last_values_k5 = df_k5.copy()
#df_last_values_k10 = df_k10.copy()
df_last_values_k20 = df_k20.copy()

#for column in df_k5.columns[1:-1]:
    #df_last_values_k5[column] = df_k5[column].apply(lambda x: x[-1] if isinstance(x, list) else x)

#for column in df_k10.columns[1:-1]:
    #f_last_values_k10[column] = df_k10[column].apply(lambda x: x[-1] if isinstance(x, list) else x)

for column in df_k20.columns[1:-1]:
    df_last_values_k20[column] = df_k20[column].apply(lambda x: x[-1] if isinstance(x, list) else x)

# Den DataFrame mit den letzten Werten anzeigen
print("--------- K5 -------")
#print(df_last_values_k5)

print("--------- K10 -------")
#print(df_last_values_k10)

print("--------- K20 -------")
print(df_last_values_k20)
# Out:
# --------- K5 -------
# --------- K10 -------
# --------- K20 -------
#          Model      Loss  F1-Score  Validation Loss  Validation F1-Score  \
# 0        VGG16  0.284188  0.921569         0.145431             1.000000
# 1     ResNet50  0.186690  0.921569         0.041407             1.000000
# 2  InceptionV3  0.540664  0.921569         0.536440             0.666667
# 3     Xception  0.287651  0.921569         0.117684             1.000000
#
#    AUC-ROC VAL  F1-Score Test  Loss Test  AUC-ROC Test
# 0          1.0       0.833333   0.192570      0.970000
# 1          1.0       0.833333   0.129347      0.973333
# 2          1.0       0.558824   0.552490      0.992222
# 3          1.0       0.833333   0.176438      0.960556

# %% [markdown]
# # Plot Diagramm

# %%
for index, row in df_k5.iterrows():
    model_name = row['Model']

    # Loss
    plt.figure(figsize=(10, 8))
    plt.plot(row['Loss'], label='Training Loss')
    plt.plot(row['Validation Loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title(f'{model_name} - Loss')
    plt.legend()
    plt.show()

    # F1-Score
    plt.figure(figsize=(10, 5))
    plt.plot(row['F1-Score'], label ='Training F1-Score')
    plt.plot(row['Validation F1-Score'], label='Validation F1-Score')
    plt.xlabel('Epochs')
    plt.ylabel('F1-Score')
    plt.title(f'{model_name} - F1-Score')
    plt.legend()
    plt.show()

    # AUC-ROC
    plt.figure(figsize=(10, 5))
    plt.plot(row['AUC-ROC VAL'], label ='AUC-ROC VAL')
    plt.xlabel('Epochs')
    plt.ylabel('AUC-ROC')
    plt.title(f'{model_name} - AUC-ROC')
    plt.legend()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-d7519d73fb89> in <cell line: 1>()
# ----> 1 for index, row in df_k5.iterrows():
#       2     model_name = row['Model']
#       3
#       4     # Loss
#       5     plt.figure(figsize=(10, 8))
#
# NameError: name 'df_k5' is not defined

# %%
for index, row in df_k10.iterrows():
    model_name = row['Model']

    # Loss
    plt.figure(figsize=(10, 8))
    plt.plot(row['Loss'], label='Training Loss')
    plt.plot(row['Validation Loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title(f'{model_name} - Loss')
    plt.legend()
    plt.show()

    # F1-Score
    plt.figure(figsize=(10, 5))
    plt.plot(row['F1-Score'], label ='Training F1-Score')
    plt.plot(row['Validation F1-Score'], label='Validation F1-Score')
    plt.xlabel('Epochs')
    plt.ylabel('F1-Score')
    plt.title(f'{model_name} - F1-Score')
    plt.legend()
    plt.show()

    # AUC-ROC
    plt.figure(figsize=(10, 5))
    plt.plot(row['AUC-ROC VAL'], label ='AUC-ROC VAL')
    plt.xlabel('Epochs')
    plt.ylabel('AUC-ROC')
    plt.title(f'{model_name} - AUC-ROC')
    plt.legend()
    plt.show()

# %%
for index, row in df_k20.iterrows():
    model_name = row['Model']

    # Loss
    plt.figure(figsize=(10, 8))
    plt.plot(row['Loss'], label='Training Loss')
    plt.plot(row['Validation Loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title(f'{model_name} - Loss')
    plt.legend()
    plt.show()

    # F1-Score
    plt.figure(figsize=(10, 5))
    plt.plot(row['F1-Score'], label ='Training F1-Score')
    plt.plot(row['Validation F1-Score'], label='Validation F1-Score')
    plt.xlabel('Epochs')
    plt.ylabel('F1-Score')
    plt.title(f'{model_name} - F1-Score')
    plt.legend()
    plt.show()

    # AUC-ROC
    plt.figure(figsize=(10, 5))
    plt.plot(row['AUC-ROC VAL'], label ='AUC-ROC VAL')
    plt.xlabel('Epochs')
    plt.ylabel('AUC-ROC')
    plt.title(f'{model_name} - AUC-ROC')
    plt.legend()
    plt.show()

# %%
# Speicherpfad für die Modelle USECASES
model_directory = "UseCases/"

# Aktuelles Datum und Uhrzeit erhalten USECASES
current_datetime = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
